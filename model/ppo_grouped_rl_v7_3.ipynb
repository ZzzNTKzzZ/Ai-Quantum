# %%
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import torch as th

import random
seed_val = 321 # random.randint(1, 100)
print(f"🎲 Random Seed: {seed_val}")
th.manual_seed(seed_val)
np.random.seed(seed_val)
random.seed(seed_val)
# Thiết lập thêm cho tính ổn định của môi trường Gym
import os
os.makedirs('v7_3', exist_ok=True)
# os.environ['PYTHONHASHSEED'] = str(seed_val)
from torch import nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import warnings
warnings.filterwarnings('ignore') # Tắt các cảnh báo không cần thiết để Log sạch đẹp hơn
# Out:
# 🎲 Random Seed: 321

# %% [markdown]
# ## [CẤU HÌNH CHIẾN LƯỢC ĐẦU TƯ - AI TRADING]

# %% [markdown]
# ## Khối cấu hình trung tâm (Control Panel) giúp bạn tinh chỉnh "tính cách" của AI

# %%
# mà không cần can thiệp sâu vào bên trong mã nguồn.
class CONFIG:
    TRAINING_MODE = 'fast_split' # 'fast_split' or 'rolling_window'
    # 1. PHÍ GIAO DỊCH (Transaction Cost): 
    # Tỷ lệ phần trăm CTCK thu cho mỗi lần bạn mua hoặc bán cổ phiếu. (VD: 0.2% = 0.002)
    COST_RATE = 0.0001

    TURNOVER_PENALTY_RATE = 0.3
    DRAWDOWN_PENALTY_RATE = 5.0
    LIQUIDITY_BONUS_RATE = 0.02
    TRAIN_WINDOW = 252
    TEST_WINDOW = 21
    SAVE_MODEL_PATH = "v7_3/AI_Brain_v7_3.zip"

    # Các giá trị tính điểm (Reward/Penalty System)
    REWARD_WIN_MULT = 100
    REWARD_LOSS_MULT = 200
    REWARD_ALPHA_MULT = 50
    REWARD_CASH_CRASH_MULT = 100
    PENALTY_OVER_DIVERSIFICATION = 0.01
    
        
    # 7. CHẾ ĐỘ CHỜ HÀNG VỀ T+2 (Rule 7: Settlement Lock):
    # Đặc sản của Chứng khoán VN. Số ngày cổ phiếu bị "nhốt" chưa về tài khoản. 
    # Trong những ngày này (VD: 2 ngày đầu tiên), AI tuyệt đối không thể bán cắt lỗ/chốt lời dù thị trường sập.
    T_PLUS_SETTLEMENT = 3
    
    # 8. SỐ BƯỚC ĐÀO TẠO (Training Timesteps):
    # Số vòng lặp để AI cập nhật bộ não. Càng cao (50k - 100k) AI càng thông minh nhưng thời gian train càng lâu.
    TRAINING_TIMESTEPS = 1_500_000
    
    # 9. ĐỘ PHÂN BỔ VỐN (Entropy Coefficient):
    # Quyết định AI sẽ All-in hay Rải rác.
    # Giá trị nhỏ (0.001) -> Ưu tiên All-in vài mã mạnh nhất.
    # Giá trị lớn (0.05) -> Ưu tiên chia đều tiền ra mua nhiều mã để phân tán rủi ro.
    ENT_COEF = 0.005

    # 10. NEURAL NETWORK & PPO HYPERPARAMETERS
    FEATURES_DIM = 256
    NET_ARCH = [64, 64]
    N_STEPS = 1024
    LEARNING_RATE = 0.00005
    BATCH_SIZE = 90
    USE_SDE = False
    SDE_SAMPLE_FREQ = 5

    # Neuron Network

# %% [markdown]
# ## LUẬT 2: MARKET CONTEXT (TỔNG HỢP VĨ MÔ & VI MÔ)

# %% [markdown]
# ## Hàm này nạp dữ liệu từ file Parquet (đã chạy HMM) và chế biến thêm các chỉ báo để tạo thành

# %%
def load_data():
    # 1. Nạp dữ liệu thô
    raw_df = pd.read_parquet(r"C:\Users\ADMIN\Desktop\Kaggle\output\hmm_v3_op1_extended\master_drl_ready_full.parquet")
    raw_df['time'] = pd.to_datetime(raw_df['time'])
    
    # Lấy các DataFrame cơ sở
    returns_df = raw_df.pivot(index='time', columns='ticker', values='log_return').fillna(0)
    weights_dim = returns_df.shape[1] # Số lượng mã cổ phiếu
    
    vol_df = raw_df.pivot(index='time', columns='ticker', values='volume').fillna(0)
    close_df = raw_df.pivot(index='time', columns='ticker', values='close').ffill().fillna(0)
    open_df = raw_df.pivot(index='time', columns='ticker', values='open').ffill().fillna(0)
    low_df = raw_df.pivot(index='time', columns='ticker', values='low').ffill().fillna(0)
    high_df = raw_df.pivot(index='time', columns='ticker', values='high').ffill().fillna(0)
    
    # -------------------------------------
    # CÁC CHỈ BÁO VĨ MÔ & KỸ THUẬT (DÀNH CHO AI HỌC)
    # -------------------------------------
    market_return_5d = returns_df.rolling(5).sum().mean(axis=1).fillna(0) 
    market_return_20d = returns_df.rolling(20).sum().mean(axis=1).fillna(0) 
    market_vol_20d = returns_df.rolling(20).std().mean(axis=1).fillna(0) 
    
    price_df = np.exp(returns_df.cumsum())
    ma20_df = price_df.rolling(20).mean()
    dist_ma20_df = ((price_df - ma20_df) / ma20_df).fillna(0)
    momentum_3d_df = (close_df / close_df.shift(3) - 1).fillna(0) # T+3 Momentum

    # -------------------------------------
    # CÁC CHỈ BÁO KỊCH BẢN LUẬT (KHÔNG CHO AI HỌC)
    # -------------------------------------
    ema_df_20 = close_df.ewm(span=20, adjust=False).mean()
    ema_df_50 = close_df.ewm(span=50, adjust=False).mean()
    ema_df_200 = close_df.ewm(span=200, adjust=False).mean()

    # SMA Vol
    def calc_sma(df, n=5):
        return df.rolling(n).mean()
    sma_vol_5_df = calc_sma(vol_df)
    sma_vol_20_df = calc_sma(vol_df, n=20)
    # RSI (Chuẩn Wilder's Smoothing)
    change_df = close_df - close_df.shift(1)
    gain_df = change_df.clip(lower=0)
    loss_df = change_df.clip(upper=0).abs()
    ema_gain = gain_df.ewm(alpha=1/20, min_periods=20, adjust=False).mean()
    ema_loss = loss_df.ewm(alpha=1/20, min_periods=20, adjust=False).mean()
    rs_df = ema_gain / ema_loss
    rsi_df = 100 - (100 / (1 + rs_df))
    rsi_df = rsi_df.fillna(100)

    # MACD
    macd_df = close_df.ewm(span=12, adjust=False).mean() - close_df.ewm(span=26, adjust=False).mean()
    signal_df = macd_df.ewm(span=9, adjust=False).mean()
    hist_df = macd_df - signal_df
    
    # Độ dốc xu hướng (Slope)
    def calc_slope(df, n=3):
        return (df - df.shift(n)) / n
    slope_ema20_3_df = calc_slope(ema_df_20, n=3)  
    slope_sma5_3_df = calc_sma(sma_vol_5_df, n=3)
    slope_sma5_3_df = calc_sma(sma_vol_5_df, n=20)
    slope_sma5_50_df = calc_sma(sma_vol_5_df, n=50)
    slope_sma5_200_df = calc_sma(sma_vol_5_df, n=200)
    # Candlestick Patterns (Đã sửa lỗi Boolean Error)
    body_df = (close_df - open_df).abs()
    tail_df = (np.minimum(close_df, open_df) - low_df)
    head_df = high_df - np.maximum(close_df, open_df)
    
    is_hammer_df = (tail_df >= 2 * body_df) & (head_df <= 0.1 * body_df) & (body_df > 0)
    is_bull_engulf_df = (close_df.shift(1) < open_df.shift(1)) & (close_df > open_df) & (close_df >= open_df.shift(1)) & (open_df <= close_df.shift(1))

    # LowestLow(5) và HighestHigh(10)
    lowest_low_5_df = low_df.rolling(5).min()
    highest_high_5_df = high_df.rolling(5).max()
    highest_high_10_df = high_df.rolling(10).max()
    highest_high_20_df = high_df.rolling(20).max()

    # Đáy và đỉnh
    # Ngày T-2 là Đỉnh nếu nó cao hơn T-4, T-3 (Quá khứ) VÀ cao hơn T-1, T (Hiện tại)
    is_peak = (high_df.shift(2) > high_df.shift(4)) & \
                (high_df.shift(2) > high_df.shift(3)) & \
                (high_df.shift(2) > high_df.shift(1)) & \
                (high_df.shift(2) > high_df)

    # Ngày T-2 là Đáy nếu nó thấp hơn T-4, T-3 (Quá khứ) VÀ thấp hơn T-1, T (Hiện tại)
    is_valley = (low_df.shift(2) < low_df.shift(4)) & \
                (low_df.shift(2) < low_df.shift(3)) & \
                (low_df.shift(2) < low_df.shift(1)) & \
                (low_df.shift(2) < low_df)
    
    peak_values = high_df.shift(2).where(is_peak, np.nan)
    valley_values = low_df.shift(2).where(is_valley, np.nan)

    last_peak_df = peak_values.ffill()
    last_valley_df = valley_values.ffill()
        
    # FIBONACCI
    wave_amplitude_df = last_peak_df - last_valley_df
    wave_state_df = pd.DataFrame(np.nan, index=high_df.index, columns=high_df.columns)
    
    wave_state_df[is_peak] = 1
    wave_state_df[is_valley] = -1
    
    last_swing_type_df = wave_state_df.ffill()
    
    # SUP() RES()
    n = 20 # Số phiên để xác nhận Đỉnh/Đáy (Bạn có thể tinh chỉnh 10 hoặc 20)
    window = 2 * n + 1
    
    # 1. Tìm mức cao nhất/thấp nhất trong 41 ngày gần nhất (20 ngày trước + 1 ngày giữa + 20 ngày sau)
    # V6 Fix: Tính đỉnh/đáy bằng trailing max/min (Bảo vệ tuyệt đối khỏi Lookahead Bias)
    rolling_max = high_df.rolling(window=2 * n + 1, min_periods=1).max()
    rolling_min = low_df.rolling(window=2 * n + 1, min_periods=1).min()

    is_peak = (high_df == rolling_max)
    is_valley = (low_df == rolling_min)
    
    # 3. Ghi nhớ mức giá tại Đỉnh/Đáy đó
    peak_values = high_df.where(is_peak, np.nan)
    valley_values = low_df.where(is_valley, np.nan)
    
    # 4. Kéo dài giá trị ra để lấy Hỗ trợ (Sup) và Kháng cự (Res) gần nhất
    res_df = peak_values.ffill() # Đỉnh gần nhất (Res)
    sup_df = valley_values.ffill() # Đáy gần nhất (Sup)


    # SÓNG TĂNG CHÍNH = Mốc cuối cùng được xác nhận là 1 cái Đỉnh
    # Trả về giá trị True/False cho từng ngày
    is_upward_wave_df = (last_swing_type_df == 1)
    fib_382_df = last_peak_df - (0.382 * wave_amplitude_df)
    fib_500_df = last_peak_df - (0.500 * wave_amplitude_df)
    fib_618_df = last_peak_df - (0.618 * wave_amplitude_df)
    fib_ext_127_df = last_peak_df + (0.272 * wave_amplitude_df)
    fib_ext_161_df = last_peak_df + (0.618 * wave_amplitude_df)

     # Bollinger Bands 
    bb_middle_df = close_df.rolling(20).mean()
    bb_std_df = close_df.rolling(20).std()
    bb_upper_df = bb_middle_df + (2 * bb_std_df)
    bb_lower_df = bb_middle_df - (2 * bb_std_df)
    
    # 2. TÍNH ĐỘ RỘNG DẢI BĂNG (BB WIDTH)
    bb_width_df = (bb_upper_df - bb_lower_df) / bb_middle_df
    
    # 3. TÍN HIỆU BIẾN ĐỘNG MẠNH (DẢI BĂNG MỞ RỘNG)
    # So sánh độ rộng hôm nay với hôm qua VÀ với Trung bình 20 ngày
    bb_expanding_df = (bb_width_df > bb_width_df.shift(1)) & \
                        (bb_width_df > bb_width_df.rolling(20).mean())
    
    # ACCUMULATION
    highest_high_21_df = high_df.rolling(21).max().shift(1)
    lowest_low_21_df = low_df.rolling(21).min().shift(1)
        
    # Biên độ dao động của cái hộp nhỏ hơn 15%
    is_accumulation_df = (highest_high_21_df - lowest_low_21_df) / lowest_low_21_df <= 0.15
    # Bóc tách dữ liệu HMM từ raw_df
    prob0_df = raw_df.pivot(index='time', columns='ticker', values='prob_ticker_0').fillna(0) 
    prob1_df = raw_df.pivot(index='time', columns='ticker', values='prob_ticker_1').fillna(0) 
    prob2_df = raw_df.pivot(index='time', columns='ticker', values='prob_ticker_2').fillna(0) 
    vol_20d_df = raw_df.pivot(index='time', columns='ticker', values='rolling_vol_20d').fillna(0)
    ret_20d_df = raw_df.pivot(index='time', columns='ticker', values='return_20d').fillna(0)
    vol_ratio_df = raw_df.pivot(index='time', columns='ticker', values='volume_ratio').fillna(0)

    # Broadcast vĩ mô
    mkt_ret5_df = pd.DataFrame(np.tile(market_return_5d.values.reshape(-1, 1), (1, weights_dim)), index=returns_df.index, columns=returns_df.columns)
    mkt_ret20_df = pd.DataFrame(np.tile(market_return_20d.values.reshape(-1, 1), (1, weights_dim)), index=returns_df.index, columns=returns_df.columns)
    mkt_vol_df = pd.DataFrame(np.tile(market_vol_20d.values.reshape(-1, 1), (1, weights_dim)), index=returns_df.index, columns=returns_df.columns)
    
    # -------------------------------------------------------------------------
    # GOM THÀNH 2 BẢNG BIỆT LẬP (1 CHO AI, 1 CHO LUẬT KỊCH BẢN)
    # -------------------------------------------------------------------------
    from scipy.stats import norm
    def apply_nqt(df):
        ranked = df.rank(axis=1, method='average')
        uniform = (ranked - 0.5) / df.shape[1]
        nqt = pd.DataFrame(norm.ppf(uniform), index=df.index, columns=df.columns)
        return nqt.replace([np.inf, -np.inf], 0).fillna(0)

    # BẢNG 1: Dành cho Mạng Nơ-ron (Đã qua NQT Cross-Sectional)
    core_list = [prob0_df, prob1_df, prob2_df, vol_20d_df, ret_20d_df, vol_ratio_df, mkt_ret5_df, mkt_ret20_df, mkt_vol_df, dist_ma20_df, momentum_3d_df]
    ai_features_df = pd.concat([apply_nqt(df) for df in core_list], axis=1).fillna(0)
                                
    # BẢNG 2: Kho vũ khí cho kịch bản của con người (AI không được thấy)

    list_strategies = [vol_df ,low_df ,close_df, 
                       ema_df_20, ema_df_50, ema_df_200, 
                       bb_lower_df, bb_middle_df ,bb_upper_df,
                       rsi_df, hist_df, macd_df,
                       sma_vol_20_df,
                       slope_ema20_3_df, slope_sma5_3_df, 
                       slope_sma5_50_df, slope_sma5_200_df,
                       is_hammer_df.astype(float), is_bull_engulf_df.astype(float),
                       lowest_low_5_df, highest_high_5_df ,highest_high_10_df, highest_high_20_df,
                       fib_382_df, fib_500_df, fib_618_df, is_upward_wave_df, fib_ext_127_df, fib_ext_161_df,
                       sup_df, res_df,
                       bb_expanding_df,
                       is_accumulation_df,
                       ]

    strategies_features_df = pd.concat(list_strategies, axis=1).fillna(0)
    
    num_strategies_features = 33
    
    # HỢP NHẤT TOÀN BỘ CHỈ BÁO VÀO AI FEATURES (Áp dụng NQT cho mảng chiến lược đưa vào AI)
    ai_strategies_df = pd.concat([apply_nqt(df) for df in list_strategies], axis=1).fillna(0)
    ai_features_df = pd.concat([ai_features_df, ai_strategies_df], axis=1)
    num_ai_features = 10
    # Đồng bộ độ dài
    returns_df, ai_features_df = returns_df.align(ai_features_df, axis=0, join='inner')
    returns_df, strategies_features_df = returns_df.align(strategies_features_df, axis=0, join='inner')
    tickers = returns_df.columns.tolist()
    
    dates = returns_df.index.strftime('%d/%m/%Y').tolist()
    return returns_df, ai_features_df, strategies_features_df, weights_dim, tickers, num_strategies_features, dates

# %% [markdown]
# ## LUẬT 1, 3, 5, 6: MÔI TRƯỜNG ĐẦU TƯ (GYM ENVIRONMENT)

# %% [markdown]
# ## Lớp này mô phỏng lại Sàn chứng khoán. Nơi AI sẽ thử nghiệm các lệnh Mua/Bán và nhận Phạt/Thưởng (Reward).

# %%
class AdvancedPortfolioEnv(gym.Env):
        def __init__(self, returns_df, ai_features_df, script_features_df, weights_dim, num_script_features, tickers=None, step_size=1, cost_rate=CONFIG.COST_RATE, is_test=False, dates=None):

            super().__init__()
            self.returns_arr = np.exp(returns_df.values) - 1.0 
            
            # Lưu 2 mảng tách biệt
            self.features_arr = ai_features_df.values
            self.script_arr = script_features_df.values
            
            self.weights_dim = weights_dim
            self.num_script_features = num_script_features
            self.n_steps = len(self.returns_arr)
            
            self.step_size = step_size
            self.cost_rate = cost_rate
            self.is_test = is_test 
            self.tickers = tickers
            self.dates = dates
            self.prev_weights = np.zeros(self.weights_dim)
            self.high_watermark = 1.0
            self.current_portfolio_value = 1.0
            
            self.action_space = spaces.Box(low=0, high=1, shape=(self.weights_dim,), dtype=np.float32)
            # Báo cho AI biết là nó chỉ cần học 10 tính năng (vì ai_features_df có 10 cột)
            self.num_features = self.features_arr.shape[1] // self.weights_dim
            self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.weights_dim, self.num_features), dtype=np.float32)
            
            self.current_step = 0
            self.weights = np.zeros(self.weights_dim)
            self.entry_prices = np.zeros(self.weights_dim)
            self.entry_scenarios = np.zeros(self.weights_dim)
            self.entry_stages = np.zeros(self.weights_dim)
            self.weight_unlocked = np.zeros(self.weights_dim)
            self.locked_weights = np.zeros((3, self.weights_dim)) # FIFO Queue
            self.avg_entry_prices = np.zeros(self.weights_dim)
            self.initial_capital = 100_000_000 # Giả lập vốn 100 triệu
            self.current_capital = self.initial_capital
            self.peak_nav = self.initial_capital
            self.prev_drawdown = 0.0
        def reset(self, seed=None, options=None):
            self.current_step = 0
            self.weights = np.zeros(self.weights_dim)
            self.weight_unlocked = np.zeros(self.weights_dim)
            self.locked_weights = np.zeros((3, self.weights_dim))
            self.avg_entry_prices = np.zeros(self.weights_dim)
            self.current_capital = self.initial_capital
            self.peak_nav = self.initial_capital
            self.prev_drawdown = 0.0
            return self._get_obs(), {}
            
        def _get_obs(self):
            idx = min(self.current_step, self.n_steps - 1)
            obs_1d = self.features_arr[idx]
            obs_2d = obs_1d.reshape(self.num_features, self.weights_dim).T
            return obs_2d.astype(np.float32)
            
        def step(self, action):
            current_obs = self._get_obs()
            idx = min(self.current_step, self.n_steps - 1)
            
            current_scripts = self.script_arr[idx].reshape(self.num_script_features, self.weights_dim).T
            prev_idx = max(0, idx - 1)
            prev_scripts = self.script_arr[prev_idx].reshape(self.num_script_features, self.weights_dim).T
            
            # V6 Fix: Xóa Kịch bản Hard-code
            # V6 Fix: Tuyến tính hóa thay vì Softmax
            # Normalize action và sửa lỗi logic Zero-out của bản cũ
            action = np.clip(action, 0, 1)
            action_sum = np.sum(action)
            if action_sum > 1.0:
                action = action / action_sum
                
            # [HÀNG ĐỢI FIFO] Cập nhật hàng về tài khoản
            self.weight_unlocked += self.locked_weights[0]
            self.locked_weights[0] = self.locked_weights[1]
            self.locked_weights[1] = self.locked_weights[2]
            self.locked_weights[2] = 0.0
            
            # [FIFO] Áp dụng luật khoá: Chỉ được bán tối đa bằng số hàng đã về (unlocked)
            max_sell = self.weight_unlocked
            action = np.maximum(action, self.weights - max_sell)
            
            # Nếu vì ép bán ít đi mà tổng action > 1.0, ta phải giảm bớt lượng mua (buy)
            action_sum = np.sum(action)
            if action_sum > 1.0:
                buys = np.maximum(0, action - self.weights)
                sells = np.maximum(0, self.weights - action)
                excess = action_sum - 1.0
                total_buys = np.sum(buys)
                if total_buys > 0:
                    reduction_factor = 1.0 - (excess / total_buys)
                    buys = buys * reduction_factor
                action = self.weights - sells + buys
                
            # [FIFO] Cập nhật lại kho sau khi mua/bán
            delta = action - self.weights
            sells = np.maximum(0, -delta)
            buys = np.maximum(0, delta)
            
            self.weight_unlocked -= sells
            
            T_SETTLE = getattr(CONFIG, 'T_PLUS_SETTLEMENT', 3)
            if T_SETTLE == 0:
                self.weight_unlocked += buys
            else:
                idx = min(T_SETTLE - 1, 2)
                self.locked_weights[idx] += buys
                
            turnover = np.sum(np.abs(action - self.weights))
            cost = self.cost_rate * turnover
            
            self.prev_weights = self.weights.copy()
            self.weights = action
            
            market_ret = np.mean(self.returns_arr[self.current_step])
            daily_ret = np.sum(self.weights * self.returns_arr[self.current_step]) - cost
            
            self.current_portfolio_value = self.current_portfolio_value * (1 + daily_ret)
            
            # V7.2 Fix: Hàm Reward mượt mà, tránh sợ hãi cực độ
            
            base_reward = daily_ret * 100 
            if daily_ret < 0:
                base_reward *= 2.0  # Phạt gấp 2 lần nếu lỗ
            
            reward = base_reward
            
            if getattr(self, 'is_test', False):

            
                date_str = self.dates[self.current_step] if getattr(self, 'dates', None) else f'Step {self.current_step}'

            
                

            
                # Tracker for detailed logs

            
                trade_logs = []

            
                current_prices = current_scripts[:, 2] # close price is index 2

            
                

            
                for i in range(self.weights_dim):

            
                    old_w = self.prev_weights[i]

            
                    new_w = self.weights[i]

            
                    

            
                    if new_w > old_w + 0.001: # Mua thêm

            
                        added_w = new_w - old_w

            
                        if old_w < 0.001:

            
                            self.avg_entry_prices[i] = current_prices[i]

            
                        else:

            
                            self.avg_entry_prices[i] = (old_w * self.avg_entry_prices[i] + added_w * current_prices[i]) / new_w

            
                        trade_logs.append(f"🟢 MUA {self.tickers[i]}: Tỷ trọng {old_w*100:.1f}% -> {new_w*100:.1f}% | Giá khớp: {current_prices[i]:.2f}")

            
                        

            
                    elif new_w < old_w - 0.001: # Bán

            
                        sold_w = old_w - new_w

            
                        if self.avg_entry_prices[i] > 0:

            
                            profit_pct = (current_prices[i] - self.avg_entry_prices[i]) / self.avg_entry_prices[i]

            
                            profit_pct -= self.cost_rate # Tính luôn thuế phí

            
                            profit_money = (sold_w * self.current_capital) * profit_pct

            
                            

            
                            icon = "🔥 CHỐT LỜI" if profit_pct > 0 else "🩸 CẮT LỖ"

            
                            trade_logs.append(f"{icon} {self.tickers[i]}: Tỷ trọng {old_w*100:.1f}% -> {new_w*100:.1f}% | Giá bán: {current_prices[i]:.2f} | Giá vốn: {self.avg_entry_prices[i]:.2f} | Lãi/Lỗ: {profit_pct*100:+.2f}% ({profit_money:+,.0f} đ)")

            
                        if new_w < 0.001:

            
                            self.avg_entry_prices[i] = 0

            
                

            
                # Cập nhật vốn hiện tại (NAV)

            
                prev_capital = self.current_capital

            
                self.current_capital = self.current_capital * (1 + daily_ret)

            
                daily_capital_change = self.current_capital - prev_capital

            
                

            
                weight_sum = np.sum(self.weights)

            
                if len(trade_logs) > 0 or weight_sum > 0.01:

            
                    cash_weight = max(0.0, 1.0 - weight_sum)

            
                    allocations = [f"{self.tickers[k]}: {self.weights[k]*100:.1f}%" for k in range(self.weights_dim) if self.weights[k] > 0.01]

            
                    alloc_str = ", ".join(allocations) if allocations else "Trống"

            
                    

            
                    print(f"\n[{date_str}] 📅 BÁO CÁO GIAO DỊCH:")

            
                    for log in trade_logs:

            
                        print(f"  > {log}")

            
                    print(f"  💵 Tỷ trọng: Tiền mặt {cash_weight*100:.1f}% | Cổ phiếu: [{alloc_str}]")

            
                    print(f"  📈 Tài sản: {daily_capital_change:+,.0f} đ | Hiệu suất ngày: {daily_ret*100:+.2f}% | Tổng NAV: {self.current_capital:,.0f} đ")

            
                    

            
            # ------------ HỆ THỐNG PHẠT DRAWDOWN & GAME OVER ------------
            self.peak_nav = max(self.peak_nav, getattr(self, 'current_capital', 100_000_000))
            drawdown = (self.peak_nav - getattr(self, 'current_capital', 100_000_000)) / self.peak_nav
            
            prev_dd = getattr(self, 'prev_drawdown', 0.0)
            if drawdown > prev_dd:
                dd_increase = drawdown - prev_dd
                reward -= (dd_increase * 1000)
            
            self.prev_drawdown = drawdown
            
            force_terminate = False
            if drawdown > 0.30:
                reward -= 100
                force_terminate = True
                if getattr(self, 'is_test', False):
                    print(f"💀 GAME OVER: Cháy tài khoản! Drawdown {drawdown*100:.1f}% tại Step {self.current_step}")
            # -----------------------------------------------------------
            
            self.current_step += 1
            done = (self.current_step >= self.n_steps - 1) or force_terminate
            
            return self._get_obs(), float(reward), done, False, {'net_return': daily_ret}

# %% [markdown]
# ## MẠNG NƠ-RON TRÍ TUỆ NHÂN TẠO (NEURAL NETWORK STRUCTURE)

# %% [markdown]
# ## Đây là "Bộ Não" thực sự của AI. Mạng Nơ-ron này chịu trách nhiệm Đọc dữ liệu (Extractor).

# %%
class AdvancedTickerExtractor(BaseFeaturesExtractor):
        def __init__(self, observation_space: spaces.Box, features_dim: int = 256):
            super().__init__(observation_space, features_dim)
            num_tickers = observation_space.shape[0] # 46 mã
            num_features_per_ticker = observation_space.shape[1] # 11 tính năng
            
            # Tầng 1 (Local): Học phân tích RIÊNG LẺ
            self.ticker_net = nn.Sequential(
                nn.Linear(num_features_per_ticker, 32),
                nn.ReLU(),
                # nn.Dropout(0.2),
                nn.Linear(32, 16),
                nn.ReLU()
            )
            
            # --- CẢI TIẾN: Tầng 1.5 (Attention) ---
            # Cho phép các cổ phiếu giao tiếp và so sánh sức mạnh với nhau
            self.attention = nn.MultiheadAttention(embed_dim=16, num_heads=4, batch_first=True)
            self.layer_norm = nn.LayerNorm(16)
            # --------------------------------------
    
            # Tầng 2 (Global): Tổng hợp ra quyết định
            self.global_net = nn.Sequential(
                nn.Linear(num_tickers * 16, features_dim),
                nn.ReLU()
            )
    
        def forward(self, observations: th.Tensor) -> th.Tensor:
            batch_size, num_tickers, num_features = observations.shape
            
            # 1. Trích xuất Local
            obs_reshaped = observations.view(batch_size * num_tickers, num_features)
            ticker_features = self.ticker_net(obs_reshaped)
            
            # Đưa về dạng 3D: (Batch, Số_Mã, Đặc_trưng) để chạy Attention
            ticker_features = ticker_features.view(batch_size, num_tickers, 16) 
            
            # 2. --- CẢI TIẾN: Cross-Ticker Attention ---
            # Các mã cổ phiếu "nhìn" nhau để tìm ra con mạnh nhất (Leader)
            attn_out, _ = self.attention(ticker_features, ticker_features, ticker_features)
            
            # Residual connection + LayerNorm (Bắt buộc phải có để đạo hàm không bị nổ))
            ticker_features = self.layer_norm(ticker_features + attn_out)
            # --------------------------------------------
            
            # 3. Đưa Tầng 1.5 vào Tầng 22
            flattened_features = ticker_features.view(batch_size, num_tickers * 16)
            global_features = self.global_net(flattened_features)
            
            return global_features

# %%
returns_df, ai_features_df, strategies_features_df, weights_dim, tickers, num_strategies_features, dates = load_data()

# %%
from stable_baselines3.common.vec_env import VecNormalize
print("\n[LUẬT 4] KHỞI ĐỘNG HỆ THỐNG HUẤN LUYỆN...")

TRAINING_MODE = getattr(CONFIG, 'TRAINING_MODE', 'fast_split') # 'fast_split' or 'rolling_window'

total_days = len(returns_df)

model = None

policy_kwargs = dict(
    features_extractor_class=AdvancedTickerExtractor,
    features_extractor_kwargs=dict(features_dim=CONFIG.FEATURES_DIM),
    net_arch=dict(pi=CONFIG.NET_ARCH, vf=CONFIG.NET_ARCH)
)


all_test_returns = []

if TRAINING_MODE == 'fast_split':
    print(f"\n=======================================================")
    print(f"--- CHẾ ĐỘ HỌC NHANH (FAST SPLIT: 70% Train, 15% Val, 15% Test) ---")
    
    train_ratio = 0.7
    val_ratio = 0.15
    
    train_end = int(total_days * train_ratio)
    val_end = int(total_days * (train_ratio + val_ratio))
    
    returns_train = returns_df.iloc[:train_end]
    ai_train = ai_features_df.iloc[:train_end]
    strategies_train = strategies_features_df.iloc[:train_end]
    dates_train = dates[:train_end]
    
    returns_val = returns_df.iloc[train_end:val_end]
    ai_val = ai_features_df.iloc[train_end:val_end]
    strategies_val = strategies_features_df.iloc[train_end:val_end]
    dates_val = dates[train_end:val_end]
    
    returns_test = returns_df.iloc[val_end:]
    ai_test = ai_features_df.iloc[val_end:]
    strategies_test = strategies_features_df.iloc[val_end:]
    dates_test = dates[val_end:]
    
    train_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
        returns_train, ai_train, strategies_train, weights_dim, num_strategies_features, tickers=tickers, dates=dates_train
    )])
    train_env = VecNormalize(train_env, norm_obs=False, norm_reward=True, clip_reward=10.0)
    
    print(f"Khởi tạo Mạng Nơ-ron AI (Train: {len(dates_train)} days, Val: {len(dates_val)} days, Test: {len(dates_test)} days)...")
    model = PPO("MlpPolicy", train_env, 
                policy_kwargs=policy_kwargs, 
                verbose=1, 
                n_steps=1024,
                learning_rate=0.00005,
                ent_coef=CONFIG.ENT_COEF,
                batch_size=90)
                
    print("\n[CURRICULUM LEARNING] Bắt đầu huấn luyện theo từng cấp độ độ trễ (T+0 -> T+1 -> T+3)...")

                
    CONFIG.T_PLUS_SETTLEMENT = 0

                
    print("Giai đoạn 1: Huấn luyện với T+0 (100,000 steps)...")

                
    model.learn(total_timesteps=10000, reset_num_timesteps=False)

                
    CONFIG.T_PLUS_SETTLEMENT = 1

                
    print("Giai đoạn 2: Huấn luyện với T+1 (100,000 steps)...")

                
    model.learn(total_timesteps=10000, reset_num_timesteps=False)

                
    CONFIG.T_PLUS_SETTLEMENT = 3

                
    print("Giai đoạn 3: Huấn luyện với T+3 (300,000 steps)...")

                
    model.learn(total_timesteps=30000, reset_num_timesteps=False)
    
    model.save(getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_3/AI_Brain_v7_3.zip'))
    train_env.save("v7_3/vec_normalize.pkl")
    
    print(f"\nĐang chạy Backtest trên Test Set (CÓ TÍNH PHÍ GIAO DỊCH {CONFIG.COST_RATE * 100}%)...")
    print("-------------------------------------------------------")
    
    test_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
        returns_test, ai_test, strategies_test, weights_dim, num_strategies_features, tickers=tickers, dates=dates_test, is_test=True
    )])
    test_env = VecNormalize.load("v7_3/vec_normalize.pkl", test_env)
    test_env.training = False
    test_env.norm_reward = False
    obs = test_env.reset()
    
    done = [False]
    while not done[0]:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = test_env.step(action)
        if 'net_return' in info[0]:
            all_test_returns.append(info[0]['net_return'])
            
    total_profit = (np.prod(1 + np.array(all_test_returns)) - 1) * 100
    print(f"\n🏆 TỔNG LỢI NHUẬN TEST SET: {total_profit:+.2f}%")
    
elif TRAINING_MODE == 'rolling_window':
    train_window = getattr(CONFIG, 'TRAIN_WINDOW', 252)
    test_window = getattr(CONFIG, 'TEST_WINDOW', 21)
    
    current_start = 0
    fold_idx = 1
    
    while current_start + train_window < total_days:
        train_start = current_start
        train_end = current_start + train_window
        test_start = train_end
        test_end = min(test_start + test_window, total_days)
        
        if test_end - test_start < 2:
            break
            
        print(f"\n=======================================================")
        print(f"--- CHU KỲ {fold_idx}: HỌC {dates[train_start]} -> {dates[train_end-1]} | THỰC CHIẾN: {dates[test_start]} -> {dates[test_end-1]} ---")
        
        returns_train = returns_df.iloc[train_start:train_end]
        ai_train = ai_features_df.iloc[train_start:train_end]
        strategies_train = strategies_features_df.iloc[train_start:train_end]
        dates_train = dates[train_start:train_end]
        
        returns_test = returns_df.iloc[test_start:test_end]
        ai_test = ai_features_df.iloc[test_start:test_end]
        strategies_test = strategies_features_df.iloc[test_start:test_end]
        dates_test = dates[test_start:test_end]
        
        train_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
            returns_train, ai_train, strategies_train, weights_dim, num_strategies_features, tickers=tickers, dates=dates_train
        )])
        
        if model is None:
            print("Khởi tạo Mạng Nơ-ron AI hoàn toàn mới...")
            train_env = VecNormalize(train_env, norm_obs=False, norm_reward=True, clip_reward=10.0)
            model = PPO("MlpPolicy", train_env, 
                policy_kwargs=policy_kwargs, 
                verbose=1, 
                n_steps=CONFIG.N_STEPS,
                learning_rate=CONFIG.LEARNING_RATE,
                ent_coef=CONFIG.ENT_COEF,
                batch_size=CONFIG.BATCH_SIZE,
                use_sde=CONFIG.USE_SDE,
                sde_sample_freq=CONFIG.SDE_SAMPLE_FREQ)
        else:
            print("Nạp kiến thức cũ, chuyển Sàn môi trường để học tiếp (Continual Learning)...")
            train_env = VecNormalize.load("v7_3/vec_normalize.pkl", train_env)
            train_env.training = True
            train_env.norm_reward = True
            model.set_env(train_env)
            
        print("\n[CURRICULUM LEARNING] Bắt đầu huấn luyện theo từng cấp độ độ trễ (T+0 -> T+1 -> T+3)...")

            
        CONFIG.T_PLUS_SETTLEMENT = 0

            
        print("Giai đoạn 1: Huấn luyện với T+0 (1,000,000 steps)...")

            
        model.learn(total_timesteps=1000000, reset_num_timesteps=False)

            
        CONFIG.T_PLUS_SETTLEMENT = 1

            
        print("Giai đoạn 2: Huấn luyện với T+1 (1,000,000 steps)...")

            
        model.learn(total_timesteps=1000000, reset_num_timesteps=False)

            
        CONFIG.T_PLUS_SETTLEMENT = 3

            
        print("Giai đoạn 3: Huấn luyện với T+3 (3,000,000 steps)...")

            
        model.learn(total_timesteps=3000000, reset_num_timesteps=False)
        
        model.save(getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_3/AI_Brain_v7_3.zip'))
        train_env.save("v7_3/vec_normalize.pkl")
        
        print(f"Đang chạy Backtest thực chiến (CÓ TÍNH PHÍ GIAO DỊCH {CONFIG.COST_RATE * 100}%)...")
        print("-------------------------------------------------------")
        
        test_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
            returns_test, ai_test, strategies_test, weights_dim, num_strategies_features, tickers=tickers, dates=dates_test, is_test=True
        )])
        obs = test_env.reset()
        
        done = [False]
        fold_returns = []
        while not done[0]:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, info = test_env.step(action)
            if 'net_return' in info[0]:
                all_test_returns.append(info[0]['net_return'])
                fold_returns.append(info[0]['net_return'])
                

        # Tính lợi nhuận lũy kế cho chu kỳ hiện tại
        fold_profit = (np.prod(1 + np.array(fold_returns)) - 1) * 100
        print(f"💰 KẾT QUẢ CHU KỲ {fold_idx}: Lợi nhuận thực chiến = {fold_profit:+.2f}%")
        print("="*55 + "\n")
        current_start += test_window
        fold_idx += 1
        

    total_profit = (np.prod(1 + np.array(all_test_returns)) - 1) * 100
    print(f"\n🏆 TỔNG LỢI NHUẬN BACKTEST TOÀN BỘ THỜI GIAN: {total_profit:+.2f}%")
    print(f"\nĐã lưu bộ não AI mới nhất vào {getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_3/AI_Brain_v7_3.zip')}. Có thể dùng trực tiếp cho Live Trading ngày mai!")

# --- Centralized Leaderboard Logger ---
import os
import shutil
import pandas as pd
from datetime import datetime

os.makedirs('v7_3', exist_ok=True)

log_file = r'training_leaderboard.csv'
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

old_model_name = f"v7_3/AI_Brain_v7_3.zip"
new_model_name = f"v7_3/AI_Brain_v7_Seed{seed_val}_Profit_{total_profit:.2f}.zip"

if os.path.exists(old_model_name):
    shutil.copy(old_model_name, new_model_name)

# Tạo dict chứa các thông số cơ bản
new_row = {
    'Timestamp': timestamp,
    'Version': 'v7_3',
    'Seed': seed_val,
    'Profit (%)': round(total_profit, 2),
    'Model Path': new_model_name,
    'Total Features': ai_features_df.shape[1] // weights_dim,
}

# Tự động quét và lấy toàn bộ các tham số trong class CONFIG
for k in dir(CONFIG):
    blacklist_cols = ['TEST_WINDOW', 'TRAINING_MODE', 'TRAINING_TIMESTEPS', 'TRAIN_WINDOW']
    if not k.startswith('__') and k not in blacklist_cols:
        new_row[k] = getattr(CONFIG, k)

# Đọc file cũ nếu có và nối thêm dòng mới (Pandas tự xử lý việc thiếu cột của dữ liệu cũ)
if os.path.exists(log_file):
    try:
        df = pd.read_csv(log_file)
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    except:
        df = pd.DataFrame([new_row])
else:
    df = pd.DataFrame([new_row])

df = df.drop(columns=[c for c in blacklist_cols if c in df.columns], errors='ignore')

df.to_csv(log_file, index=False)

print(f"🎯 Đã lưu log tự động cấu hình vào Leaderboard! Lợi nhuận: {total_profit:.2f}% | Model: {new_model_name}")
# Out:
# [LUẬT 4] KHỞI ĐỘNG HỆ THỐNG HUẤN LUYỆN...
#
# =======================================================
# --- CHẾ ĐỘ HỌC NHANH (FAST SPLIT: 70% Train, 15% Val, 15% Test) ---
# Khởi tạo Mạng Nơ-ron AI (Train: 1667 days, Val: 357 days, Test: 358 days)...
# Using cpu device
#
# [CURRICULUM LEARNING] Bắt đầu huấn luyện theo từng cấp độ độ trễ (T+0 -> T+1 -> T+3)...
# Giai đoạn 1: Huấn luyện với T+0 (100,000 steps)...
# -----------------------------
# | time/              |      |
# |    fps             | 757  |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0102613345 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -65.3        |
# |    explained_variance   | 0.0747       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0016      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0303      |
# |    std                  | 1            |
# |    value_loss           | 0.636        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.009785372 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.0949      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.101      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0327     |
# |    std                  | 1           |
# |    value_loss           | 0.144       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008379297 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0862     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 1           |
# |    value_loss           | 0.0687      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.009301177 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.121      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0391     |
# |    std                  | 1           |
# |    value_loss           | 0.0471      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009497407 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.164      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0401     |
# |    std                  | 1           |
# |    value_loss           | 0.0474      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008845032 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.142      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0432     |
# |    std                  | 1           |
# |    value_loss           | 0.0255      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 335        |
# |    iterations           | 8          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01032439 |
# |    clip_fraction        | 0.0916     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.3      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.152     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0477    |
# |    std                  | 1          |
# |    value_loss           | 0.0285     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 9           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.011027768 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.176      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0502     |
# |    std                  | 1           |
# |    value_loss           | 0.0232      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011167142 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.143      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.055      |
# |    std                  | 1           |
# |    value_loss           | 0.0162      |
# -----------------------------------------
# Giai đoạn 2: Huấn luyện với T+1 (100,000 steps)...
# ------------------------------
# | time/              |       |
# |    fps             | 641   |
# |    iterations      | 1     |
# |    time_elapsed    | 1     |
# |    total_timesteps | 11264 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011342466 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.161      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0561     |
# |    std                  | 1           |
# |    value_loss           | 0.0136      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.011996794 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.162      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0602     |
# |    std                  | 1           |
# |    value_loss           | 0.0135      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012432898 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.18       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0603     |
# |    std                  | 1           |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.011061381 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.158      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0579     |
# |    std                  | 1           |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 6            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0123095745 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -65.3        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.162       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0623      |
# |    std                  | 1            |
# |    value_loss           | 0.0111       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.012708415 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.174      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0641     |
# |    std                  | 1           |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 328        |
# |    iterations           | 8          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01411879 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.3      |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.194     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0678    |
# |    std                  | 1          |
# |    value_loss           | 0.00942    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 9           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.014584758 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.168      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0717     |
# |    std                  | 1           |
# |    value_loss           | 0.00895     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013870902 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.184      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0715     |
# |    std                  | 1           |
# |    value_loss           | 0.00792     |
# -----------------------------------------
# Giai đoạn 3: Huấn luyện với T+3 (300,000 steps)...
# ------------------------------
# | time/              |       |
# |    fps             | 651   |
# |    iterations      | 1     |
# |    time_elapsed    | 1     |
# |    total_timesteps | 21504 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016137002 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.185      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.074      |
# |    std                  | 1           |
# |    value_loss           | 0.00777     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.015581541 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.183      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0734     |
# |    std                  | 1           |
# |    value_loss           | 0.00669     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014691644 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.182      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0714     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00752     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.016442584 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.166      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0763     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00655     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016722115 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.177      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0764     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.017698292 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.189      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0806     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00638     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017784016 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.195      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0781     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00523     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 335        |
# |    iterations           | 9          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 29696      |
# | train/                  |            |
# |    approx_kl            | 0.01707817 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.2      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.171     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0781    |
# |    std                  | 0.998      |
# |    value_loss           | 0.00556    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018091183 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.183      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0801     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00497     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.018013904 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.189      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.079      |
# |    std                  | 0.998       |
# |    value_loss           | 0.0049      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019152803 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.191      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0822     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00494     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 13          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.018025208 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.183      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.082      |
# |    std                  | 0.998       |
# |    value_loss           | 0.00463     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 14          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018803542 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.192      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0821     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00484     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.019052897 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.177      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0839     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00506     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.019784212 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.193      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0843     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00402     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 386        |
# |    iterations           | 17         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 37888      |
# | train/                  |            |
# |    approx_kl            | 0.02017908 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.2      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.193     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0859    |
# |    std                  | 0.998      |
# |    value_loss           | 0.00419    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 390        |
# |    iterations           | 18         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02051106 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.2      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.215     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0862    |
# |    std                  | 0.998      |
# |    value_loss           | 0.00437    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 19          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.020672252 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.197      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0843     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00383     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 20          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020755975 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.213      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0875     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00409     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 21          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.020446157 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.18       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0869     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00408     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.022060419 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.198      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0887     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00355     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 408       |
# |    iterations           | 23        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 44032     |
# | train/                  |           |
# |    approx_kl            | 0.0222883 |
# |    clip_fraction        | 0.248     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -65.2     |
# |    explained_variance   | 0.993     |
# |    learning_rate        | 5e-05     |
# |    loss                 | -0.2      |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -0.0893   |
# |    std                  | 0.999     |
# |    value_loss           | 0.00349   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021017438 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.219      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0863     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00354     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 25          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.021949032 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.213      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0896     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00316     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 26          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022794738 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.196      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0886     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00359     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 388        |
# |    iterations           | 27         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 48128      |
# | train/                  |            |
# |    approx_kl            | 0.02324879 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.2      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.197     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0923    |
# |    std                  | 0.999      |
# |    value_loss           | 0.00365    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 28          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023884399 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.213      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0921     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00394     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 29          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.023109877 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.213      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0899     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 30          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023631228 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.198      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0911     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00332     |
# -----------------------------------------
#
# Đang chạy Backtest trên Test Set (CÓ TÍNH PHÍ GIAO DỊCH 0.01%)...
# -------------------------------------------------------
#
# [06/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 0.0% -> 9.5% | Giá khớp: 38.37
#   > 🟢 MUA BMP: Tỷ trọng 0.0% -> 5.4% | Giá khớp: 114.13
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 62.01
#   > 🟢 MUA DIG: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 16.22
#   > 🟢 MUA FPT: Tỷ trọng 0.0% -> 9.0% | Giá khớp: 125.71
#   > 🟢 MUA GAS: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 63.58
#   > 🟢 MUA HCM: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 21.40
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 9.3% | Giá khớp: 13.28
#   > 🟢 MUA HT1: Tỷ trọng 0.0% -> 3.9% | Giá khớp: 11.78
#   > 🟢 MUA KBC: Tỷ trọng 0.0% -> 5.8% | Giá khớp: 27.15
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 10.1% | Giá khớp: 15.90
#   > 🟢 MUA MSN: Tỷ trọng 0.0% -> 2.1% | Giá khớp: 67.20
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 6.2% | Giá khớp: 56.19
#   > 🟢 MUA NKG: Tỷ trọng 0.0% -> 3.9% | Giá khớp: 12.64
#   > 🟢 MUA PVD: Tỷ trọng 0.0% -> 2.5% | Giá khớp: 22.44
#   > 🟢 MUA PVT: Tỷ trọng 0.0% -> 10.3% | Giá khớp: 18.57
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 4.2% | Giá khớp: 46.93
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 5.2% | Giá khớp: 10.41
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 5.1% | Giá khớp: 57.71
#   > 🟢 MUA VSC: Tỷ trọng 0.0% -> 5.4% | Giá khớp: 12.09
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.5%, BMP: 5.4%, FPT: 9.0%, HSG: 9.3%, HT1: 3.9%, KBC: 5.8%, MBB: 10.1%, MSN: 2.1%, MWG: 6.2%, NKG: 3.9%, PVD: 2.5%, PVT: 10.3%, REE: 4.2%, SBT: 5.2%, VNM: 5.1%, VSC: 5.4%]
#   📈 Tài sản: -1,348,665 đ | Hiệu suất ngày: -1.35% | Tổng NAV: 98,651,335 đ
#
# [07/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.5%, BMP: 5.4%, FPT: 9.0%, HSG: 9.3%, HT1: 3.9%, KBC: 5.8%, MBB: 10.1%, MSN: 2.1%, MWG: 6.2%, NKG: 3.9%, PVD: 2.5%, PVT: 10.3%, REE: 4.2%, SBT: 5.2%, VNM: 5.1%, VSC: 5.4%]
#   📈 Tài sản: +558,723 đ | Hiệu suất ngày: +0.57% | Tổng NAV: 99,210,058 đ
#
# [08/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.5%, BMP: 5.4%, FPT: 9.0%, HSG: 9.3%, HT1: 3.9%, KBC: 5.8%, MBB: 10.1%, MSN: 2.1%, MWG: 6.2%, NKG: 3.9%, PVD: 2.5%, PVT: 10.3%, REE: 4.2%, SBT: 5.2%, VNM: 5.1%, VSC: 5.4%]
#   📈 Tài sản: +562,983 đ | Hiệu suất ngày: +0.57% | Tổng NAV: 99,773,041 đ
#
# [09/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BID: Tỷ trọng 9.5% -> 3.6% | Giá bán: 39.51 | Giá vốn: 38.37 | Lãi/Lỗ: +2.96% (+173,156 đ)
#   > 🟢 MUA BMP: Tỷ trọng 5.4% -> 6.0% | Giá khớp: 117.62
#   > 🩸 CẮT LỖ CTD: Tỷ trọng 0.7% -> 0.0% | Giá bán: 61.83 | Giá vốn: 62.01 | Lãi/Lỗ: -0.30% (-2,202 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.3% -> 2.6% | Giá khớp: 15.70
#   > 🟢 MUA DPM: Tỷ trọng 0.0% -> 2.5% | Giá khớp: 18.91
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 9.0% -> 6.7% | Giá bán: 125.29 | Giá vốn: 125.71 | Lãi/Lỗ: -0.34% (-8,018 đ)
#   > 🟢 MUA GAS: Tỷ trọng 0.3% -> 6.8% | Giá khớp: 63.11
#   > 🟢 MUA HCM: Tỷ trọng 0.9% -> 3.0% | Giá khớp: 21.28
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 9.3% -> 7.4% | Giá bán: 13.21 | Giá vốn: 13.28 | Lãi/Lỗ: -0.54% (-9,926 đ)
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 3.9% -> 3.7% | Giá bán: 11.69 | Giá vốn: 11.78 | Lãi/Lỗ: -0.77% (-1,175 đ)
#   > 🟢 MUA KBC: Tỷ trọng 5.8% -> 8.3% | Giá khớp: 28.30
#   > 🟢 MUA MBB: Tỷ trọng 10.1% -> 10.6% | Giá khớp: 16.12
#   > 🟢 MUA MSN: Tỷ trọng 2.1% -> 2.6% | Giá khớp: 67.30
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 6.2% -> 0.0% | Giá bán: 56.88 | Giá vốn: 56.19 | Lãi/Lỗ: +1.22% (+75,947 đ)
#   > 🩸 CẮT LỖ NKG: Tỷ trọng 3.9% -> 3.4% | Giá bán: 12.50 | Giá vốn: 12.64 | Lãi/Lỗ: -1.12% (-5,733 đ)
#   > 🟢 MUA NLG: Tỷ trọng 0.0% -> 2.5% | Giá khớp: 28.94
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 19.59
#   > 🟢 MUA PDR: Tỷ trọng 0.0% -> 2.8% | Giá khớp: 17.59
#   > 🟢 MUA PVD: Tỷ trọng 2.5% -> 4.1% | Giá khớp: 21.66
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 10.3% -> 5.1% | Giá bán: 18.22 | Giá vốn: 18.57 | Lãi/Lỗ: -1.89% (-97,481 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 4.2% -> 0.0% | Giá bán: 47.22 | Giá vốn: 46.93 | Lãi/Lỗ: +0.61% (+25,387 đ)
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 5.2% -> 0.4% | Giá bán: 10.80 | Giá vốn: 10.41 | Lãi/Lỗ: +3.74% (+177,561 đ)
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 4.1% | Giá khớp: 31.91
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 11.59
#   > 🟢 MUA VIC: Tỷ trọng -0.0% -> 4.5% | Giá khớp: 20.38
#   > 🟢 MUA VNM: Tỷ trọng 5.1% -> 7.5% | Giá khớp: 57.06
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 5.4% -> 0.0% | Giá bán: 12.33 | Giá vốn: 12.09 | Lãi/Lỗ: +1.98% (+106,013 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 3.6%, BMP: 6.0%, DIG: 2.6%, DPM: 2.5%, FPT: 6.7%, GAS: 6.8%, HCM: 3.0%, HSG: 7.4%, HT1: 3.7%, KBC: 8.3%, MBB: 10.6%, MSN: 2.6%, NKG: 3.4%, NLG: 2.5%, NT2: 1.6%, PDR: 2.8%, PVD: 4.1%, PVT: 5.1%, SJS: 4.1%, VIC: 4.5%, VNM: 7.5%]
#   📈 Tài sản: -312,254 đ | Hiệu suất ngày: -0.31% | Tổng NAV: 99,460,787 đ
#
# [10/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 3.6% -> 5.1% | Giá khớp: 38.67
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 6.0% -> 5.8% | Giá bán: 113.26 | Giá vốn: 114.52 | Lãi/Lỗ: -1.11% (-2,324 đ)
#   > 🟢 MUA CTG: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 25.73
#   > 🟢 MUA DCM: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 31.07
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 2.6% -> 2.3% | Giá bán: 15.49 | Giá vốn: 15.75 | Lãi/Lỗ: -1.67% (-4,045 đ)
#   > 🟢 MUA DPM: Tỷ trọng 2.5% -> 3.0% | Giá khớp: 18.55
#   > 🟢 MUA FPT: Tỷ trọng 6.7% -> 7.1% | Giá khớp: 124.02
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 6.8% -> 6.5% | Giá bán: 62.83 | Giá vốn: 63.13 | Lãi/Lỗ: -0.48% (-1,292 đ)
#   > 🟢 MUA GMD: Tỷ trọng 0.0% -> 0.6% | Giá khớp: 58.31
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 11.65
#   > 🟢 MUA HCM: Tỷ trọng 3.0% -> 4.0% | Giá khớp: 20.68
#   > 🟢 MUA HSG: Tỷ trọng 7.4% -> 10.4% | Giá khớp: 12.80
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 3.7% -> 0.4% | Giá bán: 11.69 | Giá vốn: 11.78 | Lãi/Lỗ: -0.77% (-25,978 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 8.3% -> 6.3% | Giá bán: 28.30 | Giá vốn: 27.49 | Lãi/Lỗ: +2.92% (+56,514 đ)
#   > 🩸 CẮT LỖ MSN: Tỷ trọng 2.6% -> 0.5% | Giá bán: 65.50 | Giá vốn: 67.22 | Lãi/Lỗ: -2.57% (-54,604 đ)
#   > 🩸 CẮT LỖ NKG: Tỷ trọng 3.4% -> 0.0% | Giá bán: 12.36 | Giá vốn: 12.64 | Lãi/Lỗ: -2.23% (-74,210 đ)
#   > 🟢 MUA NLG: Tỷ trọng 2.5% -> 3.8% | Giá khớp: 28.54
#   > 🟢 MUA NT2: Tỷ trọng 1.6% -> 2.6% | Giá khớp: 19.40
#   > 🩸 CẮT LỖ PVD: Tỷ trọng 4.1% -> 3.4% | Giá bán: 21.66 | Giá vốn: 22.15 | Lãi/Lỗ: -2.21% (-15,045 đ)
#   > 🟢 MUA PVT: Tỷ trọng 5.1% -> 7.0% | Giá khớp: 17.84
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 1.2% | Giá khớp: 47.15
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 0.4% -> 0.0% | Giá bán: 11.03 | Giá vốn: 10.41 | Lãi/Lỗ: +5.95% (+23,207 đ)
#   > 🟢 MUA TCH: Tỷ trọng 0.1% -> 0.4% | Giá khớp: 11.10
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 7.5% -> 4.6% | Giá bán: 56.60 | Giá vốn: 57.50 | Lãi/Lỗ: -1.58% (-45,572 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 5.1%, BMP: 5.8%, DIG: 2.3%, DPM: 3.0%, FPT: 7.1%, GAS: 6.5%, HAG: 1.6%, HCM: 4.0%, HSG: 10.4%, KBC: 6.3%, MBB: 10.5%, NLG: 3.8%, NT2: 2.6%, PDR: 2.8%, PVD: 3.4%, PVT: 7.0%, REE: 1.2%, SJS: 4.1%, VIC: 4.5%, VNM: 4.6%]
#   📈 Tài sản: -1,531,231 đ | Hiệu suất ngày: -1.54% | Tổng NAV: 97,929,556 đ
#
# [13/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 5.1% -> 6.7% | Giá khớp: 38.87
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 5.8% -> 5.4% | Giá bán: 111.52 | Giá vốn: 114.52 | Lãi/Lỗ: -2.63% (-11,919 đ)
#   > 🟢 MUA CTG: Tỷ trọng 0.9% -> 2.7% | Giá khớp: 25.87
#   > 🟢 MUA DCM: Tỷ trọng 0.5% -> 1.9% | Giá khớp: 31.64
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 2.0% | Giá khớp: 18.30
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 7.1% -> 4.5% | Giá bán: 124.28 | Giá vốn: 125.62 | Lãi/Lỗ: -1.08% (-26,586 đ)
#   > 🟢 MUA GMD: Tỷ trọng 0.6% -> 1.3% | Giá khớp: 58.12
#   > 🟢 MUA HCM: Tỷ trọng 4.0% -> 4.2% | Giá khớp: 21.13
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 10.4% -> 2.9% | Giá bán: 12.98 | Giá vốn: 13.14 | Lãi/Lỗ: -1.25% (-91,225 đ)
#   > 🟢 MUA HT1: Tỷ trọng 0.4% -> 1.1% | Giá khớp: 11.83
#   > 🟢 MUA KBC: Tỷ trọng 6.3% -> 7.1% | Giá khớp: 28.25
#   > 🟢 MUA MSN: Tỷ trọng 0.5% -> 1.4% | Giá khớp: 65.00
#   > 🟢 MUA NLG: Tỷ trọng 3.8% -> 6.2% | Giá khớp: 28.76
#   > 🟢 MUA PDR: Tỷ trọng 2.8% -> 5.9% | Giá khớp: 17.36
#   > 🟢 MUA PVD: Tỷ trọng 3.4% -> 3.6% | Giá khớp: 22.25
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 7.0% -> 3.9% | Giá bán: 17.91 | Giá vốn: 18.37 | Lãi/Lỗ: -2.54% (-78,825 đ)
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 4.6% -> 2.4% | Giá bán: 56.69 | Giá vốn: 57.50 | Lãi/Lỗ: -1.42% (-31,010 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.7%, BMP: 5.4%, CTG: 2.7%, DCM: 1.9%, DIG: 2.3%, DPM: 3.0%, EIB: 2.0%, FPT: 4.5%, GAS: 6.5%, GMD: 1.3%, HAG: 1.6%, HCM: 4.2%, HSG: 2.9%, HT1: 1.1%, KBC: 7.1%, MBB: 10.6%, MSN: 1.4%, NLG: 6.2%, NT2: 2.6%, PDR: 5.9%, PVD: 3.6%, PVT: 3.9%, REE: 1.3%, SJS: 4.1%, VIC: 4.5%, VNM: 2.4%]
#   📈 Tài sản: +901,758 đ | Hiệu suất ngày: +0.92% | Tổng NAV: 98,831,314 đ
#
# [14/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 6.7% -> 8.0% | Giá khớp: 38.57
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 5.4% -> 3.9% | Giá bán: 108.04 | Giá vốn: 114.52 | Lãi/Lỗ: -5.66% (-83,066 đ)
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 63.45
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 2.3% -> 0.0% | Giá bán: 15.49 | Giá vốn: 15.75 | Lãi/Lỗ: -1.67% (-38,526 đ)
#   > 🩸 CẮT LỖ DPM: Tỷ trọng 3.0% -> 2.5% | Giá bán: 18.83 | Giá vốn: 18.85 | Lãi/Lỗ: -0.13% (-668 đ)
#   > 🟢 MUA EIB: Tỷ trọng 2.0% -> 3.4% | Giá khớp: 18.25
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 4.5% -> 1.9% | Giá bán: 122.17 | Giá vốn: 125.62 | Lãi/Lỗ: -2.76% (-71,717 đ)
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 6.5% -> 0.0% | Giá bán: 63.02 | Giá vốn: 63.13 | Lãi/Lỗ: -0.18% (-11,771 đ)
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 4.2% -> 1.3% | Giá bán: 20.94 | Giá vốn: 21.15 | Lãi/Lỗ: -1.02% (-29,651 đ)
#   > 🟢 MUA HSG: Tỷ trọng 2.9% -> 3.8% | Giá khớp: 12.76
#   > 🟢 MUA HT1: Tỷ trọng 1.1% -> 1.7% | Giá khớp: 11.74
#   > 🟢 MUA KBC: Tỷ trọng 7.1% -> 10.5% | Giá khớp: 28.95
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 2.2% | Giá khớp: 31.02
# ...
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 6.1% -> 4.5% | Giá bán: 14.80 | Giá vốn: 14.87 | Lãi/Lỗ: -0.50% (-10,342 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 2.4% -> 1.4% | Giá bán: 61.50 | Giá vốn: 61.95 | Lãi/Lỗ: -0.74% (-9,860 đ)
#   > 🟢 MUA VIC: Tỷ trọng 0.6% -> 4.3% | Giá khớp: 193.20
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 2.9% -> 0.7% | Giá bán: 58.30 | Giá vốn: 58.96 | Lãi/Lỗ: -1.13% (-33,064 đ)
#   > 🟢 MUA VSC: Tỷ trọng 1.4% -> 1.8% | Giá khớp: 18.50
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 8.6%, BMP: 5.8%, BVH: 3.3%, CTD: 1.7%, CTG: 4.4%, DGW: 3.6%, EIB: 3.3%, HAG: 4.7%, HCM: 2.8%, HDC: 2.7%, HT1: 1.3%, KBC: 6.6%, MSN: 10.0%, MWG: 2.6%, NT2: 1.8%, PDR: 4.8%, PHR: 5.7%, PVT: 1.8%, REE: 2.2%, SBT: 6.7%, TCH: 4.5%, VCB: 1.4%, VIC: 4.3%, VSC: 1.8%]
#   📈 Tài sản: +814,228 đ | Hiệu suất ngày: +0.60% | Tổng NAV: 137,135,546 đ
#
# [10/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 8.6% -> 6.1% | Giá bán: 41.65 | Giá vốn: 42.57 | Lãi/Lỗ: -2.17% (-72,662 đ)
#   > 🟢 MUA BMP: Tỷ trọng 5.8% -> 7.5% | Giá khớp: 135.20
#   > 🟢 MUA BVH: Tỷ trọng 3.3% -> 3.5% | Giá khớp: 66.20
#   > 🩸 CẮT LỖ CTD: Tỷ trọng 1.7% -> 1.0% | Giá bán: 71.80 | Giá vốn: 73.53 | Lãi/Lỗ: -2.36% (-21,451 đ)
#   > 🟢 MUA CTG: Tỷ trọng 4.4% -> 5.6% | Giá khớp: 33.50
#   > 🟢 MUA DCM: Tỷ trọng 0.4% -> 4.0% | Giá khớp: 37.55
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.6% -> 1.5% | Giá bán: 39.35 | Giá vốn: 40.06 | Lãi/Lỗ: -1.77% (-49,965 đ)
#   > 🟢 MUA EIB: Tỷ trọng 3.3% -> 5.4% | Giá khớp: 20.80
#   > 🟢 MUA FPT: Tỷ trọng 0.3% -> 1.4% | Giá khớp: 74.20
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 0.2% -> 0.0% | Giá bán: 82.50 | Giá vốn: 84.16 | Lãi/Lỗ: -1.99% (-6,528 đ)
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 4.7% -> 4.4% | Giá bán: 15.25 | Giá vốn: 15.19 | Lãi/Lỗ: +0.35% (+1,211 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 2.8% -> 0.0% | Giá bán: 27.80 | Giá vốn: 27.35 | Lãi/Lỗ: +1.62% (+61,209 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 2.7% -> 2.3% | Giá bán: 15.57 | Giá vốn: 15.27 | Lãi/Lỗ: +1.93% (+10,197 đ)
#   > 🟢 MUA HT1: Tỷ trọng 1.3% -> 2.7% | Giá khớp: 13.95
#   > 🟢 MUA KBC: Tỷ trọng 6.6% -> 6.8% | Giá khớp: 29.25
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.7% | Giá khớp: 23.65
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 0.2% -> 0.0% | Giá bán: 24.70 | Giá vốn: 25.00 | Lãi/Lỗ: -1.21% (-4,100 đ)
#   > 🩸 CẮT LỖ MSN: Tỷ trọng 10.0% -> 6.1% | Giá bán: 71.90 | Giá vốn: 74.17 | Lãi/Lỗ: -3.07% (-165,512 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 2.6% -> 1.0% | Giá bán: 78.20 | Giá vốn: 77.66 | Lãi/Lỗ: +0.69% (+15,861 đ)
#   > 🟢 MUA NLG: Tỷ trọng 0.0% -> 1.7% | Giá khớp: 26.24
#   > 🟢 MUA NT2: Tỷ trọng 1.8% -> 2.0% | Giá khớp: 22.30
#   > 🟢 MUA PDR: Tỷ trọng 4.8% -> 8.6% | Giá khớp: 15.20
#   > 🟢 MUA PHR: Tỷ trọng 5.7% -> 8.3% | Giá khớp: 63.90
#   > 🟢 MUA PVD: Tỷ trọng 0.0% -> 3.6% | Giá khớp: 30.10
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 1.8% -> 0.5% | Giá bán: 19.90 | Giá vốn: 20.20 | Lãi/Lỗ: -1.50% (-25,220 đ)
#   > 🟢 MUA REE: Tỷ trọng 2.2% -> 4.5% | Giá khớp: 50.30
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 6.7% -> 0.0% | Giá bán: 21.20 | Giá vốn: 20.38 | Lãi/Lỗ: +4.03% (+371,493 đ)
#   > 🔥 CHỐT LỜI STB: Tỷ trọng 0.8% -> 0.0% | Giá bán: 70.60 | Giá vốn: 70.05 | Lãi/Lỗ: +0.78% (+8,633 đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 4.5% -> 0.0% | Giá bán: 15.20 | Giá vốn: 14.87 | Lãi/Lỗ: +2.19% (+136,630 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 1.4% -> 0.0% | Giá bán: 61.70 | Giá vốn: 61.95 | Lãi/Lỗ: -0.42% (-8,124 đ)
#   > 🩸 CẮT LỖ VHC: Tỷ trọng 0.7% -> 0.0% | Giá bán: 57.00 | Giá vốn: 57.50 | Lãi/Lỗ: -0.88% (-7,961 đ)
#   > 🟢 MUA VIC: Tỷ trọng 4.3% -> 7.1% | Giá khớp: 196.00
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 0.7% -> 0.0% | Giá bán: 58.90 | Giá vốn: 58.96 | Lãi/Lỗ: -0.11% (-1,001 đ)
#   > 🟢 MUA VSC: Tỷ trọng 1.8% -> 2.1% | Giá khớp: 18.50
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.1%, BMP: 7.5%, BVH: 3.5%, CTD: 1.0%, CTG: 5.6%, DCM: 4.0%, DGW: 1.5%, EIB: 5.4%, FPT: 1.4%, HAG: 4.4%, HDC: 2.3%, HT1: 2.7%, KBC: 6.8%, KDH: 1.7%, MSN: 6.1%, NLG: 1.7%, NT2: 2.0%, PDR: 8.6%, PHR: 8.3%, PVD: 3.6%, REE: 4.5%, VIC: 7.1%, VSC: 2.1%]
#   📈 Tài sản: +1,101,395 đ | Hiệu suất ngày: +0.80% | Tổng NAV: 138,236,941 đ
#
# [11/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 6.1% -> 6.5% | Giá khớp: 41.40
#   > 🟢 MUA CTD: Tỷ trọng 1.0% -> 1.7% | Giá khớp: 71.60
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 5.6% -> 5.3% | Giá bán: 33.35 | Giá vốn: 34.00 | Lãi/Lỗ: -1.92% (-6,357 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 1.5% -> 0.8% | Giá bán: 39.15 | Giá vốn: 40.06 | Lãi/Lỗ: -2.27% (-21,392 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.1% -> 0.6% | Giá khớp: 12.70
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 5.4% -> 5.0% | Giá bán: 20.55 | Giá vốn: 20.89 | Lãi/Lỗ: -1.65% (-7,285 đ)
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 1.4% -> 1.0% | Giá bán: 73.10 | Giá vốn: 74.00 | Lãi/Lỗ: -1.23% (-5,714 đ)
#   > 🟢 MUA HCM: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 27.45
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 0.5% -> 0.0% | Giá bán: 11.80 | Giá vốn: 11.65 | Lãi/Lỗ: +1.28% (+8,351 đ)
#   > 🟢 MUA HT1: Tỷ trọng 2.7% -> 2.9% | Giá khớp: 13.75
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 6.8% -> 6.2% | Giá bán: 31.00 | Giá vốn: 29.45 | Lãi/Lỗ: +5.27% (+43,600 đ)
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 24.75
#   > 🟢 MUA MSN: Tỷ trọng 6.1% -> 7.0% | Giá khớp: 71.00
#   > 🟢 MUA MWG: Tỷ trọng 1.0% -> 1.7% | Giá khớp: 76.90
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 2.0% -> 1.9% | Giá bán: 22.35 | Giá vốn: 22.27 | Lãi/Lỗ: +0.34% (+515 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 8.6% -> 8.3% | Giá bán: 15.00 | Giá vốn: 15.19 | Lãi/Lỗ: -1.26% (-5,766 đ)
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 8.3% -> 8.0% | Giá bán: 64.50 | Giá vốn: 64.93 | Lãi/Lỗ: -0.67% (-2,486 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 0.5% -> 0.0% | Giá bán: 19.85 | Giá vốn: 20.20 | Lãi/Lỗ: -1.75% (-12,981 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 4.5% -> 3.8% | Giá bán: 50.60 | Giá vốn: 50.38 | Lãi/Lỗ: +0.42% (+4,072 đ)
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 21.90
#   > 🔥 CHỐT LỜI VIC: Tỷ trọng 7.1% -> 6.5% | Giá bán: 196.00 | Giá vốn: 194.44 | Lãi/Lỗ: +0.79% (+6,599 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 59.20
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.5%, BMP: 7.6%, BVH: 3.5%, CTD: 1.7%, CTG: 5.3%, DCM: 4.1%, EIB: 5.0%, FPT: 1.0%, HAG: 4.4%, HDC: 2.3%, HT1: 2.9%, KBC: 6.2%, KDH: 1.7%, MSN: 7.0%, MWG: 1.7%, NLG: 1.7%, NT2: 1.9%, PDR: 8.3%, PHR: 8.0%, PVD: 3.6%, REE: 3.8%, VIC: 6.5%, VSC: 2.2%]
#   📈 Tài sản: +141,282 đ | Hiệu suất ngày: +0.10% | Tổng NAV: 138,378,223 đ
#
# [12/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 6.5% -> 4.4% | Giá bán: 41.05 | Giá vốn: 42.50 | Lãi/Lỗ: -3.41% (-100,494 đ)
#   > 🟢 MUA BMP: Tỷ trọng 7.6% -> 8.0% | Giá khớp: 135.00
#   > 🩸 CẮT LỖ BVH: Tỷ trọng 3.5% -> 0.2% | Giá bán: 65.60 | Giá vốn: 67.42 | Lãi/Lỗ: -2.71% (-122,646 đ)
#   > 🟢 MUA CTD: Tỷ trọng 1.7% -> 8.3% | Giá khớp: 70.80
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 5.3% -> 1.2% | Giá bán: 33.40 | Giá vốn: 34.00 | Lãi/Lỗ: -1.78% (-101,604 đ)
#   > 🔥 CHỐT LỜI DCM: Tỷ trọng 4.1% -> 3.7% | Giá bán: 38.20 | Giá vốn: 37.55 | Lãi/Lỗ: +1.73% (+8,798 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 0.8% -> 0.0% | Giá bán: 38.90 | Giá vốn: 40.06 | Lãi/Lỗ: -2.90% (-32,621 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.6% -> 1.8% | Giá khớp: 12.60
#   > 🟢 MUA DPM: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 24.20
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 5.0% -> 2.1% | Giá bán: 20.70 | Giá vốn: 20.89 | Lãi/Lỗ: -0.93% (-38,069 đ)
#   > 🟢 MUA FPT: Tỷ trọng 1.0% -> 3.1% | Giá khớp: 73.50
#   > 🟢 MUA GMD: Tỷ trọng 0.0% -> 1.3% | Giá khớp: 76.00
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 4.4% -> 0.0% | Giá bán: 15.25 | Giá vốn: 15.19 | Lãi/Lỗ: +0.35% (+21,652 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 2.3% -> 0.0% | Giá bán: 15.40 | Giá vốn: 15.27 | Lãi/Lỗ: +0.82% (+25,936 đ)
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 11.70
#   > 🟢 MUA HT1: Tỷ trọng 2.9% -> 4.2% | Giá khớp: 13.60
#   > 🟢 MUA MBB: Tỷ trọng 0.1% -> 1.8% | Giá khớp: 24.85
#   > 🩸 CẮT LỖ MSN: Tỷ trọng 7.0% -> 4.8% | Giá bán: 71.10 | Giá vốn: 73.75 | Lãi/Lỗ: -3.60% (-107,950 đ)
#   > 🟢 MUA MWG: Tỷ trọng 1.7% -> 6.4% | Giá khớp: 76.40
#   > 🟢 MUA NKG: Tỷ trọng 0.0% -> 1.5% | Giá khớp: 12.09
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.9% -> 0.2% | Giá bán: 22.40 | Giá vốn: 22.27 | Lãi/Lỗ: +0.56% (+13,194 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 8.3% -> 3.8% | Giá bán: 14.90 | Giá vốn: 15.19 | Lãi/Lỗ: -1.91% (-118,131 đ)
#   > 🟢 MUA PHR: Tỷ trọng 8.0% -> 8.6% | Giá khớp: 63.60
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 3.8% -> 2.4% | Giá bán: 50.40 | Giá vốn: 50.38 | Lãi/Lỗ: +0.03% (+542 đ)
#   > 🟢 MUA SBT: Tỷ trọng 0.5% -> 5.6% | Giá khớp: 21.55
#   > 🔥 CHỐT LỜI VIC: Tỷ trọng 6.5% -> 2.8% | Giá bán: 195.50 | Giá vốn: 194.44 | Lãi/Lỗ: +0.53% (+27,337 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.7% -> 4.4% | Giá khớp: 59.00
#   > 🟢 MUA VSC: Tỷ trọng 2.2% -> 2.5% | Giá khớp: 18.50
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 4.4%, BMP: 8.0%, CTD: 8.3%, CTG: 1.2%, DCM: 3.7%, DIG: 1.8%, DPM: 3.2%, EIB: 2.1%, FPT: 3.1%, GMD: 1.3%, HT1: 4.2%, KBC: 6.2%, KDH: 1.7%, MBB: 1.8%, MSN: 4.8%, MWG: 6.4%, NKG: 1.5%, NLG: 1.7%, PDR: 3.8%, PHR: 8.6%, PVD: 3.6%, REE: 2.4%, SBT: 5.6%, VIC: 2.8%, VNM: 4.4%, VSC: 2.5%]
#   📈 Tài sản: -815,420 đ | Hiệu suất ngày: -0.59% | Tổng NAV: 137,562,804 đ
#
# [15/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 4.4% -> 5.5% | Giá khớp: 41.60
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 8.0% -> 5.9% | Giá bán: 137.90 | Giá vốn: 136.58 | Lãi/Lỗ: +0.96% (+26,876 đ)
#   > 🩸 CẮT LỖ BVH: Tỷ trọng 0.2% -> 0.0% | Giá bán: 65.20 | Giá vốn: 67.42 | Lãi/Lỗ: -3.30% (-9,545 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 8.3% -> 7.3% | Giá bán: 72.30 | Giá vốn: 71.20 | Lãi/Lỗ: +1.54% (+21,698 đ)
#   > 🟢 MUA CTG: Tỷ trọng 1.2% -> 4.2% | Giá khớp: 33.70
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 3.7% -> 0.1% | Giá bán: 37.20 | Giá vốn: 37.55 | Lãi/Lỗ: -0.93% (-46,501 đ)
#   > 🟢 MUA DGW: Tỷ trọng 0.0% -> 1.2% | Giá khớp: 40.20
#   > 🟢 MUA EIB: Tỷ trọng 2.1% -> 5.4% | Giá khớp: 21.15
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 3.1% -> 2.1% | Giá bán: 73.60 | Giá vốn: 73.67 | Lãi/Lỗ: -0.10% (-1,392 đ)
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 15.15
#   > 🟢 MUA HCM: Tỷ trọng 0.3% -> 2.0% | Giá khớp: 27.45
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 4.2% -> 3.7% | Giá bán: 13.65 | Giá vốn: 13.74 | Lãi/Lỗ: -0.68% (-4,655 đ)
#   > 🩸 CẮT LỖ KDH: Tỷ trọng 1.7% -> 1.1% | Giá bán: 23.25 | Giá vốn: 23.65 | Lãi/Lỗ: -1.70% (-13,259 đ)
#   > 🟢 MUA MSN: Tỷ trọng 4.8% -> 6.9% | Giá khớp: 72.20
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 6.4% -> 5.4% | Giá bán: 79.40 | Giá vốn: 76.65 | Lãi/Lỗ: +3.58% (+47,363 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 1.7% -> 0.4% | Giá bán: 26.25 | Giá vốn: 26.24 | Lãi/Lỗ: +0.03% (+468 đ)
#   > 🟢 MUA NT2: Tỷ trọng 0.2% -> 1.6% | Giá khớp: 22.75
#   > 🟢 MUA PDR: Tỷ trọng 3.8% -> 7.2% | Giá khớp: 15.10
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 8.6% -> 7.0% | Giá bán: 64.20 | Giá vốn: 64.84 | Lãi/Lỗ: -0.99% (-20,825 đ)
#   > 🩸 CẮT LỖ PVD: Tỷ trọng 3.6% -> 0.0% | Giá bán: 29.25 | Giá vốn: 30.10 | Lãi/Lỗ: -2.83% (-141,552 đ)
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 2.8% -> 1.2% | Giá bán: 192.60 | Giá vốn: 194.44 | Lãi/Lỗ: -0.96% (-20,265 đ)
#   > 🟢 MUA VSC: Tỷ trọng 2.5% -> 2.9% | Giá khớp: 18.95
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 5.5%, BMP: 5.9%, CTD: 7.3%, CTG: 4.2%, DGW: 1.2%, DIG: 1.7%, DPM: 3.2%, EIB: 5.4%, FPT: 2.1%, GMD: 1.3%, HCM: 2.0%, HT1: 3.7%, KBC: 6.3%, KDH: 1.1%, MBB: 1.8%, MSN: 6.9%, MWG: 5.4%, NKG: 1.5%, NT2: 1.6%, PDR: 7.2%, PHR: 7.0%, REE: 2.4%, SBT: 5.6%, VIC: 1.2%, VNM: 4.4%, VSC: 2.9%]
#   📈 Tài sản: +2,034,292 đ | Hiệu suất ngày: +1.48% | Tổng NAV: 139,597,096 đ
#
# [16/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 5.5% -> 6.4% | Giá khớp: 41.90
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 5.9% -> 3.9% | Giá bán: 142.00 | Giá vốn: 136.58 | Lãi/Lỗ: +3.96% (+110,025 đ)
#   > 🟢 MUA BVH: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 65.50
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 7.3% -> 6.7% | Giá bán: 72.70 | Giá vốn: 71.20 | Lãi/Lỗ: +2.10% (+18,632 đ)
#   > 🟢 MUA CTG: Tỷ trọng 4.2% -> 6.1% | Giá khớp: 33.70
#   > 🟢 MUA DGW: Tỷ trọng 1.2% -> 2.0% | Giá khớp: 41.30
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.7% -> 1.2% | Giá bán: 13.20 | Giá vốn: 12.63 | Lãi/Lỗ: +4.48% (+30,396 đ)
#   > 🟢 MUA EIB: Tỷ trọng 5.4% -> 7.1% | Giá khớp: 21.20
#   > 🟢 MUA HAG: Tỷ trọng 0.5% -> 1.8% | Giá khớp: 15.20
#   > 🟢 MUA HCM: Tỷ trọng 2.0% -> 3.2% | Giá khớp: 27.85
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 6.3% -> 4.1% | Giá bán: 30.95 | Giá vốn: 29.45 | Lãi/Lỗ: +5.10% (+153,992 đ)
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 1.1% -> 0.0% | Giá bán: 23.70 | Giá vốn: 23.65 | Lãi/Lỗ: +0.20% (+3,127 đ)
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 1.8% -> 1.7% | Giá bán: 25.10 | Giá vốn: 24.84 | Lãi/Lỗ: +1.02% (+1,425 đ)
#   > 🟢 MUA MSN: Tỷ trọng 6.9% -> 8.1% | Giá khớp: 73.00
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 5.4% -> 4.7% | Giá bán: 79.40 | Giá vốn: 76.65 | Lãi/Lỗ: +3.58% (+38,440 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 0.4% -> 0.2% | Giá bán: 28.00 | Giá vốn: 26.24 | Lãi/Lỗ: +6.70% (+22,049 đ)
#   > 🟢 MUA NT2: Tỷ trọng 1.6% -> 1.7% | Giá khớp: 22.85
#   > 🟢 MUA PDR: Tỷ trọng 7.2% -> 8.1% | Giá khớp: 15.35
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 7.0% -> 2.7% | Giá bán: 64.60 | Giá vốn: 64.84 | Lãi/Lỗ: -0.38% (-22,835 đ)
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 5.6% -> 5.1% | Giá bán: 21.75 | Giá vốn: 21.58 | Lãi/Lỗ: +0.76% (+5,635 đ)
#   > 🟢 MUA VIC: Tỷ trọng 1.2% -> 2.5% | Giá khớp: 194.00
#   > 🟢 MUA VNM: Tỷ trọng 4.4% -> 4.6% | Giá khớp: 59.10
#   > 🟢 MUA VSC: Tỷ trọng 2.9% -> 3.3% | Giá khớp: 18.95
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.4%, BMP: 3.9%, CTD: 6.7%, CTG: 6.1%, DGW: 2.0%, DIG: 1.2%, DPM: 3.2%, EIB: 7.1%, FPT: 2.1%, GMD: 1.3%, HAG: 1.8%, HCM: 3.2%, HT1: 3.6%, KBC: 4.1%, MBB: 1.7%, MSN: 8.1%, MWG: 4.7%, NKG: 1.5%, NT2: 1.7%, PDR: 8.1%, PHR: 2.7%, REE: 2.4%, SBT: 5.1%, VIC: 2.5%, VNM: 4.6%, VSC: 3.3%]
#   📈 Tài sản: +853,199 đ | Hiệu suất ngày: +0.61% | Tổng NAV: 140,450,294 đ
#
# [17/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 6.4% -> 7.5% | Giá khớp: 42.95
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 3.9% -> 3.0% | Giá bán: 147.40 | Giá vốn: 136.58 | Lãi/Lỗ: +7.91% (+102,239 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 6.7% -> 2.3% | Giá bán: 73.60 | Giá vốn: 71.20 | Lãi/Lỗ: +3.37% (+204,716 đ)
#   > 🟢 MUA CTG: Tỷ trọng 6.1% -> 7.2% | Giá khớp: 34.30
#   > 🟢 MUA DCM: Tỷ trọng 0.1% -> 2.2% | Giá khớp: 36.30
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.2% -> 0.0% | Giá bán: 13.15 | Giá vốn: 12.63 | Lãi/Lỗ: +4.08% (+68,501 đ)
#   > 🩸 CẮT LỖ DPM: Tỷ trọng 3.2% -> 0.0% | Giá bán: 23.65 | Giá vốn: 24.20 | Lãi/Lỗ: -2.28% (-103,058 đ)
#   > 🟢 MUA EIB: Tỷ trọng 7.1% -> 8.8% | Giá khớp: 21.45
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 2.1% -> 0.0% | Giá bán: 72.30 | Giá vốn: 73.67 | Lãi/Lỗ: -1.86% (-54,327 đ)
#   > 🟢 MUA GMD: Tỷ trọng 1.3% -> 2.2% | Giá khớp: 78.80
#   > 🟢 MUA HAG: Tỷ trọng 1.8% -> 3.1% | Giá khớp: 15.35
#   > 🟢 MUA HCM: Tỷ trọng 3.2% -> 3.7% | Giá khớp: 27.50
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 0.2% -> 0.0% | Giá bán: 12.05 | Giá vốn: 11.70 | Lãi/Lỗ: +2.98% (+7,458 đ)
#   > 🔥 CHỐT LỜI HT1: Tỷ trọng 3.6% -> 1.0% | Giá bán: 13.85 | Giá vốn: 13.74 | Lãi/Lỗ: +0.78% (+28,344 đ)
#   > 🟢 MUA KBC: Tỷ trọng 4.1% -> 4.6% | Giá khớp: 31.05
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 23.30
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 1.7% -> 0.0% | Giá bán: 25.20 | Giá vốn: 24.84 | Lãi/Lỗ: +1.42% (+33,104 đ)
#   > 🟢 MUA MSN: Tỷ trọng 8.1% -> 9.2% | Giá khớp: 72.50
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 4.7% -> 0.7% | Giá bán: 79.10 | Giá vốn: 76.65 | Lãi/Lỗ: +3.19% (+179,978 đ)
#   > 🔥 CHỐT LỜI NKG: Tỷ trọng 1.5% -> 0.0% | Giá bán: 12.55 | Giá vốn: 12.09 | Lãi/Lỗ: +3.79% (+80,053 đ)
#   > 🟢 MUA NLG: Tỷ trọng 0.2% -> 5.7% | Giá khớp: 27.65
#   > 🟢 MUA NT2: Tỷ trọng 1.7% -> 3.3% | Giá khớp: 22.95
#   > 🟢 MUA PDR: Tỷ trọng 8.1% -> 12.6% | Giá khớp: 15.15
#   > 🟢 MUA PHR: Tỷ trọng 2.7% -> 3.0% | Giá khớp: 64.90
#   > 🟢 MUA REE: Tỷ trọng 2.4% -> 3.1% | Giá khớp: 50.90
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 5.1% -> 0.0% | Giá bán: 21.75 | Giá vốn: 21.58 | Lãi/Lỗ: +0.76% (+54,708 đ)
#   > 🟢 MUA SSI: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 27.70
#   > 🟢 MUA VIC: Tỷ trọng 2.5% -> 5.4% | Giá khớp: 192.00
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 4.6% -> 0.6% | Giá bán: 59.00 | Giá vốn: 59.03 | Lãi/Lỗ: -0.07% (-3,761 đ)
#   > 🟢 MUA VSC: Tỷ trọng 3.3% -> 5.7% | Giá khớp: 20.25
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 7.5%, BMP: 3.0%, CTD: 2.3%, CTG: 7.2%, DCM: 2.2%, DGW: 2.0%, EIB: 8.8%, GMD: 2.2%, HAG: 3.1%, HCM: 3.7%, HT1: 1.0%, KBC: 4.6%, KDH: 1.6%, MSN: 9.2%, NLG: 5.7%, NT2: 3.3%, PDR: 12.6%, PHR: 3.0%, REE: 3.1%, SSI: 1.1%, VIC: 5.4%, VSC: 5.7%]
#   📈 Tài sản: +853,979 đ | Hiệu suất ngày: +0.61% | Tổng NAV: 141,304,273 đ
#
# 🏆 TỔNG LỢI NHUẬN TEST SET: +41.30%
# 🎯 Đã lưu log tự động cấu hình vào Leaderboard! Lợi nhuận: 41.30% | Model: v7_3/AI_Brain_v7_Seed321_Profit_41.30.zip

# %% [markdown]
# ## Kết quả

# %%
# Đoạn code đánh giá chuyên sâu (Evaluation & Metrics)
# Bạn hãy chạy (Run) cell này sau khi model đã train xong.

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# ---------------------------------------------
# Cài đặt Seaborn style để biểu đồ đẹp hơn
# ---------------------------------------------
sns.set_theme(style="whitegrid")

# Giả sử các biến từ hàm load_data() đã có trong bộ nhớ: 
# returns_df, ai_features_df, strategies_features_df, tickers, dates, weights_dim

try:
    total_days = len(returns_df)

    # Lấy 15% dữ liệu cuối cùng để backtest (giống fast_split)
    test_ratio = 0.15
    test_size = int(total_days * test_ratio)
    test_start = total_days - test_size

    returns_test = returns_df.iloc[test_start:]
    ai_test = ai_features_df.iloc[test_start:]
    strategies_test = strategies_features_df.iloc[test_start:]
    dates_test = dates[test_start:]

    from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
    from stable_baselines3 import PPO

    model_path = getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_3/AI_Brain_v7_3.zip')
    env_path = 'v7_3/vec_normalize.pkl'

    print(f"🔄 Đang nạp bộ não từ {model_path} để tiến hành phân tích...")
    model = PPO.load(model_path)
    
    test_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
            returns_test, ai_test, strategies_test, weights_dim, num_strategies_features, tickers=tickers, dates=dates_test, is_test=True
        )])
    test_env = VecNormalize.load(env_path, test_env)
    test_env.training = False
    test_env.norm_reward = False
    
    obs = test_env.reset()
    done = [False]
    
    portfolio_returns = []
    portfolio_dates = []
    benchmark_returns = [] # Benchmark: Lợi nhuận Equal Weight của danh mục
    action_history = []
    
    step_idx = 0
    while not done[0]:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = test_env.step(action)
        
        if 'net_return' in info[0]:
            portfolio_returns.append(info[0]['net_return'])
            portfolio_dates.append(pd.to_datetime(dates_test[step_idx], format='%d/%m/%Y'))
            
            # Tính benchmark (Equal Weight)
            bm_ret = np.mean(returns_test.iloc[step_idx].values)
            benchmark_returns.append(bm_ret)
            
            action_history.append(action[0])
            
        step_idx += 1
        
    perf_df = pd.DataFrame({
        'AI_Strategy': portfolio_returns,
        'Benchmark_EQ': benchmark_returns
    }, index=portfolio_dates)
    
    # ---------------------------------------------------------
    # 1. TÍNH TOÁN CÁC CHỈ SỐ RỦI RO VÀ HIỆU SUẤT (METRICS)
    # ---------------------------------------------------------
    def calc_metrics(returns):
        cum_ret = (1 + returns).cumprod()
        total_return = cum_ret.iloc[-1] - 1
        annualized_return = (1 + total_return)**(252 / len(returns)) - 1
        sharpe_ratio = np.sqrt(252) * (returns.mean() / returns.std()) if returns.std() != 0 else 0
        
        rolling_max = cum_ret.cummax()
        drawdowns = (cum_ret - rolling_max) / rolling_max
        max_drawdown = drawdowns.min()
        
        win_rate = (returns > 0).mean()
        return total_return, annualized_return, sharpe_ratio, max_drawdown, win_rate
        
    ai_tot, ai_ann, ai_sharpe, ai_mdd, ai_win = calc_metrics(perf_df['AI_Strategy'])
    bm_tot, bm_ann, bm_sharpe, bm_mdd, bm_win = calc_metrics(perf_df['Benchmark_EQ'])
    
    cov = np.cov(perf_df['AI_Strategy'], perf_df['Benchmark_EQ'])[0][1]
    var = np.var(perf_df['Benchmark_EQ'])
    beta = cov / var if var > 0 else 1
    alpha = ai_ann - (beta * bm_ann)
    
    print("\n=========================================================")
    print("📊 BÁO CÁO HIỆU SUẤT ĐẦU TƯ (BACKTEST)")
    print("=========================================================")
    print(f"{str('Chỉ số').ljust(20)} | {str('AI Strategy').ljust(15)} | {str('Benchmark (EQ)').ljust(15)}")
    print("-" * 55)
    print(f"{str('Tổng lợi nhuận').ljust(20)} | {ai_tot*100:>14.2f}% | {bm_tot*100:>14.2f}%")
    print(f"{str('Lợi nhuận năm').ljust(20)} | {ai_ann*100:>14.2f}% | {bm_ann*100:>14.2f}%")
    print(f"{str('Sharpe Ratio').ljust(20)} | {ai_sharpe:>14.2f}  | {bm_sharpe:>14.2f} ")
    print(f"{str('Max Drawdown').ljust(20)} | {ai_mdd*100:>14.2f}% | {bm_mdd*100:>14.2f}%")
    print(f"{str('Win Rate (Ngày)').ljust(20)} | {ai_win*100:>14.2f}% | {bm_win*100:>14.2f}%")
    print("-" * 55)
    print(f"Alpha (So với BM): {alpha*100:.2f}% (Lợi nhuận vượt trội sau khi trừ rủi ro thị trường)")
    print(f"Beta  (So với BM): {beta:.2f} (Độ nhạy cảm với biến động chung)")
    
    # ---------------------------------------------------------
    # 2. VẼ BIỂU ĐỒ EQUITY CURVE (LỢI NHUẬN TÍCH LŨY)
    # ---------------------------------------------------------
    fig, ax = plt.subplots(figsize=(12, 6))
    ((1 + perf_df).cumprod() - 1).plot(ax=ax, linewidth=2)
    plt.title("So sánh Lợi nhuận Tích lũy (Equity Curve): AI vs Benchmark", fontsize=14, fontweight='bold')
    plt.ylabel("Lợi nhuận (%)")
    plt.xlabel("Thời gian")
    
    import matplotlib.ticker as mtick
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.show()

    # ---------------------------------------------------------
    # 3. PHÂN TÍCH HÀNH VI (ALLOCATION HISTORY)
    # ---------------------------------------------------------
    action_df = pd.DataFrame(action_history, columns=tickers, index=portfolio_dates)
    action_df = action_df.loc[:, action_df.max() > 0.01]
    
    mean_alloc = action_df.mean().sort_values(ascending=False)
    print("\n=========================================================")
    print("🔍 PHÂN TÍCH HÀNH VI: AI YÊU THÍCH CỔ PHIẾU NÀO NHẤT?")
    print("=========================================================")
    print(mean_alloc.head(10).apply(lambda x: f"{x*100:.2f}%").to_string())
    
    action_df['CASH'] = 1.0 - action_df.sum(axis=1)
    action_df['CASH'] = action_df['CASH'].clip(lower=0)
    
    fig2, ax2 = plt.subplots(figsize=(14, 7))
    top_cols = list(mean_alloc.head(10).index) + ['CASH']
    action_df[top_cols].plot.area(ax=ax2, colormap='tab20', alpha=0.8, linewidth=0)
    plt.title("Biến động Phân bổ Tỷ trọng (Portfolio Allocation) theo thời gian", fontsize=14, fontweight='bold')
    plt.ylabel("Tỷ trọng (%)")
    plt.xlabel("Thời gian")
    plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    ax2.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.tight_layout()
    plt.show()
    
    # ---------------------------------------------------------
    # 4. KẾT LUẬN HÀNH VI: BÁN NON HAY GỒNG LÃI?
    # ---------------------------------------------------------
    cash_holdings = action_df['CASH'].mean()
    turnover_rate = action_df.drop(columns=['CASH']).diff().abs().sum(axis=1).mean()
    
    print("\n=========================================================")
    print("💡 ĐÁNH GIÁ PHONG CÁCH GIAO DỊCH CỦA AI")
    print("=========================================================")
    print(f"- Tỷ trọng Tiền mặt trung bình: {cash_holdings*100:.2f}% ")
    if cash_holdings > 0.5:
        print("  -> Phong cách: Rất an toàn (Phòng thủ). AI thường xuyên ôm tiền đứng ngoài.")
    elif cash_holdings < 0.1:
        print("  -> Phong cách: Tấn công (Aggressive). AI gần như lúc nào cũng full cổ phiếu.")
    else:
        print("  -> Phong cách: Cân bằng. Biết tiến biết lùi.")
        
    print(f"- Tốc độ xoay vòng vốn (Turnover/ngày): {turnover_rate*100:.2f}%")
    if turnover_rate > 0.3:
        print("  -> AI lướt sóng (T+) rất nhiều. Có xu hướng chốt non nhanh để bảo toàn rủi ro.")
    elif turnover_rate < 0.05:
        print("  -> AI có xu hướng Buy & Hold (Gồng lãi/lỗ) dài hạn, ít nhảy nhót.")
    else:
        print("  -> AI giao dịch ở mức độ vừa phải, luân chuyển dòng tiền hợp lý.")

except Exception as e:
    import traceback
    print(f"Không thể chạy đánh giá. Lỗi: {e}")
    traceback.print_exc()
# Out:
# 🔄 Đang nạp bộ não từ v7_3/AI_Brain_v7_3.zip để tiến hành phân tích...
#
# [07/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 0.0% -> 9.8% | Giá khớp: 39.96
#   > 🟢 MUA BMP: Tỷ trọng 0.0% -> 7.4% | Giá khớp: 117.53
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 61.66
#   > 🟢 MUA CTG: Tỷ trọng 0.0% -> 2.0% | Giá khớp: 25.70
#   > 🟢 MUA DIG: Tỷ trọng 0.0% -> 1.0% | Giá khớp: 15.66
#   > 🟢 MUA FPT: Tỷ trọng 0.0% -> 4.8% | Giá khớp: 126.38
#   > 🟢 MUA GAS: Tỷ trọng 0.0% -> 3.9% | Giá khớp: 63.11
#   > 🟢 MUA HCM: Tỷ trọng 0.0% -> 6.3% | Giá khớp: 21.36
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 9.9% | Giá khớp: 13.28
#   > 🟢 MUA HT1: Tỷ trọng 0.0% -> 2.5% | Giá khớp: 11.69
#   > 🟢 MUA KBC: Tỷ trọng 0.0% -> 5.4% | Giá khớp: 28.05
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 12.6% | Giá khớp: 16.24
#   > 🟢 MUA MSN: Tỷ trọng 0.0% -> 5.2% | Giá khớp: 66.80
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 5.9% | Giá khớp: 56.29
#   > 🟢 MUA NLG: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 29.69
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 2.4% | Giá khớp: 18.80
#   > 🟢 MUA PDR: Tỷ trọng 0.0% -> 1.3% | Giá khớp: 17.45
#   > 🟢 MUA PVD: Tỷ trọng 0.0% -> 2.6% | Giá khớp: 21.66
#   > 🟢 MUA PVT: Tỷ trọng 0.0% -> 5.6% | Giá khớp: 18.22
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 1.2% | Giá khớp: 47.52
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 5.0% | Giá khớp: 10.41
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 56.97
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.8%, BMP: 7.4%, CTD: 1.1%, CTG: 2.0%, DIG: 1.0%, FPT: 4.8%, GAS: 3.9%, HCM: 6.3%, HSG: 9.9%, HT1: 2.5%, KBC: 5.4%, MBB: 12.6%, MSN: 5.2%, MWG: 5.9%, NT2: 2.4%, PDR: 1.3%, PVD: 2.6%, PVT: 5.6%, REE: 1.2%, SBT: 5.0%, VNM: 3.2%]
#   📈 Tài sản: +625,648 đ | Hiệu suất ngày: +0.63% | Tổng NAV: 100,625,648 đ
#
# [08/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.8%, BMP: 7.4%, CTD: 1.1%, CTG: 2.0%, DIG: 1.0%, FPT: 4.8%, GAS: 3.9%, HCM: 6.3%, HSG: 9.9%, HT1: 2.5%, KBC: 5.4%, MBB: 12.6%, MSN: 5.2%, MWG: 5.9%, NT2: 2.4%, PDR: 1.3%, PVD: 2.6%, PVT: 5.6%, REE: 1.2%, SBT: 5.0%, VNM: 3.2%]
#   📈 Tài sản: +683,805 đ | Hiệu suất ngày: +0.68% | Tổng NAV: 101,309,454 đ
#
# [09/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.8%, BMP: 7.4%, CTD: 1.1%, CTG: 2.0%, DIG: 1.0%, FPT: 4.8%, GAS: 3.9%, HCM: 6.3%, HSG: 9.9%, HT1: 2.5%, KBC: 5.4%, MBB: 12.6%, MSN: 5.2%, MWG: 5.9%, NT2: 2.4%, PDR: 1.3%, PVD: 2.6%, PVT: 5.6%, REE: 1.2%, SBT: 5.0%, VNM: 3.2%]
#   📈 Tài sản: -566,761 đ | Hiệu suất ngày: -0.56% | Tổng NAV: 100,742,692 đ
#
# [10/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 9.8% -> 5.8% | Giá bán: 38.67 | Giá vốn: 39.96 | Lãi/Lỗ: -3.24% (-133,473 đ)
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 7.4% -> 5.8% | Giá bán: 113.26 | Giá vốn: 117.53 | Lãi/Lỗ: -3.64% (-57,705 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 1.1% -> 0.0% | Giá bán: 62.10 | Giá vốn: 61.66 | Lãi/Lỗ: +0.70% (+7,777 đ)
#   > 🔥 CHỐT LỜI CTG: Tỷ trọng 2.0% -> 1.3% | Giá bán: 25.73 | Giá vốn: 25.70 | Lãi/Lỗ: +0.11% (+738 đ)
#   > 🟢 MUA DCM: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 31.07
#   > 🟢 MUA DIG: Tỷ trọng 1.0% -> 2.3% | Giá khớp: 15.49
#   > 🟢 MUA DPM: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 18.55
#   > 🟢 MUA FPT: Tỷ trọng 4.8% -> 7.2% | Giá khớp: 124.02
#   > 🟢 MUA GAS: Tỷ trọng 3.9% -> 6.2% | Giá khớp: 62.83
#   > 🟢 MUA GMD: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 58.31
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 2.3% | Giá khớp: 11.65
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 6.3% -> 4.4% | Giá bán: 20.68 | Giá vốn: 21.36 | Lãi/Lỗ: -3.19% (-59,304 đ)
#   > 🟢 MUA HSG: Tỷ trọng 9.9% -> 11.6% | Giá khớp: 12.80
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 2.5% -> 0.4% | Giá bán: 11.69 | Giá vốn: 11.69 | Lãi/Lỗ: -0.01% (-212 đ)
#   > 🟢 MUA KBC: Tỷ trọng 5.4% -> 6.3% | Giá khớp: 28.30
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 12.6% -> 10.5% | Giá bán: 15.86 | Giá vốn: 16.24 | Lãi/Lỗ: -2.35% (-49,926 đ)
#   > 🩸 CẮT LỖ MSN: Tỷ trọng 5.2% -> 0.0% | Giá bán: 65.50 | Giá vốn: 66.80 | Lãi/Lỗ: -1.96% (-103,437 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 5.9% -> 0.0% | Giá bán: 56.68 | Giá vốn: 56.29 | Lãi/Lỗ: +0.68% (+40,699 đ)
#   > 🟢 MUA NLG: Tỷ trọng 0.9% -> 4.3% | Giá khớp: 28.54
#   > 🟢 MUA NT2: Tỷ trọng 2.4% -> 3.0% | Giá khớp: 19.40
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 1.3% -> 0.0% | Giá bán: 16.71 | Giá vốn: 17.45 | Lãi/Lỗ: -4.25% (-55,640 đ)
#   > 🟢 MUA PVD: Tỷ trọng 2.6% -> 3.4% | Giá khớp: 21.66
#   > 🟢 MUA PVT: Tỷ trọng 5.6% -> 7.8% | Giá khớp: 17.84
#   > 🟢 MUA REE: Tỷ trọng 1.2% -> 1.8% | Giá khớp: 47.15
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 5.0% -> 0.0% | Giá bán: 11.03 | Giá vốn: 10.41 | Lãi/Lỗ: +5.95% (+300,574 đ)
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 2.5% | Giá khớp: 32.80
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 11.10
#   > 🟢 MUA VIC: Tỷ trọng 0.0% -> 3.0% | Giá khớp: 20.25
#   > 🟢 MUA VNM: Tỷ trọng 3.2% -> 4.6% | Giá khớp: 56.60
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 5.8%, BMP: 5.8%, CTG: 1.3%, DIG: 2.3%, DPM: 3.2%, FPT: 7.2%, GAS: 6.2%, HAG: 2.3%, HCM: 4.4%, HSG: 11.6%, KBC: 6.3%, MBB: 10.5%, NLG: 4.3%, NT2: 3.0%, PVD: 3.4%, PVT: 7.8%, REE: 1.8%, SJS: 2.5%, VIC: 3.0%, VNM: 4.6%]
#   📈 Tài sản: -1,568,358 đ | Hiệu suất ngày: -1.56% | Tổng NAV: 99,174,334 đ
#
# [13/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 5.8% -> 7.9% | Giá khớp: 38.87
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 5.8% -> 5.4% | Giá bán: 111.52 | Giá vốn: 117.53 | Lãi/Lỗ: -5.12% (-23,552 đ)
#   > 🟢 MUA CTG: Tỷ trọng 1.3% -> 4.0% | Giá khớp: 25.87
#   > 🟢 MUA DCM: Tỷ trọng 0.7% -> 2.9% | Giá khớp: 31.64
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 2.3% -> 1.3% | Giá bán: 15.57 | Giá vốn: 15.56 | Lãi/Lỗ: +0.03% (+312 đ)
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 18.30
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 7.2% -> 4.5% | Giá bán: 124.28 | Giá vốn: 125.59 | Lãi/Lỗ: -1.05% (-27,810 đ)
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 6.2% -> 2.4% | Giá bán: 62.55 | Giá vốn: 63.00 | Lãi/Lỗ: -0.73% (-27,875 đ)
#   > 🟢 MUA GMD: Tỷ trọng 0.9% -> 1.8% | Giá khớp: 58.12
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 11.6% -> 2.1% | Giá bán: 12.98 | Giá vốn: 13.21 | Lãi/Lỗ: -1.75% (-165,493 đ)
#   > 🟢 MUA HT1: Tỷ trọng 0.4% -> 1.7% | Giá khớp: 11.83
#   > 🟢 MUA KBC: Tỷ trọng 6.3% -> 7.6% | Giá khớp: 28.25
#   > 🟢 MUA MSN: Tỷ trọng 0.0% -> 1.8% | Giá khớp: 65.00
#   > 🟢 MUA NLG: Tỷ trọng 4.3% -> 8.0% | Giá khớp: 28.76
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 3.0% -> 0.6% | Giá bán: 19.40 | Giá vốn: 18.91 | Lãi/Lỗ: +2.58% (+62,617 đ)
#   > 🟢 MUA PDR: Tỷ trọng 0.0% -> 7.0% | Giá khớp: 17.36
#   > 🟢 MUA PVD: Tỷ trọng 3.4% -> 3.7% | Giá khớp: 22.25
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 7.8% -> 3.9% | Giá bán: 17.91 | Giá vốn: 18.11 | Lãi/Lỗ: -1.11% (-44,007 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 1.8% -> 1.3% | Giá bán: 47.66 | Giá vốn: 47.39 | Lãi/Lỗ: +0.55% (+2,742 đ)
#   > 🟢 MUA VIC: Tỷ trọng 3.0% -> 4.0% | Giá khớp: 20.15
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 4.6% -> 1.4% | Giá bán: 56.69 | Giá vốn: 56.86 | Lãi/Lỗ: -0.30% (-9,587 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 7.9%, BMP: 5.4%, CTG: 4.0%, DCM: 2.9%, DIG: 1.3%, DPM: 3.2%, EIB: 3.2%, FPT: 4.5%, GAS: 2.4%, GMD: 1.8%, HAG: 2.3%, HCM: 4.5%, HSG: 2.1%, HT1: 1.7%, KBC: 7.6%, MBB: 10.6%, MSN: 1.8%, NLG: 8.0%, PDR: 7.0%, PVD: 3.7%, PVT: 3.9%, REE: 1.3%, SJS: 2.5%, VIC: 4.0%, VNM: 1.4%]
#   📈 Tài sản: +985,641 đ | Hiệu suất ngày: +0.99% | Tổng NAV: 100,159,975 đ
#
# [14/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 7.9% -> 8.0% | Giá khớp: 38.57
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 5.4% -> 3.9% | Giá bán: 108.04 | Giá vốn: 117.53 | Lãi/Lỗ: -8.08% (-120,144 đ)
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 63.45
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 4.0% -> 2.7% | Giá bán: 25.36 | Giá vốn: 25.82 | Lãi/Lỗ: -1.78% (-22,790 đ)
#   > 🟢 MUA EIB: Tỷ trọng 3.2% -> 3.4% | Giá khớp: 18.25
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 4.5% -> 2.4% | Giá bán: 122.17 | Giá vốn: 125.59 | Lãi/Lỗ: -2.73% (-58,026 đ)
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 4.5% -> 1.3% | Giá bán: 20.94 | Giá vốn: 21.36 | Lãi/Lỗ: -1.98% (-64,111 đ)
#   > 🟢 MUA HSG: Tỷ trọng 2.1% -> 2.9% | Giá khớp: 12.76
#   > 🟢 MUA KBC: Tỷ trọng 7.6% -> 9.1% | Giá khớp: 28.95
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 31.02
#   > 🟢 MUA MBB: Tỷ trọng 10.6% -> 13.0% | Giá khớp: 15.98
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 56.39
#   > 🟢 MUA NKG: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 12.04
#   > 🟢 MUA NLG: Tỷ trọng 8.0% -> 9.4% | Giá khớp: 28.67
#   > 🟢 MUA NT2: Tỷ trọng 0.6% -> 1.4% | Giá khớp: 19.40
#   > 🟢 MUA PDR: Tỷ trọng 7.0% -> 9.2% | Giá khớp: 17.03
#   > 🟢 MUA PHR: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 49.24
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 3.7% -> 1.1% | Giá bán: 21.91 | Giá vốn: 21.71 | Lãi/Lỗ: +0.90% (+23,259 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 3.9% -> 2.3% | Giá bán: 17.91 | Giá vốn: 18.11 | Lãi/Lỗ: -1.11% (-17,644 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 1.3% -> 0.7% | Giá bán: 47.96 | Giá vốn: 47.39 | Lãi/Lỗ: +1.18% (+7,010 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 8.0%, BMP: 3.9%, CTG: 2.7%, DCM: 2.9%, DIG: 1.3%, DPM: 3.2%, EIB: 3.4%, FPT: 2.4%, GAS: 2.4%, GMD: 1.8%, HAG: 2.3%, HCM: 1.3%, HSG: 2.9%, HT1: 1.7%, KBC: 9.1%, KDH: 1.1%, MBB: 13.0%, MSN: 1.8%, MWG: 1.4%, NLG: 9.4%, NT2: 1.4%, PDR: 9.2%, PVD: 1.1%, PVT: 2.3%, SJS: 2.5%, VIC: 4.0%, VNM: 1.4%]
#   📈 Tài sản: -485,891 đ | Hiệu suất ngày: -0.49% | Tổng NAV: 99,674,084 đ
#
# [15/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 8.0% -> 7.8% | Giá bán: 38.77 | Giá vốn: 39.65 | Lãi/Lỗ: -2.22% (-4,136 đ)
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 3.9% -> 0.4% | Giá bán: 108.56 | Giá vốn: 117.53 | Lãi/Lỗ: -7.64% (-265,337 đ)
#   > 🟢 MUA CTG: Tỷ trọng 2.7% -> 2.9% | Giá khớp: 25.22
#   > 🔥 CHỐT LỜI DCM: Tỷ trọng 2.9% -> 2.2% | Giá bán: 31.74 | Giá vốn: 31.50 | Lãi/Lỗ: +0.75% (+5,444 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.3% -> 0.0% | Giá bán: 15.79 | Giá vốn: 15.56 | Lãi/Lỗ: +1.44% (+19,149 đ)
#   > 🟢 MUA FPT: Tỷ trọng 2.4% -> 5.5% | Giá khớp: 122.51
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 2.4% -> 0.0% | Giá bán: 62.92 | Giá vốn: 63.00 | Lãi/Lỗ: -0.14% (-3,367 đ)
#   > 🩸 CẮT LỖ GMD: Tỷ trọng 1.8% -> 0.9% | Giá bán: 56.62 | Giá vốn: 58.22 | Lãi/Lỗ: -2.76% (-25,401 đ)
#   > 🩸 CẮT LỖ HAG: Tỷ trọng 2.3% -> 0.0% | Giá bán: 11.65 | Giá vốn: 11.65 | Lãi/Lỗ: -0.01% (-226 đ)
#   > 🟢 MUA HCM: Tỷ trọng 1.3% -> 2.2% | Giá khớp: 21.21
#   > 🟢 MUA HSG: Tỷ trọng 2.9% -> 9.1% | Giá khớp: 13.10
#   > 🟢 MUA HT1: Tỷ trọng 1.7% -> 3.6% | Giá khớp: 12.53
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 9.1% -> 8.3% | Giá bán: 29.90 | Giá vốn: 28.25 | Lãi/Lỗ: +5.83% (+49,467 đ)
#   > 🟢 MUA MBB: Tỷ trọng 13.0% -> 18.0% | Giá khớp: 16.01
#   > 🟢 MUA NKG: Tỷ trọng 0.2% -> 0.5% | Giá khớp: 12.64
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 9.4% -> 5.8% | Giá bán: 28.58 | Giá vốn: 28.75 | Lãi/Lỗ: -0.60% (-21,706 đ)
#   > 🟢 MUA PVT: Tỷ trọng 2.3% -> 4.4% | Giá khớp: 18.29
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 0.7% -> 0.0% | Giá bán: 47.59 | Giá vốn: 47.39 | Lãi/Lỗ: +0.40% (+2,760 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 2.5% -> 0.0% | Giá bán: 36.70 | Giá vốn: 32.80 | Lãi/Lỗ: +11.88% (+299,334 đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 0.5% -> 0.0% | Giá bán: 11.43 | Giá vốn: 11.10 | Lãi/Lỗ: +2.96% (+13,957 đ)
#   > 🟢 MUA VIC: Tỷ trọng 4.0% -> 4.2% | Giá khớp: 20.12
#   > 🔥 CHỐT LỜI VNM: Tỷ trọng 1.4% -> 0.9% | Giá bán: 56.97 | Giá vốn: 56.86 | Lãi/Lỗ: +0.19% (+1,045 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 7.8%, CTG: 2.9%, DCM: 2.2%, DPM: 3.1%, EIB: 3.4%, FPT: 5.5%, HCM: 2.2%, HSG: 9.1%, HT1: 3.6%, KBC: 8.3%, KDH: 1.1%, MBB: 18.0%, MSN: 1.8%, MWG: 1.4%, NLG: 5.8%, NT2: 1.4%, PDR: 9.2%, PVD: 1.2%, PVT: 4.4%, VIC: 4.2%]
#   📈 Tài sản: +1,236,951 đ | Hiệu suất ngày: +1.24% | Tổng NAV: 100,911,035 đ
#
# [16/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 7.8% -> 8.2% | Giá khớp: 38.97
#   > 🟢 MUA BMP: Tỷ trọng 0.4% -> 3.1% | Giá khớp: 110.47
#   > 🟢 MUA CTG: Tỷ trọng 2.9% -> 3.2% | Giá khớp: 25.25
#   > 🔥 CHỐT LỜI DCM: Tỷ trọng 2.2% -> 0.0% | Giá bán: 31.64 | Giá vốn: 31.50 | Lãi/Lỗ: +0.44% (+9,724 đ)
#   > 🟢 MUA EIB: Tỷ trọng 3.4% -> 4.8% | Giá khớp: 18.30
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 5.5% -> 3.1% | Giá bán: 123.35 | Giá vốn: 123.86 | Lãi/Lỗ: -0.42% (-10,297 đ)
#   > 🟢 MUA GMD: Tỷ trọng 0.9% -> 3.2% | Giá khớp: 57.56
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 0.8% | Giá khớp: 11.75
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 2.2% -> 1.9% | Giá bán: 21.48 | Giá vốn: 21.30 | Lãi/Lỗ: +0.86% (+3,020 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 9.1% -> 7.0% | Giá bán: 12.91 | Giá vốn: 13.09 | Lãi/Lỗ: -1.42% (-30,070 đ)
#   > 🔥 CHỐT LỜI HT1: Tỷ trọng 3.6% -> 2.0% | Giá bán: 12.53 | Giá vốn: 12.19 | Lãi/Lỗ: +2.79% (+46,892 đ)
#   > 🟢 MUA KBC: Tỷ trọng 8.3% -> 9.5% | Giá khớp: 29.90
#   > 🟢 MUA KDH: Tỷ trọng 1.1% -> 2.1% | Giá khớp: 31.20
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 18.0% -> 13.5% | Giá bán: 16.05 | Giá vốn: 16.14 | Lãi/Lỗ: -0.58% (-25,986 đ)
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 1.8% -> 0.0% | Giá bán: 66.30 | Giá vốn: 65.00 | Lãi/Lỗ: +1.99% (+36,488 đ)
#   > 🟢 MUA NLG: Tỷ trọng 5.8% -> 8.2% | Giá khớp: 29.02
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.4% -> 1.2% | Giá bán: 19.31 | Giá vốn: 19.20 | Lãi/Lỗ: +0.55% (+1,587 đ)
#   > 🟢 MUA PDR: Tỷ trọng 9.2% -> 10.5% | Giá khớp: 17.22
#   > 🟢 MUA PVD: Tỷ trọng 1.2% -> 1.6% | Giá khớp: 22.05
#   > 🔥 CHỐT LỜI PVT: Tỷ trọng 4.4% -> 2.2% | Giá bán: 18.22 | Giá vốn: 18.20 | Lãi/Lỗ: +0.11% (+2,518 đ)
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 1.3% | Giá khớp: 48.10
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 0.8% | Giá khớp: 35.12
#   > 🟢 MUA VIC: Tỷ trọng 4.2% -> 4.5% | Giá khớp: 20.23
#   > 🟢 MUA VNM: Tỷ trọng 0.9% -> 1.6% | Giá khớp: 57.15
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 8.2%, BMP: 3.1%, CTG: 3.2%, DPM: 3.2%, EIB: 4.8%, FPT: 3.1%, GMD: 3.2%, HCM: 1.9%, HSG: 7.0%, HT1: 2.0%, KBC: 9.5%, KDH: 2.1%, MBB: 13.5%, MWG: 1.4%, NLG: 8.2%, NT2: 1.2%, PDR: 10.5%, PVD: 1.6%, PVT: 2.2%, REE: 1.3%, VIC: 4.5%, VNM: 1.6%]
#   📈 Tài sản: +204,526 đ | Hiệu suất ngày: +0.20% | Tổng NAV: 101,115,561 đ
#
# [17/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 8.2% -> 5.9% | Giá bán: 39.07 | Giá vốn: 39.61 | Lãi/Lỗ: -1.38% (-32,573 đ)
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 3.1% -> 2.7% | Giá bán: 111.00 | Giá vốn: 111.39 | Lãi/Lỗ: -0.36% (-1,491 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 0.2% -> 0.0% | Giá bán: 66.32 | Giá vốn: 63.45 | Lãi/Lỗ: +4.51% (+5,185 đ)
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 3.2% -> 0.5% | Giá bán: 25.53 | Giá vốn: 25.73 | Lãi/Lỗ: -0.77% (-21,431 đ)
#   > 🟢 MUA DPM: Tỷ trọng 3.2% -> 4.8% | Giá khớp: 18.99
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 4.8% -> 1.3% | Giá bán: 18.30 | Giá vốn: 18.30 | Lãi/Lỗ: +0.00% (+53 đ)
#   > 🟢 MUA FPT: Tỷ trọng 3.1% -> 6.4% | Giá khớp: 125.46
#   > 🟢 MUA GAS: Tỷ trọng 0.0% -> 4.4% | Giá khớp: 62.92
#   > 🔥 CHỐT LỜI GMD: Tỷ trọng 3.2% -> 2.3% | Giá bán: 58.31 | Giá vốn: 57.74 | Lãi/Lỗ: +0.98% (+8,458 đ)
#   > 🟢 MUA HAG: Tỷ trọng 0.8% -> 1.1% | Giá khớp: 11.80
#   > 🟢 MUA HCM: Tỷ trọng 1.9% -> 4.0% | Giá khớp: 21.66
#   > 🟢 MUA HSG: Tỷ trọng 7.0% -> 15.3% | Giá khớp: 13.06
#   > 🟢 MUA HT1: Tỷ trọng 2.0% -> 4.5% | Giá khớp: 12.53
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 9.5% -> 5.5% | Giá bán: 29.85 | Giá vốn: 28.46 | Lãi/Lỗ: +4.88% (+195,894 đ)
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 2.1% -> 1.0% | Giá bán: 31.25 | Giá vốn: 31.10 | Lãi/Lỗ: +0.46% (+5,101 đ)
#   > 🟢 MUA MBB: Tỷ trọng 13.5% -> 16.9% | Giá khớp: 16.12
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 1.4% -> 0.0% | Giá bán: 56.88 | Giá vốn: 56.39 | Lãi/Lỗ: +0.86% (+12,053 đ)
#   > 🟢 MUA NKG: Tỷ trọng 0.5% -> 4.4% | Giá khớp: 12.68
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 8.2% -> 2.4% | Giá bán: 29.38 | Giá vốn: 28.83 | Lãi/Lỗ: +1.90% (+110,940 đ)
#   > 🩸 CẮT LỖ NT2: Tỷ trọng 1.2% -> 0.1% | Giá bán: 19.16 | Giá vốn: 19.20 | Lãi/Lỗ: -0.23% (-2,528 đ)
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 10.5% -> 1.3% | Giá bán: 17.45 | Giá vốn: 17.27 | Lãi/Lỗ: +1.01% (+93,310 đ)
#   > 🔥 CHỐT LỜI PHR: Tỷ trọng 0.5% -> 0.0% | Giá bán: 50.12 | Giá vốn: 49.24 | Lãi/Lỗ: +1.78% (+8,268 đ)
#   > 🟢 MUA PVT: Tỷ trọng 2.2% -> 6.6% | Giá khớp: 18.43
#   > 🟢 MUA REE: Tỷ trọng 1.3% -> 1.6% | Giá khớp: 48.91
#   > 🟢 MUA SJS: Tỷ trọng 0.8% -> 2.7% | Giá khớp: 33.11
#   > 🔥 CHỐT LỜI VIC: Tỷ trọng 4.5% -> 0.5% | Giá bán: 20.23 | Giá vốn: 20.22 | Lãi/Lỗ: +0.03% (+1,270 đ)
#   > 🟢 MUA VNM: Tỷ trọng 1.6% -> 2.0% | Giá khớp: 57.24
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 5.9%, BMP: 2.7%, DPM: 4.8%, EIB: 1.3%, FPT: 6.4%, GAS: 4.4%, GMD: 2.3%, HAG: 1.1%, HCM: 4.0%, HSG: 15.3%, HT1: 4.5%, KBC: 5.5%, MBB: 16.9%, NKG: 4.4%, NLG: 2.4%, PDR: 1.3%, PVD: 1.7%, PVT: 6.6%, REE: 1.6%, SJS: 2.7%, VNM: 2.0%]
#   📈 Tài sản: +546,588 đ | Hiệu suất ngày: +0.54% | Tổng NAV: 101,662,149 đ
#
# [20/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 5.9% -> 8.7% | Giá khớp: 39.46
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 65.60
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 0.5% -> 0.4% | Giá bán: 25.60 | Giá vốn: 25.73 | Lãi/Lỗ: -0.50% (-702 đ)
#   > 🔥 CHỐT LỜI DPM: Tỷ trọng 4.8% -> 1.7% | Giá bán: 18.99 | Giá vốn: 18.70 | Lãi/Lỗ: +1.54% (+49,003 đ)
#   > 🔥 CHỐT LỜI FPT: Tỷ trọng 6.4% -> 4.8% | Giá bán: 126.30 | Giá vốn: 124.69 | Lãi/Lỗ: +1.28% (+20,976 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 4.0% -> 3.1% | Giá bán: 21.59 | Giá vốn: 21.49 | Lãi/Lỗ: +0.46% (+3,940 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 15.3% -> 10.2% | Giá bán: 13.10 | Giá vốn: 13.08 | Lãi/Lỗ: +0.17% (+9,025 đ)
#   > 🔥 CHỐT LỜI HT1: Tỷ trọng 4.5% -> 2.5% | Giá bán: 12.63 | Giá vốn: 12.38 | Lãi/Lỗ: +2.02% (+40,796 đ)
#   > 🟢 MUA KBC: Tỷ trọng 5.5% -> 8.3% | Giá khớp: 29.55
#   > 🟢 MUA MBB: Tỷ trọng 16.9% -> 18.0% | Giá khớp: 16.39
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 0.4% | Giá khớp: 56.68
#   > 🩸 CẮT LỖ NKG: Tỷ trọng 4.4% -> 3.9% | Giá bán: 12.46 | Giá vốn: 12.64 | Lãi/Lỗ: -1.46% (-8,065 đ)
#   > 🟢 MUA NLG: Tỷ trọng 2.4% -> 4.7% | Giá khớp: 29.20
#   > 🟢 MUA NT2: Tỷ trọng 0.1% -> 3.2% | Giá khớp: 19.31
#   > 🟢 MUA PDR: Tỷ trọng 1.3% -> 2.8% | Giá khớp: 17.40
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 1.7% -> 0.6% | Giá bán: 22.93 | Giá vốn: 21.81 | Lãi/Lỗ: +5.12% (+60,043 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 6.6% -> 4.5% | Giá bán: 18.29 | Giá vốn: 18.35 | Lãi/Lỗ: -0.36% (-7,938 đ)
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 11.22
#   > 🟢 MUA SJS: Tỷ trọng 2.7% -> 4.4% | Giá khớp: 31.33
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 0.5% -> 0.4% | Giá bán: 20.20 | Giá vốn: 20.22 | Lãi/Lỗ: -0.12% (-195 đ)
#   > 🔥 CHỐT LỜI VNM: Tỷ trọng 2.0% -> 1.3% | Giá bán: 57.15 | Giá vốn: 57.04 | Lãi/Lỗ: +0.19% (+1,272 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 8.7%, BMP: 2.7%, CTD: 1.4%, DPM: 1.7%, EIB: 1.3%, FPT: 4.8%, GAS: 4.4%, GMD: 2.3%, HAG: 1.1%, HCM: 3.1%, HSG: 10.2%, HT1: 2.5%, KBC: 8.3%, MBB: 18.0%, NKG: 3.9%, NLG: 4.7%, NT2: 3.2%, PDR: 2.8%, PVT: 4.5%, REE: 1.6%, SJS: 4.4%, VNM: 1.3%]
#   📈 Tài sản: +43,801 đ | Hiệu suất ngày: +0.04% | Tổng NAV: 101,705,949 đ
#
# [21/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 8.7% -> 8.1% | Giá bán: 39.36 | Giá vốn: 39.56 | Lãi/Lỗ: -0.52% (-3,504 đ)
#   > 🟢 MUA BMP: Tỷ trọng 2.7% -> 3.2% | Giá khớp: 109.69
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 0.4% -> 0.0% | Giá bán: 25.60 | Giá vốn: 25.73 | Lãi/Lỗ: -0.50% (-1,868 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.0% -> 1.8% | Giá khớp: 16.05
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 1.3% -> 0.0% | Giá bán: 18.15 | Giá vốn: 18.30 | Lãi/Lỗ: -0.82% (-11,191 đ)
#   > 🔥 CHỐT LỜI FPT: Tỷ trọng 4.8% -> 3.3% | Giá bán: 126.21 | Giá vốn: 124.69 | Lãi/Lỗ: +1.21% (+18,460 đ)
#   > 🔥 CHỐT LỜI GMD: Tỷ trọng 2.3% -> 0.0% | Giá bán: 58.31 | Giá vốn: 57.74 | Lãi/Lỗ: +0.98% (+23,297 đ)
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 1.1% -> 0.3% | Giá bán: 11.95 | Giá vốn: 11.76 | Lãi/Lỗ: +1.58% (+12,883 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 3.1% -> 2.1% | Giá bán: 21.82 | Giá vốn: 21.49 | Lãi/Lỗ: +1.53% (+15,984 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 10.2% -> 8.3% | Giá bán: 12.95 | Giá vốn: 13.08 | Lãi/Lỗ: -0.97% (-18,464 đ)
#   > 🟢 MUA HT1: Tỷ trọng 2.5% -> 4.1% | Giá khớp: 12.53
#   > 🟢 MUA KBC: Tỷ trọng 8.3% -> 10.4% | Giá khớp: 29.35
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 1.0% -> 0.0% | Giá bán: 31.25 | Giá vốn: 31.10 | Lãi/Lỗ: +0.46% (+4,530 đ)
#   > 🟢 MUA MSN: Tỷ trọng 0.0% -> 1.9% | Giá khớp: 65.70
#   > 🟢 MUA NLG: Tỷ trọng 4.7% -> 5.7% | Giá khớp: 29.16
#   > 🟢 MUA NT2: Tỷ trọng 3.2% -> 3.4% | Giá khớp: 18.87
#   > 🟢 MUA PDR: Tỷ trọng 2.8% -> 4.8% | Giá khớp: 17.03
#   > 🟢 MUA PVD: Tỷ trọng 0.6% -> 1.6% | Giá khớp: 22.98
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 1.6% -> 0.3% | Giá bán: 48.40 | Giá vốn: 48.26 | Lãi/Lỗ: +0.28% (+3,708 đ)
#   > 🟢 MUA SJS: Tỷ trọng 4.4% -> 5.8% | Giá khớp: 31.49
#   > 🔥 CHỐT LỜI VIC: Tỷ trọng 0.4% -> 0.0% | Giá bán: 20.23 | Giá vốn: 20.22 | Lãi/Lỗ: +0.03% (+114 đ)
#   > 🔥 CHỐT LỜI VNM: Tỷ trọng 1.3% -> 0.4% | Giá bán: 57.06 | Giá vốn: 57.04 | Lãi/Lỗ: +0.03% (+281 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 8.1%, BMP: 3.2%, CTD: 1.3%, DIG: 1.8%, DPM: 1.6%, FPT: 3.3%, GAS: 4.4%, HCM: 2.1%, HSG: 8.3%, HT1: 4.1%, KBC: 10.4%, MBB: 18.0%, MSN: 1.9%, NKG: 3.9%, NLG: 5.7%, NT2: 3.4%, PDR: 4.8%, PVD: 1.6%, PVT: 4.5%, SJS: 5.8%]
#   📈 Tài sản: -482,787 đ | Hiệu suất ngày: -0.47% | Tổng NAV: 101,223,162 đ
#
# [22/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 8.1% -> 9.9% | Giá khớp: 39.07
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 3.2% -> 1.8% | Giá bán: 109.08 | Giá vốn: 111.13 | Lãi/Lỗ: -1.85% (-25,642 đ)
#   > 🟢 MUA DIG: Tỷ trọng 1.8% -> 4.2% | Giá khớp: 15.88
#   > 🩸 CẮT LỖ DPM: Tỷ trọng 1.6% -> 0.0% | Giá bán: 18.55 | Giá vốn: 18.70 | Lãi/Lỗ: -0.81% (-13,385 đ)
#   > 🔥 CHỐT LỜI FPT: Tỷ trọng 3.3% -> 2.0% | Giá bán: 126.04 | Giá vốn: 124.69 | Lãi/Lỗ: +1.07% (+14,917 đ)
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 4.4% -> 1.0% | Giá bán: 62.92 | Giá vốn: 62.92 | Lãi/Lỗ: -0.01% (-336 đ)
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 0.3% -> 0.0% | Giá bán: 12.10 | Giá vốn: 11.76 | Lãi/Lỗ: +2.86% (+7,879 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 8.3% -> 7.0% | Giá bán: 12.76 | Giá vốn: 13.08 | Lãi/Lỗ: -2.43% (-32,925 đ)
#   > 🟢 MUA HT1: Tỷ trọng 4.1% -> 4.8% | Giá khớp: 12.28
#   > 🟢 MUA KBC: Tỷ trọng 10.4% -> 11.0% | Giá khớp: 28.95
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 18.0% -> 15.3% | Giá bán: 16.35 | Giá vốn: 16.15 | Lãi/Lỗ: +1.21% (+33,222 đ)
#   > 🟢 MUA MSN: Tỷ trọng 1.9% -> 3.7% | Giá khớp: 65.20
#   > 🩸 CẮT LỖ NKG: Tỷ trọng 3.9% -> 3.5% | Giá bán: 12.09 | Giá vốn: 12.64 | Lãi/Lỗ: -4.38% (-15,856 đ)
#   > 🟢 MUA NLG: Tỷ trọng 5.7% -> 7.3% | Giá khớp: 29.74
#   > 🟢 MUA NT2: Tỷ trọng 3.4% -> 4.5% | Giá khớp: 18.82
#   > 🟢 MUA PDR: Tỷ trọng 4.8% -> 5.8% | Giá khớp: 16.99
#   > 🟢 MUA PVD: Tỷ trọng 1.6% -> 5.3% | Giá khớp: 22.64
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 4.5% -> 2.2% | Giá bán: 18.02 | Giá vốn: 18.35 | Lãi/Lỗ: -1.83% (-41,796 đ)
#   > 🟢 MUA REE: Tỷ trọng 0.3% -> 2.6% | Giá khớp: 47.96
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 5.8% -> 3.6% | Giá bán: 33.11 | Giá vốn: 32.49 | Lãi/Lỗ: +1.90% (+41,091 đ)
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 0.4% -> 0.0% | Giá bán: 56.87 | Giá vốn: 57.04 | Lãi/Lỗ: -0.30% (-1,117 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.9%, BMP: 1.8%, CTD: 1.3%, DIG: 4.2%, FPT: 2.0%, GAS: 1.0%, HCM: 2.1%, HSG: 7.0%, HT1: 4.8%, KBC: 11.0%, MBB: 15.3%, MSN: 3.7%, NKG: 3.5%, NLG: 7.3%, NT2: 4.5%, PDR: 5.8%, PVD: 5.3%, PVT: 2.2%, REE: 2.6%, SJS: 3.6%]
#   📈 Tài sản: -412,844 đ | Hiệu suất ngày: -0.41% | Tổng NAV: 100,810,318 đ
#
# [23/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 9.9% -> 9.4% | Giá bán: 39.46 | Giá vốn: 39.47 | Lãi/Lỗ: -0.04% (-191 đ)
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 1.8% -> 0.5% | Giá bán: 109.43 | Giá vốn: 111.13 | Lãi/Lỗ: -1.54% (-20,589 đ)
#   > 🟢 MUA CTD: Tỷ trọng 1.3% -> 1.5% | Giá khớp: 65.60
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 18.35
#   > 🔥 CHỐT LỜI FPT: Tỷ trọng 2.0% -> 0.0% | Giá bán: 129.92 | Giá vốn: 124.69 | Lãi/Lỗ: +4.19% (+82,972 đ)
#   > 🔥 CHỐT LỜI GAS: Tỷ trọng 1.0% -> 0.0% | Giá bán: 63.11 | Giá vốn: 62.92 | Lãi/Lỗ: +0.29% (+3,057 đ)
#   > 🟢 MUA HCM: Tỷ trọng 2.1% -> 6.7% | Giá khớp: 22.27
#   > 🟢 MUA HPG: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 19.81
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 7.0% -> 3.3% | Giá bán: 12.98 | Giá vốn: 13.08 | Lãi/Lỗ: -0.74% (-27,503 đ)
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 4.8% -> 3.9% | Giá bán: 12.33 | Giá vốn: 12.41 | Lãi/Lỗ: -0.68% (-6,159 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 11.0% -> 8.7% | Giá bán: 29.40 | Giá vốn: 28.93 | Lãi/Lỗ: +1.60% (+37,890 đ)
#   > 🟢 MUA MBB: Tỷ trọng 15.3% -> 17.1% | Giá khớp: 16.65
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 0.4% -> 0.0% | Giá bán: 58.36 | Giá vốn: 56.68 | Lãi/Lỗ: +2.95% (+10,443 đ)
#   > 🩸 CẮT LỖ NKG: Tỷ trọng 3.5% -> 0.5% | Giá bán: 12.27 | Giá vốn: 12.64 | Lãi/Lỗ: -2.96% (-91,285 đ)
#   > 🟢 MUA NLG: Tỷ trọng 7.3% -> 11.8% | Giá khớp: 30.36
#   > 🩸 CẮT LỖ NT2: Tỷ trọng 4.5% -> 3.0% | Giá bán: 19.02 | Giá vốn: 19.17 | Lãi/Lỗ: -0.77% (-11,653 đ)
#   > 🟢 MUA PDR: Tỷ trọng 5.8% -> 10.0% | Giá khớp: 17.22
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 5.3% -> 4.8% | Giá bán: 23.03 | Giá vốn: 22.62 | Lãi/Lỗ: +1.80% (+10,192 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 2.2% -> 0.0% | Giá bán: 18.19 | Giá vốn: 18.35 | Lãi/Lỗ: -0.90% (-20,056 đ)
#   > 🟢 MUA REE: Tỷ trọng 2.6% -> 2.8% | Giá khớp: 48.32
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 0.5% -> 0.0% | Giá bán: 11.55 | Giá vốn: 11.22 | Lãi/Lỗ: +2.93% (+15,129 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 3.6% -> 1.3% | Giá bán: 34.15 | Giá vốn: 32.49 | Lãi/Lỗ: +5.10% (+118,503 đ)
#   > 🟢 MUA VIC: Tỷ trọng 0.0% -> 3.4% | Giá khớp: 20.20
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.4%, CTD: 1.5%, DIG: 4.2%, EIB: 3.2%, HCM: 6.7%, HSG: 3.3%, HT1: 3.9%, KBC: 8.7%, MBB: 17.1%, MSN: 3.7%, NLG: 11.8%, NT2: 3.0%, PDR: 10.0%, PVD: 4.8%, REE: 2.8%, SJS: 1.3%, VIC: 3.4%]
#   📈 Tài sản: +1,381,933 đ | Hiệu suất ngày: +1.37% | Tổng NAV: 102,192,251 đ
#
# [24/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 9.4% -> 9.9% | Giá khớp: 39.56
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 0.5% -> 0.0% | Giá bán: 110.47 | Giá vốn: 111.13 | Lãi/Lỗ: -0.60% (-3,049 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 1.5% -> 0.2% | Giá bán: 65.69 | Giá vốn: 65.60 | Lãi/Lỗ: +0.13% (+1,727 đ)
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 4.2% -> 2.4% | Giá bán: 15.32 | Giá vốn: 15.95 | Lãi/Lỗ: -3.98% (-72,843 đ)
#   > 🟢 MUA DPM: Tỷ trọng 0.0% -> 1.0% | Giá khớp: 19.16
#   > 🟢 MUA FPT: Tỷ trọng 0.0% -> 4.3% | Giá khớp: 129.16
#   > 🟢 MUA GAS: Tỷ trọng 0.0% -> 3.4% | Giá khớp: 63.96
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 6.7% -> 5.7% | Giá bán: 22.24 | Giá vốn: 22.02 | Lãi/Lỗ: +0.99% (+9,418 đ)
#   > 🟢 MUA HPG: Tỷ trọng 0.2% -> 1.4% | Giá khớp: 19.73
#   > 🟢 MUA HSG: Tỷ trọng 3.3% -> 8.6% | Giá khớp: 13.02
#   > 🔥 CHỐT LỜI HT1: Tỷ trọng 3.9% -> 3.4% | Giá bán: 12.43 | Giá vốn: 12.41 | Lãi/Lỗ: +0.12% (+680 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 8.7% -> 3.8% | Giá bán: 29.00 | Giá vốn: 28.93 | Lãi/Lỗ: +0.22% (+10,857 đ)
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 17.1% -> 15.2% | Giá bán: 16.80 | Giá vốn: 16.21 | Lãi/Lỗ: +3.66% (+71,364 đ)
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 3.7% -> 1.8% | Giá bán: 68.00 | Giá vốn: 65.45 | Lãi/Lỗ: +3.88% (+73,809 đ)
#   > 🟢 MUA NKG: Tỷ trọng 0.5% -> 2.0% | Giá khớp: 12.09
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 11.8% -> 6.1% | Giá bán: 32.35 | Giá vốn: 29.63 | Lãi/Lỗ: +9.16% (+535,317 đ)
#   > 🩸 CẮT LỖ NT2: Tỷ trọng 3.0% -> 1.1% | Giá bán: 18.97 | Giá vốn: 19.17 | Lãi/Lỗ: -1.04% (-20,143 đ)
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 10.0% -> 5.2% | Giá bán: 17.68 | Giá vốn: 17.19 | Lãi/Lỗ: +2.83% (+137,526 đ)
#   > 🟢 MUA PVD: Tỷ trọng 4.8% -> 6.7% | Giá khớp: 23.08
#   > 🟢 MUA PVT: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 18.02
#   > 🟢 MUA REE: Tỷ trọng 2.8% -> 4.6% | Giá khớp: 47.66
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 4.7% | Giá khớp: 11.60
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 1.3% -> 0.0% | Giá bán: 33.61 | Giá vốn: 32.49 | Lãi/Lỗ: +3.44% (+47,228 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 57.43
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.9%, DIG: 2.4%, DPM: 1.0%, EIB: 3.2%, FPT: 4.3%, GAS: 3.4%, HCM: 5.7%, HPG: 1.4%, HSG: 8.6%, HT1: 3.4%, KBC: 3.8%, MBB: 15.2%, MSN: 1.8%, NKG: 2.0%, NLG: 6.1%, NT2: 1.1%, PDR: 5.2%, PVD: 6.7%, REE: 4.6%, SBT: 4.7%, VIC: 3.4%, VNM: 1.1%]
#   📈 Tài sản: +699,997 đ | Hiệu suất ngày: +0.68% | Tổng NAV: 102,892,248 đ
#
# [03/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 9.9% -> 10.8% | Giá khớp: 38.97
#   > 🟢 MUA BMP: Tỷ trọng 0.0% -> 3.0% | Giá khớp: 107.16
#   > 🟢 MUA CTD: Tỷ trọng 0.2% -> 1.7% | Giá khớp: 64.34
#   > 🟢 MUA DGW: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 36.68
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 2.4% -> 1.6% | Giá bán: 15.10 | Giá vốn: 15.95 | Lãi/Lỗ: -5.36% (-45,134 đ)
#   > 🟢 MUA DPM: Tỷ trọng 1.0% -> 2.1% | Giá khớp: 19.35
#   > 🟢 MUA FPT: Tỷ trọng 4.3% -> 5.2% | Giá khớp: 122.51
#   > 🟢 MUA GMD: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 58.97
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 5.7% -> 4.5% | Giá bán: 22.08 | Giá vốn: 22.02 | Lãi/Lỗ: +0.26% (+3,227 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 8.6% -> 5.3% | Giá bán: 13.13 | Giá vốn: 13.04 | Lãi/Lỗ: +0.67% (+22,672 đ)
#   > 🟢 MUA HT1: Tỷ trọng 3.4% -> 3.6% | Giá khớp: 12.43
#   > 🟢 MUA KBC: Tỷ trọng 3.8% -> 4.6% | Giá khớp: 29.40
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 15.2% -> 13.4% | Giá bán: 16.54 | Giá vốn: 16.21 | Lãi/Lỗ: +2.06% (+38,521 đ)
#   > 🟢 MUA MSN: Tỷ trọng 1.8% -> 2.0% | Giá khớp: 68.00
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 3.1% | Giá khớp: 58.75
#   > 🔥 CHỐT LỜI NKG: Tỷ trọng 2.0% -> 1.5% | Giá bán: 12.36 | Giá vốn: 12.22 | Lãi/Lỗ: +1.14% (+5,558 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 6.1% -> 4.5% | Giá bán: 30.98 | Giá vốn: 29.63 | Lãi/Lỗ: +4.53% (+74,869 đ)
#   > 🩸 CẮT LỖ NT2: Tỷ trọng 1.1% -> 0.0% | Giá bán: 18.97 | Giá vốn: 19.17 | Lãi/Lỗ: -1.04% (-11,900 đ)
#   > 🟢 MUA PHR: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 51.30
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 6.7% -> 1.9% | Giá bán: 22.88 | Giá vốn: 22.75 | Lãi/Lỗ: +0.55% (+26,858 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 4.6% -> 2.0% | Giá bán: 47.88 | Giá vốn: 47.88 | Lãi/Lỗ: +0.00% (+5 đ)
#   > 🟢 MUA VNM: Tỷ trọng 1.1% -> 3.5% | Giá khớp: 55.86
#   > 🟢 MUA VSC: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 13.60
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 10.8%, BMP: 3.0%, CTD: 1.7%, DGW: 1.1%, DIG: 1.6%, DPM: 2.1%, EIB: 3.2%, FPT: 5.2%, GAS: 3.4%, GMD: 1.6%, HCM: 4.5%, HPG: 1.4%, HSG: 5.3%, HT1: 3.6%, KBC: 4.6%, MBB: 13.4%, MSN: 2.0%, MWG: 3.1%, NKG: 1.5%, NLG: 4.5%, PDR: 5.3%, PVD: 1.9%, REE: 2.0%, SBT: 4.7%, VIC: 3.4%, VNM: 3.5%]
#   📈 Tài sản: -1,267,928 đ | Hiệu suất ngày: -1.23% | Tổng NAV: 101,624,320 đ
#
# [04/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 10.8% -> 9.1% | Giá bán: 39.21 | Giá vốn: 39.43 | Lãi/Lỗ: -0.58% (-9,700 đ)
#   > 🟢 MUA BMP: Tỷ trọng 3.0% -> 5.4% | Giá khớp: 108.04
#   > 🟢 MUA BVH: Tỷ trọng 0.0% -> 1.0% | Giá khớp: 50.39
#   > 🟢 MUA CTD: Tỷ trọng 1.7% -> 3.4% | Giá khớp: 68.82
#   > 🟢 MUA CTG: Tỷ trọng 0.0% -> 3.0% | Giá khớp: 27.04
#   > 🟢 MUA DCM: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 32.68
#   > 🟢 MUA DGW: Tỷ trọng 1.1% -> 3.2% | Giá khớp: 37.12
#   > 🟢 MUA DIG: Tỷ trọng 1.6% -> 2.2% | Giá khớp: 15.32
#   > 🟢 MUA DPM: Tỷ trọng 2.1% -> 3.1% | Giá khớp: 19.44
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 3.2% -> 0.0% | Giá bán: 18.60 | Giá vốn: 18.35 | Lãi/Lỗ: +1.35% (+44,061 đ)
#   > 🟢 MUA GMD: Tỷ trọng 1.6% -> 2.8% | Giá khớp: 59.34
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 4.5% -> 1.2% | Giá bán: 22.55 | Giá vốn: 22.02 | Lãi/Lỗ: +2.40% (+81,540 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 1.4% -> 1.1% | Giá bán: 19.96 | Giá vốn: 19.74 | Lãi/Lỗ: +1.08% (+2,686 đ)
#   > 🟢 MUA HT1: Tỷ trọng 3.6% -> 4.5% | Giá khớp: 12.53
#   > 🟢 MUA KBC: Tỷ trọng 4.6% -> 5.4% | Giá khớp: 29.70
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 13.4% -> 5.5% | Giá bán: 16.84 | Giá vốn: 16.21 | Lãi/Lỗ: +3.91% (+312,812 đ)
#   > 🟢 MUA MSN: Tỷ trọng 2.0% -> 2.2% | Giá khớp: 68.60
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 4.5% -> 1.1% | Giá bán: 30.62 | Giá vốn: 29.63 | Lãi/Lỗ: +3.32% (+115,043 đ)
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 5.3% -> 1.8% | Giá bán: 17.64 | Giá vốn: 17.19 | Lãi/Lỗ: +2.59% (+92,821 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 2.0% -> 1.8% | Giá bán: 48.40 | Giá vốn: 47.88 | Lãi/Lỗ: +1.09% (+1,720 đ)
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 33.96
#   > 🟢 MUA STB: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 37.30
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 3.4% -> 2.9% | Giá bán: 20.05 | Giá vốn: 20.20 | Lãi/Lỗ: -0.75% (-4,427 đ)
#   > 🟢 MUA VNM: Tỷ trọng 3.5% -> 6.0% | Giá khớp: 55.58
#   > 🟢 MUA VSC: Tỷ trọng 0.5% -> 3.6% | Giá khớp: 13.92
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.1%, BMP: 5.4%, CTD: 3.4%, CTG: 3.0%, DGW: 3.2%, DIG: 2.2%, DPM: 3.1%, FPT: 5.2%, GAS: 3.4%, GMD: 2.8%, HCM: 1.2%, HPG: 1.1%, HSG: 5.3%, HT1: 4.5%, KBC: 5.4%, MBB: 5.5%, MSN: 2.2%, MWG: 3.1%, NKG: 1.5%, NLG: 1.1%, PDR: 1.8%, PVD: 1.9%, REE: 1.8%, SBT: 4.7%, SJS: 1.6%, STB: 1.1%, VIC: 2.9%, VNM: 6.0%, VSC: 3.6%]
#   📈 Tài sản: +1,272,825 đ | Hiệu suất ngày: +1.25% | Tổng NAV: 102,897,144 đ
#
# [05/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 9.1% -> 7.0% | Giá bán: 39.16 | Giá vốn: 39.43 | Lãi/Lỗ: -0.71% (-15,619 đ)
#   > 🟢 MUA BMP: Tỷ trọng 5.4% -> 5.6% | Giá khớp: 108.47
#   > 🟢 MUA BVH: Tỷ trọng 1.0% -> 3.3% | Giá khớp: 50.29
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 3.4% -> 3.2% | Giá bán: 71.60 | Giá vốn: 66.63 | Lãi/Lỗ: +7.45% (+13,883 đ)
#   > 🟢 MUA CTG: Tỷ trọng 3.0% -> 4.9% | Giá khớp: 27.00
#   > 🟢 MUA DCM: Tỷ trọng 0.7% -> 3.2% | Giá khớp: 32.96
#   > 🟢 MUA DIG: Tỷ trọng 2.2% -> 3.0% | Giá khớp: 16.35
#   > 🟢 MUA DXG: Tỷ trọng 0.0% -> 2.0% | Giá khớp: 11.59
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 5.2% -> 4.5% | Giá bán: 123.18 | Giá vốn: 128.03 | Lãi/Lỗ: -3.80% (-27,957 đ)
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 3.4% -> 0.0% | Giá bán: 63.86 | Giá vốn: 63.96 | Lãi/Lỗ: -0.17% (-5,762 đ)
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 12.00
#   > 🟢 MUA HCM: Tỷ trọng 1.2% -> 2.3% | Giá khớp: 22.39
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 1.1% -> 0.0% | Giá bán: 19.92 | Giá vốn: 19.74 | Lãi/Lỗ: +0.88% (+10,054 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 5.3% -> 0.0% | Giá bán: 13.36 | Giá vốn: 13.04 | Lãi/Lỗ: +2.43% (+132,248 đ)
#   > 🟢 MUA KBC: Tỷ trọng 5.4% -> 6.2% | Giá khớp: 29.40
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 5.5% -> 5.1% | Giá bán: 16.88 | Giá vốn: 16.21 | Lãi/Lỗ: +4.15% (+17,540 đ)
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 2.2% -> 0.4% | Giá bán: 67.50 | Giá vốn: 65.93 | Lãi/Lỗ: +2.37% (+44,630 đ)
#   > 🟢 MUA NKG: Tỷ trọng 1.5% -> 3.8% | Giá khớp: 12.91
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 1.1% -> 0.6% | Giá bán: 30.98 | Giá vốn: 29.63 | Lãi/Lỗ: +4.53% (+21,469 đ)
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 1.8% -> 0.7% | Giá bán: 18.28 | Giá vốn: 17.19 | Lãi/Lỗ: +6.32% (+67,696 đ)
#   > 🟢 MUA PVD: Tỷ trọng 1.9% -> 2.2% | Giá khớp: 23.13
#   > 🟢 MUA PVT: Tỷ trọng 1.0% -> 3.3% | Giá khớp: 18.15
#   > 🟢 MUA REE: Tỷ trọng 1.8% -> 4.0% | Giá khớp: 48.76
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 4.7% -> 0.0% | Giá bán: 12.07 | Giá vốn: 11.60 | Lãi/Lỗ: +4.04% (+194,349 đ)
#   > 🟢 MUA SJS: Tỷ trọng 1.6% -> 2.0% | Giá khớp: 34.77
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 0.4% | Giá khớp: 12.87
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 2.9% -> 0.0% | Giá bán: 20.02 | Giá vốn: 20.20 | Lãi/Lỗ: -0.90% (-26,616 đ)
#   > 🟢 MUA VNM: Tỷ trọng 6.0% -> 7.0% | Giá khớp: 56.78
#   > 🟢 MUA VSC: Tỷ trọng 3.6% -> 5.9% | Giá khớp: 14.07
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 7.0%, BMP: 5.6%, BVH: 3.3%, CTD: 3.2%, CTG: 4.9%, DCM: 3.2%, DGW: 3.2%, DIG: 3.0%, DPM: 3.2%, DXG: 2.0%, FPT: 4.5%, GMD: 2.8%, HAG: 1.4%, HCM: 2.3%, HT1: 4.4%, KBC: 6.2%, MBB: 5.1%, MWG: 3.1%, NKG: 3.8%, PVD: 2.2%, PVT: 3.3%, REE: 4.0%, SJS: 2.0%, STB: 1.1%, VNM: 7.0%, VSC: 5.9%]
#   📈 Tài sản: +669,461 đ | Hiệu suất ngày: +0.65% | Tổng NAV: 103,566,605 đ
#
# [06/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 7.0% -> 9.8% | Giá khớp: 39.36
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 5.6% -> 2.5% | Giá bán: 107.77 | Giá vốn: 107.57 | Lãi/Lỗ: +0.18% (+5,495 đ)
#   > 🟢 MUA CTD: Tỷ trọng 3.2% -> 3.8% | Giá khớp: 73.39
#   > 🟢 MUA CTG: Tỷ trọng 4.9% -> 5.5% | Giá khớp: 27.11
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 3.2% -> 2.1% | Giá bán: 37.55 | Giá vốn: 36.97 | Lãi/Lỗ: +1.57% (+18,193 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 3.0% -> 1.4% | Giá bán: 16.27 | Giá vốn: 15.90 | Lãi/Lỗ: +2.29% (+36,902 đ)
#   > 🔥 CHỐT LỜI DPM: Tỷ trọng 3.2% -> 1.1% | Giá bán: 19.60 | Giá vốn: 19.32 | Lãi/Lỗ: +1.45% (+31,204 đ)
#   > 🟢 MUA FPT: Tỷ trọng 4.5% -> 5.7% | Giá khớp: 123.35
#   > 🟢 MUA GMD: Tỷ trọng 2.8% -> 3.5% | Giá khớp: 59.25
#   > 🟢 MUA HAG: Tỷ trọng 1.4% -> 1.9% | Giá khớp: 12.00
#   > 🟢 MUA HCM: Tỷ trọng 2.3% -> 2.6% | Giá khớp: 22.28
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 3.0% | Giá khớp: 13.24
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 4.4% -> 1.6% | Giá bán: 12.43 | Giá vốn: 12.44 | Lãi/Lỗ: -0.07% (-1,950 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 6.2% -> 4.0% | Giá bán: 29.35 | Giá vốn: 29.15 | Lãi/Lỗ: +0.68% (+15,705 đ)
#   > 🟢 MUA MBB: Tỷ trọng 5.1% -> 8.8% | Giá khớp: 16.95
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 0.4% -> 0.2% | Giá bán: 67.40 | Giá vốn: 65.93 | Lãi/Lỗ: +2.22% (+3,768 đ)
#   > 🩸 CẮT LỖ MWG: Tỷ trọng 3.1% -> 0.0% | Giá bán: 58.26 | Giá vốn: 58.75 | Lãi/Lỗ: -0.84% (-26,685 đ)
#   > 🟢 MUA NKG: Tỷ trọng 3.8% -> 4.5% | Giá khớp: 12.86
#   > 🟢 MUA NLG: Tỷ trọng 0.6% -> 1.6% | Giá khớp: 30.58
#   > 🟢 MUA PDR: Tỷ trọng 0.7% -> 2.9% | Giá khớp: 18.33
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 0.5% -> 0.0% | Giá bán: 51.30 | Giá vốn: 51.30 | Lãi/Lỗ: -0.01% (-47 đ)
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 2.2% -> 0.3% | Giá bán: 23.23 | Giá vốn: 22.80 | Lãi/Lỗ: +1.88% (+37,481 đ)
#   > 🟢 MUA PVT: Tỷ trọng 3.3% -> 4.8% | Giá khớp: 18.40
#   > 🟢 MUA REE: Tỷ trọng 4.0% -> 4.5% | Giá khớp: 48.40
#   > 🟢 MUA VHC: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 68.13
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 7.0% -> 5.6% | Giá bán: 56.04 | Giá vốn: 56.14 | Lãi/Lỗ: -0.18% (-2,669 đ)
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 5.9% -> 5.4% | Giá bán: 14.03 | Giá vốn: 13.95 | Lãi/Lỗ: +0.54% (+2,588 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.8%, BMP: 2.5%, BVH: 3.3%, CTD: 3.8%, CTG: 5.5%, DCM: 3.2%, DGW: 2.1%, DIG: 1.4%, DPM: 1.1%, DXG: 2.0%, FPT: 5.7%, GMD: 3.5%, HAG: 1.9%, HCM: 2.6%, HSG: 3.0%, HT1: 1.6%, KBC: 4.0%, MBB: 8.8%, NKG: 4.5%, NLG: 1.6%, PDR: 2.9%, PVT: 4.8%, REE: 4.5%, SJS: 2.0%, STB: 1.1%, VNM: 5.6%, VSC: 5.4%]
#   📈 Tài sản: +3,767 đ | Hiệu suất ngày: +0.00% | Tổng NAV: 103,570,372 đ
#
# [07/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BVH: Tỷ trọng 3.3% -> 3.6% | Giá khớp: 51.08
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 3.8% -> 0.7% | Giá bán: 73.39 | Giá vốn: 67.80 | Lãi/Lỗ: +8.24% (+270,576 đ)
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 3.2% -> 2.5% | Giá bán: 32.73 | Giá vốn: 32.90 | Lãi/Lỗ: -0.53% (-3,669 đ)
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 2.1% -> 1.1% | Giá bán: 37.31 | Giá vốn: 36.97 | Lãi/Lỗ: +0.92% (+9,545 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.4% -> 0.7% | Giá bán: 16.18 | Giá vốn: 15.90 | Lãi/Lỗ: +1.72% (+12,228 đ)
#   > 🟢 MUA DPM: Tỷ trọng 1.1% -> 2.0% | Giá khớp: 19.33
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 1.3% | Giá khớp: 18.65
#   > 🟢 MUA FPT: Tỷ trọng 5.7% -> 6.2% | Giá khớp: 123.01
#   > 🟢 MUA GAS: Tỷ trọng 0.0% -> 1.2% | Giá khớp: 63.39
#   > 🩸 CẮT LỖ GMD: Tỷ trọng 3.5% -> 1.2% | Giá bán: 58.87 | Giá vốn: 59.15 | Lãi/Lỗ: -0.49% (-11,985 đ)
#   > 🟢 MUA HCM: Tỷ trọng 2.6% -> 3.8% | Giá khớp: 22.28
#   > 🟢 MUA HT1: Tỷ trọng 1.6% -> 2.4% | Giá khớp: 12.38
#   > 🟢 MUA MBB: Tỷ trọng 8.8% -> 9.6% | Giá khớp: 17.06
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 0.2% -> 0.0% | Giá bán: 67.70 | Giá vốn: 65.93 | Lãi/Lỗ: +2.67% (+5,606 đ)
#   > 🔥 CHỐT LỜI NKG: Tỷ trọng 4.5% -> 3.0% | Giá bán: 12.73 | Giá vốn: 12.67 | Lãi/Lỗ: +0.50% (+8,003 đ)
#   > 🟢 MUA NLG: Tỷ trọng 1.6% -> 2.2% | Giá khớp: 30.76
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 19.21
#   > 🟢 MUA PDR: Tỷ trọng 2.9% -> 4.0% | Giá khớp: 18.01
#   > 🟢 MUA PVT: Tỷ trọng 4.8% -> 5.2% | Giá khớp: 18.33
#   > 🟢 MUA REE: Tỷ trọng 4.5% -> 4.7% | Giá khớp: 48.98
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 2.0% -> 1.3% | Giá bán: 35.54 | Giá vốn: 34.10 | Lãi/Lỗ: +4.21% (+28,308 đ)
#   > 🔥 CHỐT LỜI STB: Tỷ trọng 1.1% -> 0.0% | Giá bán: 37.45 | Giá vốn: 37.30 | Lãi/Lỗ: +0.39% (+4,497 đ)
#   > 🟢 MUA TCH: Tỷ trọng 0.4% -> 2.1% | Giá khớp: 12.58
#   > 🟢 MUA VCB: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 61.76
#   > 🟢 MUA VNM: Tỷ trọng 5.6% -> 6.2% | Giá khớp: 56.14
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 5.4% -> 4.8% | Giá bán: 13.99 | Giá vốn: 13.95 | Lãi/Lỗ: +0.25% (+1,590 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 9.9%, BMP: 2.4%, BVH: 3.6%, CTG: 5.4%, DCM: 2.5%, DGW: 1.1%, DPM: 2.0%, DXG: 2.0%, EIB: 1.3%, FPT: 6.2%, GAS: 1.2%, GMD: 1.2%, HAG: 1.9%, HCM: 3.8%, HSG: 3.0%, HT1: 2.4%, KBC: 4.0%, MBB: 9.6%, NKG: 3.0%, NLG: 2.2%, PDR: 4.0%, PVT: 5.2%, REE: 4.7%, SJS: 1.3%, TCH: 2.1%, VNM: 6.2%, VSC: 4.8%]
#   📈 Tài sản: +346,798 đ | Hiệu suất ngày: +0.33% | Tổng NAV: 103,917,170 đ
#
# [10/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BID: Tỷ trọng 9.9% -> 6.1% | Giá bán: 39.91 | Giá vốn: 39.41 | Lãi/Lỗ: +1.25% (+48,685 đ)
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 2.4% -> 0.9% | Giá bán: 103.68 | Giá vốn: 107.57 | Lãi/Lỗ: -3.63% (-59,186 đ)
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 3.6% -> 0.3% | Giá bán: 51.86 | Giá vốn: 50.38 | Lãi/Lỗ: +2.94% (+101,614 đ)
#   > 🔥 CHỐT LỜI CTG: Tỷ trọng 5.4% -> 0.5% | Giá bán: 27.66 | Giá vốn: 27.03 | Lãi/Lỗ: +2.31% (+116,670 đ)
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 2.5% -> 0.0% | Giá bán: 32.21 | Giá vốn: 32.90 | Lãi/Lỗ: -2.11% (-55,468 đ)
#   > 🟢 MUA DGW: Tỷ trọng 1.1% -> 3.9% | Giá khớp: 36.54
#   > 🟢 MUA DIG: Tỷ trọng 0.7% -> 1.1% | Giá khớp: 15.88
#   > 🟢 MUA DPM: Tỷ trọng 2.0% -> 6.0% | Giá khớp: 19.05
#   > 🟢 MUA DXG: Tỷ trọng 2.0% -> 2.8% | Giá khớp: 10.99
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 6.2% -> 6.0% | Giá bán: 119.56 | Giá vốn: 126.69 | Lãi/Lỗ: -5.64% (-11,157 đ)
#   > 🟢 MUA GAS: Tỷ trọng 1.2% -> 5.5% | Giá khớp: 63.39
#   > 🟢 MUA GMD: Tỷ trọng 1.2% -> 4.6% | Giá khớp: 58.03
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 1.9% -> 1.8% | Giá bán: 12.45 | Giá vốn: 12.00 | Lãi/Lỗ: +3.74% (+4,936 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 3.8% -> 1.7% | Giá bán: 22.39 | Giá vốn: 22.23 | Lãi/Lỗ: +0.70% (+15,508 đ)
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 2.4% -> 2.3% | Giá bán: 12.18 | Giá vốn: 12.42 | Lãi/Lỗ: -1.93% (-2,111 đ)
#   > 🟢 MUA KBC: Tỷ trọng 4.0% -> 5.9% | Giá khớp: 28.45
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 9.6% -> 4.8% | Giá bán: 17.18 | Giá vốn: 16.57 | Lãi/Lỗ: +3.70% (+184,096 đ)
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 56.59
#   > 🟢 MUA NKG: Tỷ trọng 3.0% -> 6.1% | Giá khớp: 12.27
#   > 🟢 MUA NLG: Tỷ trọng 2.2% -> 2.9% | Giá khớp: 30.00
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 4.0% -> 3.3% | Giá bán: 17.40 | Giá vốn: 18.04 | Lãi/Lỗ: -3.54% (-26,461 đ)
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 0.3% -> 0.0% | Giá bán: 22.88 | Giá vốn: 22.80 | Lãi/Lỗ: +0.35% (+955 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 5.2% -> 1.9% | Giá bán: 17.88 | Giá vốn: 18.21 | Lãi/Lỗ: -1.84% (-62,412 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 4.7% -> 0.7% | Giá bán: 48.98 | Giá vốn: 48.39 | Lãi/Lỗ: +1.21% (+50,496 đ)
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 2.2% | Giá khớp: 12.73
#   > 🟢 MUA SJS: Tỷ trọng 1.3% -> 2.4% | Giá khớp: 35.04
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 2.1% -> 1.6% | Giá bán: 12.41 | Giá vốn: 12.64 | Lãi/Lỗ: -1.83% (-8,233 đ)
#   > 🟢 MUA VCB: Tỷ trọng 0.1% -> 1.1% | Giá khớp: 61.23
#   > 🟢 MUA VNM: Tỷ trọng 6.2% -> 10.2% | Giá khớp: 55.95
#   > 🟢 MUA VSC: Tỷ trọng 4.8% -> 6.0% | Giá khớp: 13.57
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.1%, DGW: 3.9%, DIG: 1.1%, DPM: 6.0%, DXG: 2.8%, EIB: 1.3%, FPT: 6.0%, GAS: 5.5%, GMD: 4.6%, HAG: 1.8%, HCM: 1.7%, HSG: 3.0%, HT1: 2.3%, KBC: 5.9%, MBB: 4.8%, MWG: 1.1%, NKG: 6.1%, NLG: 2.9%, PDR: 3.3%, PVT: 1.9%, SBT: 2.2%, SJS: 2.4%, TCH: 1.6%, VCB: 1.1%, VNM: 10.2%, VSC: 6.0%]
#   📈 Tài sản: -1,667,661 đ | Hiệu suất ngày: -1.60% | Tổng NAV: 102,249,509 đ
#
# [11/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BID: Tỷ trọng 6.1% -> 5.6% | Giá bán: 40.00 | Giá vốn: 39.41 | Lãi/Lỗ: +1.48% (+8,836 đ)
#   > 🟢 MUA BMP: Tỷ trọng 0.9% -> 2.3% | Giá khớp: 103.85
#   > 🟢 MUA CTD: Tỷ trọng 0.7% -> 3.5% | Giá khớp: 75.28
#   > 🔥 CHỐT LỜI CTG: Tỷ trọng 0.5% -> 0.0% | Giá bán: 27.93 | Giá vốn: 27.03 | Lãi/Lỗ: +3.31% (+17,815 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.9% -> 3.6% | Giá bán: 36.20 | Giá vốn: 36.66 | Lãi/Lỗ: -1.27% (-3,572 đ)
#   > 🟢 MUA DIG: Tỷ trọng 1.1% -> 2.1% | Giá khớp: 15.96
#   > 🟢 MUA DPM: Tỷ trọng 6.0% -> 7.6% | Giá khớp: 19.22
#   > 🟢 MUA DXG: Tỷ trọng 2.8% -> 4.3% | Giá khớp: 10.99
#   > 🟢 MUA FPT: Tỷ trọng 6.0% -> 8.1% | Giá khớp: 122.42
#   > 🟢 MUA GAS: Tỷ trọng 5.5% -> 9.5% | Giá khớp: 63.11
#   > 🩸 CẮT LỖ GMD: Tỷ trọng 4.6% -> 4.4% | Giá bán: 57.27 | Giá vốn: 58.31 | Lãi/Lỗ: -1.80% (-2,783 đ)
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 1.8% -> 0.0% | Giá bán: 12.55 | Giá vốn: 12.00 | Lãi/Lỗ: +4.57% (+83,643 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 1.7% -> 1.4% | Giá bán: 22.39 | Giá vốn: 22.23 | Lãi/Lỗ: +0.70% (+2,319 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 3.0% -> 0.9% | Giá bán: 12.50 | Giá vốn: 13.24 | Lãi/Lỗ: -5.60% (-117,882 đ)
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 2.3% -> 0.8% | Giá bán: 12.23 | Giá vốn: 12.42 | Lãi/Lỗ: -1.52% (-22,936 đ)
#   > 🩸 CẮT LỖ KBC: Tỷ trọng 5.9% -> 2.0% | Giá bán: 28.90 | Giá vốn: 28.92 | Lãi/Lỗ: -0.08% (-3,047 đ)
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 4.8% -> 1.4% | Giá bán: 17.25 | Giá vốn: 16.57 | Lãi/Lỗ: +4.12% (+141,743 đ)
#   > 🟢 MUA MWG: Tỷ trọng 1.1% -> 2.8% | Giá khớp: 55.60
#   > 🩸 CẮT LỖ NKG: Tỷ trọng 6.1% -> 5.6% | Giá bán: 12.41 | Giá vốn: 12.46 | Lãi/Lỗ: -0.45% (-2,194 đ)
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 2.9% -> 1.2% | Giá bán: 29.51 | Giá vốn: 30.28 | Lãi/Lỗ: -2.54% (-41,923 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 3.3% -> 1.1% | Giá bán: 17.50 | Giá vốn: 18.04 | Lãi/Lỗ: -2.99% (-66,334 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 1.9% -> 0.7% | Giá bán: 17.77 | Giá vốn: 18.21 | Lãi/Lỗ: -2.44% (-31,080 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 0.7% -> 0.2% | Giá bán: 49.50 | Giá vốn: 48.39 | Lãi/Lỗ: +2.29% (+12,262 đ)
#   > 🟢 MUA SBT: Tỷ trọng 2.2% -> 7.3% | Giá khớp: 12.82
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 2.4% -> 1.1% | Giá bán: 35.97 | Giá vốn: 34.53 | Lãi/Lỗ: +4.17% (+56,051 đ)
#   > 🟢 MUA TCH: Tỷ trọng 1.6% -> 2.0% | Giá khớp: 12.62
#   > 🟢 MUA VCB: Tỷ trọng 1.1% -> 1.8% | Giá khớp: 61.03
#   > 🩸 CẮT LỖ VHC: Tỷ trọng 0.9% -> 0.0% | Giá bán: 67.74 | Giá vốn: 68.13 | Lãi/Lỗ: -0.58% (-5,235 đ)
#   > 🟢 MUA VNM: Tỷ trọng 10.2% -> 12.1% | Giá khớp: 55.77
#   > 🩸 CẮT LỖ VSC: Tỷ trọng 6.0% -> 4.7% | Giá bán: 13.72 | Giá vốn: 13.88 | Lãi/Lỗ: -1.13% (-15,157 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 5.6%, BMP: 2.3%, CTD: 3.5%, DGW: 3.6%, DIG: 2.1%, DPM: 7.6%, DXG: 4.3%, EIB: 1.3%, FPT: 8.1%, GAS: 9.5%, GMD: 4.4%, HCM: 1.4%, KBC: 2.0%, MBB: 1.4%, MWG: 2.8%, NKG: 5.6%, NLG: 1.2%, PDR: 1.1%, SBT: 7.3%, SJS: 1.1%, TCH: 2.0%, VCB: 1.8%, VNM: 12.1%, VSC: 4.7%]
#   📈 Tài sản: +431,598 đ | Hiệu suất ngày: +0.42% | Tổng NAV: 102,681,106 đ
#
# [12/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 5.6% -> 7.4% | Giá khớp: 39.56
#   > 🟢 MUA BMP: Tỷ trọng 2.3% -> 4.9% | Giá khớp: 104.03
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 0.3% -> 0.0% | Giá bán: 53.33 | Giá vốn: 50.38 | Lãi/Lỗ: +5.85% (+16,211 đ)
#   > 🟢 MUA CTD: Tỷ trọng 3.5% -> 3.8% | Giá khớp: 75.90
#   > 🟢 MUA DGW: Tỷ trọng 3.6% -> 4.8% | Giá khớp: 36.35
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 2.1% -> 1.4% | Giá bán: 15.83 | Giá vốn: 15.93 | Lãi/Lỗ: -0.62% (-4,660 đ)
#   > 🔥 CHỐT LỜI DPM: Tỷ trọng 7.6% -> 5.7% | Giá bán: 19.27 | Giá vốn: 19.16 | Lãi/Lỗ: +0.59% (+11,816 đ)
#   > 🩸 CẮT LỖ DXG: Tỷ trọng 4.3% -> 2.3% | Giá bán: 10.91 | Giá vốn: 11.27 | Lãi/Lỗ: -3.22% (-66,056 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 1.3% -> 0.0% | Giá bán: 19.20 | Giá vốn: 18.65 | Lãi/Lỗ: +2.94% (+37,924 đ)
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 8.1% -> 5.5% | Giá bán: 122.09 | Giá vốn: 125.60 | Lãi/Lỗ: -2.81% (-72,995 đ)
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 9.5% -> 8.3% | Giá bán: 63.20 | Giá vốn: 63.27 | Lãi/Lỗ: -0.12% (-1,564 đ)
#   > 🩸 CẮT LỖ GMD: Tỷ trọng 4.4% -> 3.4% | Giá bán: 56.99 | Giá vốn: 58.31 | Lãi/Lỗ: -2.28% (-23,473 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 1.4% -> 0.0% | Giá bán: 22.43 | Giá vốn: 22.23 | Lãi/Lỗ: +0.88% (+12,341 đ)
#   > 🟢 MUA HSG: Tỷ trọng 0.9% -> 1.7% | Giá khớp: 12.46
#   > 🟢 MUA HT1: Tỷ trọng 0.8% -> 1.5% | Giá khớp: 12.48
#   > 🟢 MUA KBC: Tỷ trọng 2.0% -> 2.4% | Giá khớp: 29.00
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 1.4% -> 0.8% | Giá bán: 17.02 | Giá vốn: 16.57 | Lãi/Lỗ: +2.73% (+18,057 đ)
#   > 🟢 MUA MSN: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 69.00
#   > 🟢 MUA NKG: Tỷ trọng 5.6% -> 5.9% | Giá khớp: 12.23
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 1.2% -> 0.7% | Giá bán: 29.29 | Giá vốn: 30.28 | Lãi/Lỗ: -3.26% (-18,135 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 1.1% -> 0.0% | Giá bán: 17.36 | Giá vốn: 18.04 | Lãi/Lỗ: -3.76% (-42,141 đ)
#   > 🟢 MUA PVT: Tỷ trọng 0.7% -> 1.6% | Giá khớp: 17.84
#   > 🟢 MUA REE: Tỷ trọng 0.2% -> 0.9% | Giá khớp: 49.86
#   > 🟢 MUA SBT: Tỷ trọng 7.3% -> 7.7% | Giá khớp: 12.64
#   > 🟢 MUA SJS: Tỷ trọng 1.1% -> 1.9% | Giá khớp: 35.77
#   > 🟢 MUA TCH: Tỷ trọng 2.0% -> 4.3% | Giá khớp: 12.50
#   > 🟢 MUA VCB: Tỷ trọng 1.8% -> 2.1% | Giá khớp: 60.76
#   > 🟢 MUA VHC: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 67.16
#   > 🟢 MUA VNM: Tỷ trọng 12.1% -> 12.3% | Giá khớp: 56.32
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 4.7% -> 4.3% | Giá bán: 13.99 | Giá vốn: 13.88 | Lãi/Lỗ: +0.82% (+3,397 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 7.4%, BMP: 4.9%, CTD: 3.8%, DGW: 4.8%, DIG: 1.4%, DPM: 5.7%, DXG: 2.3%, FPT: 5.5%, GAS: 8.3%, GMD: 3.4%, HSG: 1.7%, HT1: 1.5%, KBC: 2.4%, MWG: 2.8%, NKG: 5.9%, PVT: 1.6%, SBT: 7.7%, SJS: 1.9%, TCH: 4.3%, VCB: 2.1%, VNM: 12.3%, VSC: 4.3%]
#   📈 Tài sản: -68,608 đ | Hiệu suất ngày: -0.07% | Tổng NAV: 102,612,499 đ
#
# [13/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 7.4% -> 7.6% | Giá khớp: 39.56
#   > 🟢 MUA BVH: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 53.33
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 3.8% -> 3.1% | Giá bán: 80.65 | Giá vốn: 74.02 | Lãi/Lỗ: +8.95% (+60,698 đ)
#   > 🟢 MUA DGW: Tỷ trọng 4.8% -> 5.2% | Giá khớp: 36.30
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.4% -> 1.0% | Giá bán: 16.09 | Giá vốn: 15.93 | Lãi/Lỗ: +1.01% (+3,763 đ)
#   > 🔥 CHỐT LỜI DPM: Tỷ trọng 5.7% -> 1.6% | Giá bán: 20.18 | Giá vốn: 19.16 | Lãi/Lỗ: +5.34% (+222,837 đ)
#   > 🩸 CẮT LỖ DXG: Tỷ trọng 2.3% -> 1.5% | Giá bán: 10.80 | Giá vốn: 11.27 | Lãi/Lỗ: -4.19% (-33,588 đ)
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 19.15
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 5.5% -> 4.3% | Giá bán: 120.49 | Giá vốn: 125.60 | Lãi/Lỗ: -4.08% (-52,782 đ)
# ...
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.6% -> 1.5% | Giá bán: 39.35 | Giá vốn: 40.06 | Lãi/Lỗ: -1.77% (-50,730 đ)
#   > 🟢 MUA EIB: Tỷ trọng 3.3% -> 5.4% | Giá khớp: 20.80
#   > 🟢 MUA FPT: Tỷ trọng 0.3% -> 1.4% | Giá khớp: 74.20
#   > 🩸 CẮT LỖ GAS: Tỷ trọng 0.2% -> 0.0% | Giá bán: 82.50 | Giá vốn: 84.16 | Lãi/Lỗ: -1.99% (-6,628 đ)
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 4.7% -> 4.4% | Giá bán: 15.25 | Giá vốn: 15.19 | Lãi/Lỗ: +0.35% (+1,229 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 2.8% -> 0.0% | Giá bán: 27.80 | Giá vốn: 27.35 | Lãi/Lỗ: +1.62% (+62,146 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 2.7% -> 2.3% | Giá bán: 15.57 | Giá vốn: 15.27 | Lãi/Lỗ: +1.93% (+10,353 đ)
#   > 🟢 MUA HT1: Tỷ trọng 1.3% -> 2.7% | Giá khớp: 13.95
#   > 🟢 MUA KBC: Tỷ trọng 6.6% -> 6.8% | Giá khớp: 29.25
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.7% | Giá khớp: 23.65
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 0.2% -> 0.0% | Giá bán: 24.70 | Giá vốn: 25.00 | Lãi/Lỗ: -1.21% (-4,163 đ)
#   > 🩸 CẮT LỖ MSN: Tỷ trọng 10.0% -> 6.1% | Giá bán: 71.90 | Giá vốn: 74.17 | Lãi/Lỗ: -3.07% (-168,046 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 2.6% -> 1.0% | Giá bán: 78.20 | Giá vốn: 77.66 | Lãi/Lỗ: +0.69% (+16,103 đ)
#   > 🟢 MUA NLG: Tỷ trọng 0.0% -> 1.7% | Giá khớp: 26.24
#   > 🟢 MUA NT2: Tỷ trọng 1.8% -> 2.0% | Giá khớp: 22.30
#   > 🟢 MUA PDR: Tỷ trọng 4.8% -> 8.6% | Giá khớp: 15.20
#   > 🟢 MUA PHR: Tỷ trọng 5.7% -> 8.3% | Giá khớp: 63.90
#   > 🟢 MUA PVD: Tỷ trọng 0.0% -> 3.6% | Giá khớp: 30.10
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 1.8% -> 0.5% | Giá bán: 19.90 | Giá vốn: 20.20 | Lãi/Lỗ: -1.50% (-25,606 đ)
#   > 🟢 MUA REE: Tỷ trọng 2.2% -> 4.5% | Giá khớp: 50.30
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 6.7% -> 0.0% | Giá bán: 21.20 | Giá vốn: 20.38 | Lãi/Lỗ: +4.03% (+377,179 đ)
#   > 🔥 CHỐT LỜI STB: Tỷ trọng 0.8% -> 0.0% | Giá bán: 70.60 | Giá vốn: 70.05 | Lãi/Lỗ: +0.78% (+8,765 đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 4.5% -> 0.0% | Giá bán: 15.20 | Giá vốn: 14.87 | Lãi/Lỗ: +2.19% (+138,721 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 1.4% -> 0.0% | Giá bán: 61.70 | Giá vốn: 61.95 | Lãi/Lỗ: -0.42% (-8,249 đ)
#   > 🩸 CẮT LỖ VHC: Tỷ trọng 0.7% -> 0.0% | Giá bán: 57.00 | Giá vốn: 57.50 | Lãi/Lỗ: -0.88% (-8,083 đ)
#   > 🟢 MUA VIC: Tỷ trọng 4.3% -> 7.1% | Giá khớp: 196.00
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 0.7% -> 0.0% | Giá bán: 58.90 | Giá vốn: 58.96 | Lãi/Lỗ: -0.11% (-1,016 đ)
#   > 🟢 MUA VSC: Tỷ trọng 1.8% -> 2.1% | Giá khớp: 18.50
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.1%, BMP: 7.5%, BVH: 3.5%, CTD: 1.0%, CTG: 5.6%, DCM: 4.0%, DGW: 1.5%, EIB: 5.4%, FPT: 1.4%, HAG: 4.4%, HDC: 2.3%, HT1: 2.7%, KBC: 6.8%, KDH: 1.7%, MSN: 6.1%, NLG: 1.7%, NT2: 2.0%, PDR: 8.6%, PHR: 8.3%, PVD: 3.6%, REE: 4.5%, VIC: 7.1%, VSC: 2.1%]
#   📈 Tài sản: +1,118,254 đ | Hiệu suất ngày: +0.80% | Tổng NAV: 140,352,904 đ
#
# [11/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 6.1% -> 6.5% | Giá khớp: 41.40
#   > 🟢 MUA CTD: Tỷ trọng 1.0% -> 1.7% | Giá khớp: 71.60
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 5.6% -> 5.3% | Giá bán: 33.35 | Giá vốn: 34.00 | Lãi/Lỗ: -1.92% (-6,455 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 1.5% -> 0.8% | Giá bán: 39.15 | Giá vốn: 40.06 | Lãi/Lỗ: -2.27% (-21,720 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.1% -> 0.6% | Giá khớp: 12.70
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 5.4% -> 5.0% | Giá bán: 20.55 | Giá vốn: 20.89 | Lãi/Lỗ: -1.65% (-7,397 đ)
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 1.4% -> 1.0% | Giá bán: 73.10 | Giá vốn: 74.00 | Lãi/Lỗ: -1.23% (-5,801 đ)
#   > 🟢 MUA HCM: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 27.45
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 0.5% -> 0.0% | Giá bán: 11.80 | Giá vốn: 11.65 | Lãi/Lỗ: +1.28% (+8,478 đ)
#   > 🟢 MUA HT1: Tỷ trọng 2.7% -> 2.9% | Giá khớp: 13.75
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 6.8% -> 6.2% | Giá bán: 31.00 | Giá vốn: 29.45 | Lãi/Lỗ: +5.27% (+44,268 đ)
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 24.75
#   > 🟢 MUA MSN: Tỷ trọng 6.1% -> 7.0% | Giá khớp: 71.00
#   > 🟢 MUA MWG: Tỷ trọng 1.0% -> 1.7% | Giá khớp: 76.90
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 2.0% -> 1.9% | Giá bán: 22.35 | Giá vốn: 22.27 | Lãi/Lỗ: +0.34% (+523 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 8.6% -> 8.3% | Giá bán: 15.00 | Giá vốn: 15.19 | Lãi/Lỗ: -1.26% (-5,854 đ)
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 8.3% -> 8.0% | Giá bán: 64.50 | Giá vốn: 64.93 | Lãi/Lỗ: -0.67% (-2,524 đ)
#   > 🩸 CẮT LỖ PVT: Tỷ trọng 0.5% -> 0.0% | Giá bán: 19.85 | Giá vốn: 20.20 | Lãi/Lỗ: -1.75% (-13,180 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 4.5% -> 3.8% | Giá bán: 50.60 | Giá vốn: 50.38 | Lãi/Lỗ: +0.42% (+4,135 đ)
#   > 🟢 MUA SBT: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 21.90
#   > 🔥 CHỐT LỜI VIC: Tỷ trọng 7.1% -> 6.5% | Giá bán: 196.00 | Giá vốn: 194.44 | Lãi/Lỗ: +0.79% (+6,700 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 59.20
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.5%, BMP: 7.6%, BVH: 3.5%, CTD: 1.7%, CTG: 5.3%, DCM: 4.1%, EIB: 5.0%, FPT: 1.0%, HAG: 4.4%, HDC: 2.3%, HT1: 2.9%, KBC: 6.2%, KDH: 1.7%, MSN: 7.0%, MWG: 1.7%, NLG: 1.7%, NT2: 1.9%, PDR: 8.3%, PHR: 8.0%, PVD: 3.6%, REE: 3.8%, VIC: 6.5%, VSC: 2.2%]
#   📈 Tài sản: +143,445 đ | Hiệu suất ngày: +0.10% | Tổng NAV: 140,496,349 đ
#
# [12/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BID: Tỷ trọng 6.5% -> 4.4% | Giá bán: 41.05 | Giá vốn: 42.50 | Lãi/Lỗ: -3.41% (-102,032 đ)
#   > 🟢 MUA BMP: Tỷ trọng 7.6% -> 8.0% | Giá khớp: 135.00
#   > 🩸 CẮT LỖ BVH: Tỷ trọng 3.5% -> 0.2% | Giá bán: 65.60 | Giá vốn: 67.42 | Lãi/Lỗ: -2.71% (-124,523 đ)
#   > 🟢 MUA CTD: Tỷ trọng 1.7% -> 8.3% | Giá khớp: 70.80
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 5.3% -> 1.2% | Giá bán: 33.40 | Giá vốn: 34.00 | Lãi/Lỗ: -1.78% (-103,159 đ)
#   > 🔥 CHỐT LỜI DCM: Tỷ trọng 4.1% -> 3.7% | Giá bán: 38.20 | Giá vốn: 37.55 | Lãi/Lỗ: +1.73% (+8,933 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 0.8% -> 0.0% | Giá bán: 38.90 | Giá vốn: 40.06 | Lãi/Lỗ: -2.90% (-33,121 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.6% -> 1.8% | Giá khớp: 12.60
#   > 🟢 MUA DPM: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 24.20
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 5.0% -> 2.1% | Giá bán: 20.70 | Giá vốn: 20.89 | Lãi/Lỗ: -0.93% (-38,652 đ)
#   > 🟢 MUA FPT: Tỷ trọng 1.0% -> 3.1% | Giá khớp: 73.50
#   > 🟢 MUA GMD: Tỷ trọng 0.0% -> 1.3% | Giá khớp: 76.00
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 4.4% -> 0.0% | Giá bán: 15.25 | Giá vốn: 15.19 | Lãi/Lỗ: +0.35% (+21,984 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 2.3% -> 0.0% | Giá bán: 15.40 | Giá vốn: 15.27 | Lãi/Lỗ: +0.82% (+26,333 đ)
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 11.70
#   > 🟢 MUA HT1: Tỷ trọng 2.9% -> 4.2% | Giá khớp: 13.60
#   > 🟢 MUA MBB: Tỷ trọng 0.1% -> 1.8% | Giá khớp: 24.85
#   > 🩸 CẮT LỖ MSN: Tỷ trọng 7.0% -> 4.8% | Giá bán: 71.10 | Giá vốn: 73.75 | Lãi/Lỗ: -3.60% (-109,603 đ)
#   > 🟢 MUA MWG: Tỷ trọng 1.7% -> 6.4% | Giá khớp: 76.40
#   > 🟢 MUA NKG: Tỷ trọng 0.0% -> 1.5% | Giá khớp: 12.09
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.9% -> 0.2% | Giá bán: 22.40 | Giá vốn: 22.27 | Lãi/Lỗ: +0.56% (+13,396 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 8.3% -> 3.8% | Giá bán: 14.90 | Giá vốn: 15.19 | Lãi/Lỗ: -1.91% (-119,939 đ)
#   > 🟢 MUA PHR: Tỷ trọng 8.0% -> 8.6% | Giá khớp: 63.60
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 3.8% -> 2.4% | Giá bán: 50.40 | Giá vốn: 50.38 | Lãi/Lỗ: +0.03% (+550 đ)
#   > 🟢 MUA SBT: Tỷ trọng 0.5% -> 5.6% | Giá khớp: 21.55
#   > 🔥 CHỐT LỜI VIC: Tỷ trọng 6.5% -> 2.8% | Giá bán: 195.50 | Giá vốn: 194.44 | Lãi/Lỗ: +0.53% (+27,755 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.7% -> 4.4% | Giá khớp: 59.00
#   > 🟢 MUA VSC: Tỷ trọng 2.2% -> 2.5% | Giá khớp: 18.50
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 4.4%, BMP: 8.0%, CTD: 8.3%, CTG: 1.2%, DCM: 3.7%, DIG: 1.8%, DPM: 3.2%, EIB: 2.1%, FPT: 3.1%, GMD: 1.3%, HT1: 4.2%, KBC: 6.2%, KDH: 1.7%, MBB: 1.8%, MSN: 4.8%, MWG: 6.4%, NKG: 1.5%, NLG: 1.7%, PDR: 3.8%, PHR: 8.6%, PVD: 3.6%, REE: 2.4%, SBT: 5.6%, VIC: 2.8%, VNM: 4.4%, VSC: 2.5%]
#   📈 Tài sản: -827,901 đ | Hiệu suất ngày: -0.59% | Tổng NAV: 139,668,448 đ
#
# [15/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 4.4% -> 5.5% | Giá khớp: 41.60
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 8.0% -> 5.9% | Giá bán: 137.90 | Giá vốn: 136.58 | Lãi/Lỗ: +0.96% (+27,287 đ)
#   > 🩸 CẮT LỖ BVH: Tỷ trọng 0.2% -> 0.0% | Giá bán: 65.20 | Giá vốn: 67.42 | Lãi/Lỗ: -3.30% (-9,691 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 8.3% -> 7.3% | Giá bán: 72.30 | Giá vốn: 71.20 | Lãi/Lỗ: +1.54% (+22,030 đ)
#   > 🟢 MUA CTG: Tỷ trọng 1.2% -> 4.2% | Giá khớp: 33.70
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 3.7% -> 0.1% | Giá bán: 37.20 | Giá vốn: 37.55 | Lãi/Lỗ: -0.93% (-47,213 đ)
#   > 🟢 MUA DGW: Tỷ trọng 0.0% -> 1.2% | Giá khớp: 40.20
#   > 🟢 MUA EIB: Tỷ trọng 2.1% -> 5.4% | Giá khớp: 21.15
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 3.1% -> 2.1% | Giá bán: 73.60 | Giá vốn: 73.67 | Lãi/Lỗ: -0.10% (-1,413 đ)
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 15.15
#   > 🟢 MUA HCM: Tỷ trọng 0.3% -> 2.0% | Giá khớp: 27.45
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 4.2% -> 3.7% | Giá bán: 13.65 | Giá vốn: 13.74 | Lãi/Lỗ: -0.68% (-4,727 đ)
#   > 🩸 CẮT LỖ KDH: Tỷ trọng 1.7% -> 1.1% | Giá bán: 23.25 | Giá vốn: 23.65 | Lãi/Lỗ: -1.70% (-13,462 đ)
#   > 🟢 MUA MSN: Tỷ trọng 4.8% -> 6.9% | Giá khớp: 72.20
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 6.4% -> 5.4% | Giá bán: 79.40 | Giá vốn: 76.65 | Lãi/Lỗ: +3.58% (+48,088 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 1.7% -> 0.4% | Giá bán: 26.25 | Giá vốn: 26.24 | Lãi/Lỗ: +0.03% (+476 đ)
#   > 🟢 MUA NT2: Tỷ trọng 0.2% -> 1.6% | Giá khớp: 22.75
#   > 🟢 MUA PDR: Tỷ trọng 3.8% -> 7.2% | Giá khớp: 15.10
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 8.6% -> 7.0% | Giá bán: 64.20 | Giá vốn: 64.84 | Lãi/Lỗ: -0.99% (-21,143 đ)
#   > 🩸 CẮT LỖ PVD: Tỷ trọng 3.6% -> 0.0% | Giá bán: 29.25 | Giá vốn: 30.10 | Lãi/Lỗ: -2.83% (-143,718 đ)
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 2.8% -> 1.2% | Giá bán: 192.60 | Giá vốn: 194.44 | Lãi/Lỗ: -0.96% (-20,576 đ)
#   > 🟢 MUA VSC: Tỷ trọng 2.5% -> 2.9% | Giá khớp: 18.95
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 5.5%, BMP: 5.9%, CTD: 7.3%, CTG: 4.2%, DGW: 1.2%, DIG: 1.7%, DPM: 3.2%, EIB: 5.4%, FPT: 2.1%, GMD: 1.3%, HCM: 2.0%, HT1: 3.7%, KBC: 6.3%, KDH: 1.1%, MBB: 1.8%, MSN: 6.9%, MWG: 5.4%, NKG: 1.5%, NT2: 1.6%, PDR: 7.2%, PHR: 7.0%, REE: 2.4%, SBT: 5.6%, VIC: 1.2%, VNM: 4.4%, VSC: 2.9%]
#   📈 Tài sản: +2,065,430 đ | Hiệu suất ngày: +1.48% | Tổng NAV: 141,733,878 đ
#
# [16/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 5.5% -> 6.4% | Giá khớp: 41.90
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 5.9% -> 3.9% | Giá bán: 142.00 | Giá vốn: 136.58 | Lãi/Lỗ: +3.96% (+111,709 đ)
#   > 🟢 MUA BVH: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 65.50
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 7.3% -> 6.7% | Giá bán: 72.70 | Giá vốn: 71.20 | Lãi/Lỗ: +2.10% (+18,918 đ)
#   > 🟢 MUA CTG: Tỷ trọng 4.2% -> 6.1% | Giá khớp: 33.70
#   > 🟢 MUA DGW: Tỷ trọng 1.2% -> 2.0% | Giá khớp: 41.30
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.7% -> 1.2% | Giá bán: 13.20 | Giá vốn: 12.63 | Lãi/Lỗ: +4.48% (+30,862 đ)
#   > 🟢 MUA EIB: Tỷ trọng 5.4% -> 7.1% | Giá khớp: 21.20
#   > 🟢 MUA HAG: Tỷ trọng 0.5% -> 1.8% | Giá khớp: 15.20
#   > 🟢 MUA HCM: Tỷ trọng 2.0% -> 3.2% | Giá khớp: 27.85
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 6.3% -> 4.1% | Giá bán: 30.95 | Giá vốn: 29.45 | Lãi/Lỗ: +5.10% (+156,349 đ)
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 1.1% -> 0.0% | Giá bán: 23.70 | Giá vốn: 23.65 | Lãi/Lỗ: +0.20% (+3,175 đ)
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 1.8% -> 1.7% | Giá bán: 25.10 | Giá vốn: 24.84 | Lãi/Lỗ: +1.02% (+1,447 đ)
#   > 🟢 MUA MSN: Tỷ trọng 6.9% -> 8.1% | Giá khớp: 73.00
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 5.4% -> 4.7% | Giá bán: 79.40 | Giá vốn: 76.65 | Lãi/Lỗ: +3.58% (+39,029 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 0.4% -> 0.2% | Giá bán: 28.00 | Giá vốn: 26.24 | Lãi/Lỗ: +6.70% (+22,386 đ)
#   > 🟢 MUA NT2: Tỷ trọng 1.6% -> 1.7% | Giá khớp: 22.85
#   > 🟢 MUA PDR: Tỷ trọng 7.2% -> 8.1% | Giá khớp: 15.35
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 7.0% -> 2.7% | Giá bán: 64.60 | Giá vốn: 64.84 | Lãi/Lỗ: -0.38% (-23,185 đ)
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 5.6% -> 5.1% | Giá bán: 21.75 | Giá vốn: 21.58 | Lãi/Lỗ: +0.76% (+5,721 đ)
#   > 🟢 MUA VIC: Tỷ trọng 1.2% -> 2.5% | Giá khớp: 194.00
#   > 🟢 MUA VNM: Tỷ trọng 4.4% -> 4.6% | Giá khớp: 59.10
#   > 🟢 MUA VSC: Tỷ trọng 2.9% -> 3.3% | Giá khớp: 18.95
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 6.4%, BMP: 3.9%, CTD: 6.7%, CTG: 6.1%, DGW: 2.0%, DIG: 1.2%, DPM: 3.2%, EIB: 7.1%, FPT: 2.1%, GMD: 1.3%, HAG: 1.8%, HCM: 3.2%, HT1: 3.6%, KBC: 4.1%, MBB: 1.7%, MSN: 8.1%, MWG: 4.7%, NKG: 1.5%, NT2: 1.7%, PDR: 8.1%, PHR: 2.7%, REE: 2.4%, SBT: 5.1%, VIC: 2.5%, VNM: 4.6%, VSC: 3.3%]
#   📈 Tài sản: +866,259 đ | Hiệu suất ngày: +0.61% | Tổng NAV: 142,600,137 đ
#
# [17/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 6.4% -> 7.5% | Giá khớp: 42.95
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 3.9% -> 3.0% | Giá bán: 147.40 | Giá vốn: 136.58 | Lãi/Lỗ: +7.91% (+103,804 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 6.7% -> 2.3% | Giá bán: 73.60 | Giá vốn: 71.20 | Lãi/Lỗ: +3.37% (+207,850 đ)
#   > 🟢 MUA CTG: Tỷ trọng 6.1% -> 7.2% | Giá khớp: 34.30
#   > 🟢 MUA DCM: Tỷ trọng 0.1% -> 2.2% | Giá khớp: 36.30
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 1.2% -> 0.0% | Giá bán: 13.15 | Giá vốn: 12.63 | Lãi/Lỗ: +4.08% (+69,550 đ)
#   > 🩸 CẮT LỖ DPM: Tỷ trọng 3.2% -> 0.0% | Giá bán: 23.65 | Giá vốn: 24.20 | Lãi/Lỗ: -2.28% (-104,635 đ)
#   > 🟢 MUA EIB: Tỷ trọng 7.1% -> 8.8% | Giá khớp: 21.45
#   > 🩸 CẮT LỖ FPT: Tỷ trọng 2.1% -> 0.0% | Giá bán: 72.30 | Giá vốn: 73.67 | Lãi/Lỗ: -1.86% (-55,158 đ)
#   > 🟢 MUA GMD: Tỷ trọng 1.3% -> 2.2% | Giá khớp: 78.80
#   > 🟢 MUA HAG: Tỷ trọng 1.8% -> 3.1% | Giá khớp: 15.35
#   > 🟢 MUA HCM: Tỷ trọng 3.2% -> 3.7% | Giá khớp: 27.50
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 0.2% -> 0.0% | Giá bán: 12.05 | Giá vốn: 11.70 | Lãi/Lỗ: +2.98% (+7,573 đ)
#   > 🔥 CHỐT LỜI HT1: Tỷ trọng 3.6% -> 1.0% | Giá bán: 13.85 | Giá vốn: 13.74 | Lãi/Lỗ: +0.78% (+28,778 đ)
#   > 🟢 MUA KBC: Tỷ trọng 4.1% -> 4.6% | Giá khớp: 31.05
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 23.30
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 1.7% -> 0.0% | Giá bán: 25.20 | Giá vốn: 24.84 | Lãi/Lỗ: +1.42% (+33,611 đ)
#   > 🟢 MUA MSN: Tỷ trọng 8.1% -> 9.2% | Giá khớp: 72.50
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 4.7% -> 0.7% | Giá bán: 79.10 | Giá vốn: 76.65 | Lãi/Lỗ: +3.19% (+182,732 đ)
#   > 🔥 CHỐT LỜI NKG: Tỷ trọng 1.5% -> 0.0% | Giá bán: 12.55 | Giá vốn: 12.09 | Lãi/Lỗ: +3.79% (+81,278 đ)
#   > 🟢 MUA NLG: Tỷ trọng 0.2% -> 5.7% | Giá khớp: 27.65
#   > 🟢 MUA NT2: Tỷ trọng 1.7% -> 3.3% | Giá khớp: 22.95
#   > 🟢 MUA PDR: Tỷ trọng 8.1% -> 12.6% | Giá khớp: 15.15
#   > 🟢 MUA PHR: Tỷ trọng 2.7% -> 3.0% | Giá khớp: 64.90
#   > 🟢 MUA REE: Tỷ trọng 2.4% -> 3.1% | Giá khớp: 50.90
#   > 🔥 CHỐT LỜI SBT: Tỷ trọng 5.1% -> 0.0% | Giá bán: 21.75 | Giá vốn: 21.58 | Lãi/Lỗ: +0.76% (+55,545 đ)
#   > 🟢 MUA SSI: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 27.70
#   > 🟢 MUA VIC: Tỷ trọng 2.5% -> 5.4% | Giá khớp: 192.00
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 4.6% -> 0.6% | Giá bán: 59.00 | Giá vốn: 59.03 | Lãi/Lỗ: -0.07% (-3,819 đ)
#   > 🟢 MUA VSC: Tỷ trọng 3.3% -> 5.7% | Giá khớp: 20.25
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 7.5%, BMP: 3.0%, CTD: 2.3%, CTG: 7.2%, DCM: 2.2%, DGW: 2.0%, EIB: 8.8%, GMD: 2.2%, HAG: 3.1%, HCM: 3.7%, HT1: 1.0%, KBC: 4.6%, KDH: 1.6%, MSN: 9.2%, NLG: 5.7%, NT2: 3.3%, PDR: 12.6%, PHR: 3.0%, REE: 3.1%, SSI: 1.1%, VIC: 5.4%, VSC: 5.7%]
#   📈 Tài sản: +867,050 đ | Hiệu suất ngày: +0.61% | Tổng NAV: 143,467,187 đ
#
# =========================================================
# 📊 BÁO CÁO HIỆU SUẤT ĐẦU TƯ (BACKTEST)
# =========================================================
# Chỉ số               | AI Strategy     | Benchmark (EQ)
# -------------------------------------------------------
# Tổng lợi nhuận       |          43.47% |          17.62%
# Lợi nhuận năm        |          29.11% |          12.17%
# Sharpe Ratio         |           1.20  |           0.62
# Max Drawdown         |         -23.75% |         -23.65%
# Win Rate (Ngày)      |          58.15% |          54.49%
# -------------------------------------------------------
# Alpha (So với BM): 16.65% (Lợi nhuận vượt trội sau khi trừ rủi ro thị trường)
# Beta  (So với BM): 1.02 (Độ nhạy cảm với biến động chung)
# =========================================================
# 🔍 PHÂN TÍCH HÀNH VI: AI YÊU THÍCH CỔ PHIẾU NÀO NHẤT?
# =========================================================
# HCM    9.92%
# BID    9.78%
# MBB    8.26%
# KBC    7.71%
# MSN    7.54%
# VNM    7.19%
# CTG    7.12%
# GAS    7.07%
# PDR    6.69%
# VSC    6.54%
# =========================================================
# 💡 ĐÁNH GIÁ PHONG CÁCH GIAO DỊCH CỦA AI
# =========================================================
# - Tỷ trọng Tiền mặt trung bình: 0.06%
#   -> Phong cách: Tấn công (Aggressive). AI gần như lúc nào cũng full cổ phiếu.
# - Tốc độ xoay vòng vốn (Turnover/ngày): 98.68%
#   -> AI lướt sóng (T+) rất nhiều. Có xu hướng chốt non nhanh để bảo toàn rủi ro.
