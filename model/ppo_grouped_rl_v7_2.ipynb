# %%
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import torch as th

import random
seed_val = 321 # random.randint(1, 100)
print(f"🎲 Random Seed: {seed_val}")
th.manual_seed(seed_val)
np.random.seed(seed_val)
random.seed(seed_val)
# Thiết lập thêm cho tính ổn định của môi trường Gym
import os
os.makedirs('v7_2', exist_ok=True)
# os.environ['PYTHONHASHSEED'] = str(seed_val)
from torch import nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import warnings
warnings.filterwarnings('ignore') # Tắt các cảnh báo không cần thiết để Log sạch đẹp hơn
# Out:
# 🎲 Random Seed: 321

# %% [markdown]
# ## [CẤU HÌNH CHIẾN LƯỢC ĐẦU TƯ - AI TRADING]

# %% [markdown]
# ## Khối cấu hình trung tâm (Control Panel) giúp bạn tinh chỉnh "tính cách" của AI

# %%
# mà không cần can thiệp sâu vào bên trong mã nguồn.
class CONFIG:
    TRAINING_MODE = 'fast_split' # 'fast_split' or 'rolling_window'
    # 1. PHÍ GIAO DỊCH (Transaction Cost): 
    # Tỷ lệ phần trăm CTCK thu cho mỗi lần bạn mua hoặc bán cổ phiếu. (VD: 0.2% = 0.002)
    COST_RATE = 0.0001

    TURNOVER_PENALTY_RATE = 0.1
    DRAWDOWN_PENALTY_RATE = 5.0
    LIQUIDITY_BONUS_RATE = 0.02
    TRAIN_WINDOW = 252
    TEST_WINDOW = 21
    SAVE_MODEL_PATH = "v7_2/AI_Brain_v7_2.zip"

    # Các giá trị tính điểm (Reward/Penalty System)
    REWARD_WIN_MULT = 100
    REWARD_LOSS_MULT = 200
    REWARD_ALPHA_MULT = 50
    REWARD_CASH_CRASH_MULT = 100
    PENALTY_OVER_DIVERSIFICATION = 0.01
    
        
    # 7. CHẾ ĐỘ CHỜ HÀNG VỀ T+2 (Rule 7: Settlement Lock):
    # Đặc sản của Chứng khoán VN. Số ngày cổ phiếu bị "nhốt" chưa về tài khoản. 
    # Trong những ngày này (VD: 2 ngày đầu tiên), AI tuyệt đối không thể bán cắt lỗ/chốt lời dù thị trường sập.
    T_PLUS_SETTLEMENT = 3
    
    # 8. SỐ BƯỚC ĐÀO TẠO (Training Timesteps):
    # Số vòng lặp để AI cập nhật bộ não. Càng cao (50k - 100k) AI càng thông minh nhưng thời gian train càng lâu.
    TRAINING_TIMESTEPS = 1_500_000
    
    # 9. ĐỘ PHÂN BỔ VỐN (Entropy Coefficient):
    # Quyết định AI sẽ All-in hay Rải rác.
    # Giá trị nhỏ (0.001) -> Ưu tiên All-in vài mã mạnh nhất.
    # Giá trị lớn (0.05) -> Ưu tiên chia đều tiền ra mua nhiều mã để phân tán rủi ro.
    ENT_COEF = 0.005

    # Neuron Network

# %% [markdown]
# ## LUẬT 2: MARKET CONTEXT (TỔNG HỢP VĨ MÔ & VI MÔ)

# %% [markdown]
# ## Hàm này nạp dữ liệu từ file Parquet (đã chạy HMM) và chế biến thêm các chỉ báo để tạo thành

# %%
def load_data():
    # 1. Nạp dữ liệu thô
    raw_df = pd.read_parquet(r"C:\Users\ADMIN\Desktop\Kaggle\output\hmm_v3_op1_extended\master_drl_ready_full.parquet")
    raw_df['time'] = pd.to_datetime(raw_df['time'])
    
    # Lấy các DataFrame cơ sở
    returns_df = raw_df.pivot(index='time', columns='ticker', values='log_return').fillna(0)
    weights_dim = returns_df.shape[1] # Số lượng mã cổ phiếu
    
    vol_df = raw_df.pivot(index='time', columns='ticker', values='volume').fillna(0)
    close_df = raw_df.pivot(index='time', columns='ticker', values='close').ffill().fillna(0)
    open_df = raw_df.pivot(index='time', columns='ticker', values='open').ffill().fillna(0)
    low_df = raw_df.pivot(index='time', columns='ticker', values='low').ffill().fillna(0)
    high_df = raw_df.pivot(index='time', columns='ticker', values='high').ffill().fillna(0)
    
    # -------------------------------------
    # CÁC CHỈ BÁO VĨ MÔ & KỸ THUẬT (DÀNH CHO AI HỌC)
    # -------------------------------------
    market_return_5d = returns_df.rolling(5).sum().mean(axis=1).fillna(0) 
    market_return_20d = returns_df.rolling(20).sum().mean(axis=1).fillna(0) 
    market_vol_20d = returns_df.rolling(20).std().mean(axis=1).fillna(0) 
    
    price_df = np.exp(returns_df.cumsum())
    ma20_df = price_df.rolling(20).mean()
    dist_ma20_df = ((price_df - ma20_df) / ma20_df).fillna(0)
    momentum_3d_df = (close_df / close_df.shift(3) - 1).fillna(0) # T+3 Momentum

    # -------------------------------------
    # CÁC CHỈ BÁO KỊCH BẢN LUẬT (KHÔNG CHO AI HỌC)
    # -------------------------------------
    ema_df_20 = close_df.ewm(span=20, adjust=False).mean()
    ema_df_50 = close_df.ewm(span=50, adjust=False).mean()
    ema_df_200 = close_df.ewm(span=200, adjust=False).mean()

    # SMA Vol
    def calc_sma(df, n=5):
        return df.rolling(n).mean()
    sma_vol_5_df = calc_sma(vol_df)
    sma_vol_20_df = calc_sma(vol_df, n=20)
    # RSI (Chuẩn Wilder's Smoothing)
    change_df = close_df - close_df.shift(1)
    gain_df = change_df.clip(lower=0)
    loss_df = change_df.clip(upper=0).abs()
    ema_gain = gain_df.ewm(alpha=1/20, min_periods=20, adjust=False).mean()
    ema_loss = loss_df.ewm(alpha=1/20, min_periods=20, adjust=False).mean()
    rs_df = ema_gain / ema_loss
    rsi_df = 100 - (100 / (1 + rs_df))
    rsi_df = rsi_df.fillna(100)

    # MACD
    macd_df = close_df.ewm(span=12, adjust=False).mean() - close_df.ewm(span=26, adjust=False).mean()
    signal_df = macd_df.ewm(span=9, adjust=False).mean()
    hist_df = macd_df - signal_df
    
    # Độ dốc xu hướng (Slope)
    def calc_slope(df, n=3):
        return (df - df.shift(n)) / n
    slope_ema20_3_df = calc_slope(ema_df_20, n=3)  
    slope_sma5_3_df = calc_sma(sma_vol_5_df, n=3)
    # Candlestick Patterns (Đã sửa lỗi Boolean Error)
    body_df = (close_df - open_df).abs()
    tail_df = (np.minimum(close_df, open_df) - low_df)
    head_df = high_df - np.maximum(close_df, open_df)
    
    is_hammer_df = (tail_df >= 2 * body_df) & (head_df <= 0.1 * body_df) & (body_df > 0)
    is_bull_engulf_df = (close_df.shift(1) < open_df.shift(1)) & (close_df > open_df) & (close_df >= open_df.shift(1)) & (open_df <= close_df.shift(1))

    # LowestLow(5) và HighestHigh(10)
    lowest_low_5_df = low_df.rolling(5).min()
    highest_high_5_df = high_df.rolling(5).max()
    highest_high_10_df = high_df.rolling(10).max()
    highest_high_20_df = high_df.rolling(20).max()

    # Đáy và đỉnh
    # Ngày T-2 là Đỉnh nếu nó cao hơn T-4, T-3 (Quá khứ) VÀ cao hơn T-1, T (Hiện tại)
    is_peak = (high_df.shift(2) > high_df.shift(4)) & \
                (high_df.shift(2) > high_df.shift(3)) & \
                (high_df.shift(2) > high_df.shift(1)) & \
                (high_df.shift(2) > high_df)

    # Ngày T-2 là Đáy nếu nó thấp hơn T-4, T-3 (Quá khứ) VÀ thấp hơn T-1, T (Hiện tại)
    is_valley = (low_df.shift(2) < low_df.shift(4)) & \
                (low_df.shift(2) < low_df.shift(3)) & \
                (low_df.shift(2) < low_df.shift(1)) & \
                (low_df.shift(2) < low_df)
    
    peak_values = high_df.shift(2).where(is_peak, np.nan)
    valley_values = low_df.shift(2).where(is_valley, np.nan)

    last_peak_df = peak_values.ffill()
    last_valley_df = valley_values.ffill()
        
    # FIBONACCI
    wave_amplitude_df = last_peak_df - last_valley_df
    wave_state_df = pd.DataFrame(np.nan, index=high_df.index, columns=high_df.columns)
    
    wave_state_df[is_peak] = 1
    wave_state_df[is_valley] = -1
    
    last_swing_type_df = wave_state_df.ffill()
    
    # SUP() RES()
    n = 20 # Số phiên để xác nhận Đỉnh/Đáy (Bạn có thể tinh chỉnh 10 hoặc 20)
    window = 2 * n + 1
    
    # 1. Tìm mức cao nhất/thấp nhất trong 41 ngày gần nhất (20 ngày trước + 1 ngày giữa + 20 ngày sau)
    # V6 Fix: Tính đỉnh/đáy bằng trailing max/min (Bảo vệ tuyệt đối khỏi Lookahead Bias)
    rolling_max = high_df.rolling(window=20, min_periods=1).max()
    rolling_min = low_df.rolling(window=20, min_periods=1).min()

    is_peak = (high_df == rolling_max)
    is_valley = (low_df == rolling_min)
    
    # 3. Ghi nhớ mức giá tại Đỉnh/Đáy đó
    peak_values = high_df.where(is_peak, np.nan)
    valley_values = low_df.where(is_valley, np.nan)
    
    # 4. Kéo dài giá trị ra để lấy Hỗ trợ (Sup) và Kháng cự (Res) gần nhất
    res_df = peak_values.ffill() # Đỉnh gần nhất (Res)
    sup_df = valley_values.ffill() # Đáy gần nhất (Sup)


    # SÓNG TĂNG CHÍNH = Mốc cuối cùng được xác nhận là 1 cái Đỉnh
    # Trả về giá trị True/False cho từng ngày
    is_upward_wave_df = (last_swing_type_df == 1)
    fib_382_df = last_peak_df - (0.382 * wave_amplitude_df)
    fib_500_df = last_peak_df - (0.500 * wave_amplitude_df)
    fib_618_df = last_peak_df - (0.618 * wave_amplitude_df)
    fib_ext_127_df = last_peak_df + (0.272 * wave_amplitude_df)
    fib_ext_161_df = last_peak_df + (0.618 * wave_amplitude_df)

     # Bollinger Bands 
    bb_middle_df = close_df.rolling(20).mean()
    bb_std_df = close_df.rolling(20).std()
    bb_upper_df = bb_middle_df + (2 * bb_std_df)
    bb_lower_df = bb_middle_df - (2 * bb_std_df)
    
    # 2. TÍNH ĐỘ RỘNG DẢI BĂNG (BB WIDTH)
    bb_width_df = (bb_upper_df - bb_lower_df) / bb_middle_df
    
    # 3. TÍN HIỆU BIẾN ĐỘNG MẠNH (DẢI BĂNG MỞ RỘNG)
    # So sánh độ rộng hôm nay với hôm qua VÀ với Trung bình 20 ngày
    bb_expanding_df = (bb_width_df > bb_width_df.shift(1)) & \
                        (bb_width_df > bb_width_df.rolling(20).mean())
    
    # ACCUMULATION
    highest_high_21_df = high_df.rolling(21).max().shift(1)
    lowest_low_21_df = low_df.rolling(21).min().shift(1)
        
    # Biên độ dao động của cái hộp nhỏ hơn 15%
    is_accumulation_df = (highest_high_21_df - lowest_low_21_df) / lowest_low_21_df <= 0.15
    # Bóc tách dữ liệu HMM từ raw_df
    prob0_df = raw_df.pivot(index='time', columns='ticker', values='prob_ticker_0').fillna(0) 
    prob1_df = raw_df.pivot(index='time', columns='ticker', values='prob_ticker_1').fillna(0) 
    prob2_df = raw_df.pivot(index='time', columns='ticker', values='prob_ticker_2').fillna(0) 
    vol_20d_df = raw_df.pivot(index='time', columns='ticker', values='rolling_vol_20d').fillna(0)
    ret_20d_df = raw_df.pivot(index='time', columns='ticker', values='return_20d').fillna(0)
    vol_ratio_df = raw_df.pivot(index='time', columns='ticker', values='volume_ratio').fillna(0)

    # Broadcast vĩ mô
    mkt_ret5_df = pd.DataFrame(np.tile(market_return_5d.values.reshape(-1, 1), (1, weights_dim)), index=returns_df.index, columns=returns_df.columns)
    mkt_ret20_df = pd.DataFrame(np.tile(market_return_20d.values.reshape(-1, 1), (1, weights_dim)), index=returns_df.index, columns=returns_df.columns)
    mkt_vol_df = pd.DataFrame(np.tile(market_vol_20d.values.reshape(-1, 1), (1, weights_dim)), index=returns_df.index, columns=returns_df.columns)
    
    # -------------------------------------------------------------------------
    # GOM THÀNH 2 BẢNG BIỆT LẬP (1 CHO AI, 1 CHO LUẬT KỊCH BẢN)
    # -------------------------------------------------------------------------
    from scipy.stats import norm
    def apply_nqt(df):
        ranked = df.rank(axis=1, method='average')
        uniform = (ranked - 0.5) / df.shape[1]
        nqt = pd.DataFrame(norm.ppf(uniform), index=df.index, columns=df.columns)
        return nqt.replace([np.inf, -np.inf], 0).fillna(0)

    # BẢNG 1: Dành cho Mạng Nơ-ron (Đã qua NQT Cross-Sectional)
    core_list = [prob0_df, prob1_df, prob2_df, vol_20d_df, ret_20d_df, vol_ratio_df, mkt_ret5_df, mkt_ret20_df, mkt_vol_df, dist_ma20_df, momentum_3d_df]
    ai_features_df = pd.concat([apply_nqt(df) for df in core_list], axis=1).fillna(0)
                                
    # BẢNG 2: Kho vũ khí cho kịch bản của con người (AI không được thấy)

    list_strategies = [vol_df ,low_df ,close_df, 
                       ema_df_20, ema_df_50, ema_df_200, 
                       bb_lower_df, bb_middle_df ,bb_upper_df,
                       rsi_df, hist_df, macd_df,
                       sma_vol_20_df,
                       slope_ema20_3_df, slope_sma5_3_df, 
                       is_hammer_df.astype(float), is_bull_engulf_df.astype(float),
                       lowest_low_5_df, highest_high_5_df ,highest_high_10_df, highest_high_20_df,
                       fib_382_df, fib_500_df, fib_618_df, is_upward_wave_df, fib_ext_127_df, fib_ext_161_df,
                       sup_df, res_df,
                       bb_expanding_df,
                       is_accumulation_df,
                       ]

    strategies_features_df = pd.concat(list_strategies, axis=1).fillna(0)
    
    num_strategies_features = 31
    
    # HỢP NHẤT TOÀN BỘ CHỈ BÁO VÀO AI FEATURES (Áp dụng NQT cho mảng chiến lược đưa vào AI)
    ai_strategies_df = pd.concat([apply_nqt(df) for df in list_strategies], axis=1).fillna(0)
    ai_features_df = pd.concat([ai_features_df, ai_strategies_df], axis=1)

    # Đồng bộ độ dài
    returns_df, ai_features_df = returns_df.align(ai_features_df, axis=0, join='inner')
    returns_df, strategies_features_df = returns_df.align(strategies_features_df, axis=0, join='inner')
    tickers = returns_df.columns.tolist()
    
    dates = returns_df.index.strftime('%d/%m/%Y').tolist()
    return returns_df, ai_features_df, strategies_features_df, weights_dim, tickers, num_strategies_features, dates

# %% [markdown]
# ## LUẬT 1, 3, 5, 6: MÔI TRƯỜNG ĐẦU TƯ (GYM ENVIRONMENT)

# %% [markdown]
# ## Lớp này mô phỏng lại Sàn chứng khoán. Nơi AI sẽ thử nghiệm các lệnh Mua/Bán và nhận Phạt/Thưởng (Reward).

# %%
class AdvancedPortfolioEnv(gym.Env):
        def __init__(self, returns_df, ai_features_df, script_features_df, weights_dim, num_script_features, tickers=None, step_size=1, cost_rate=CONFIG.COST_RATE, is_test=False, dates=None):

            super().__init__()
            self.returns_arr = np.exp(returns_df.values) - 1.0 
            
            # Lưu 2 mảng tách biệt
            self.features_arr = ai_features_df.values
            self.script_arr = script_features_df.values
            
            self.weights_dim = weights_dim
            self.num_script_features = num_script_features
            self.n_steps = len(self.returns_arr)
            
            self.step_size = step_size
            self.cost_rate = cost_rate
            self.is_test = is_test 
            self.tickers = tickers
            self.dates = dates
            self.prev_weights = np.zeros(self.weights_dim)
            self.high_watermark = 1.0
            self.current_portfolio_value = 1.0
            
            self.action_space = spaces.Box(low=0, high=1, shape=(self.weights_dim,), dtype=np.float32)
            # Báo cho AI biết là nó chỉ cần học 10 tính năng (vì ai_features_df có 10 cột)
            self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.weights_dim, 42), dtype=np.float32)
            
            self.current_step = 0
            self.weights = np.zeros(self.weights_dim)
            self.entry_prices = np.zeros(self.weights_dim)
            self.entry_scenarios = np.zeros(self.weights_dim)
            self.entry_stages = np.zeros(self.weights_dim)
            self.t_plus_lock = np.zeros(self.weights_dim) # T+2.5 Lock timer
            self.avg_entry_prices = np.zeros(self.weights_dim)
            self.initial_capital = 100_000_000 # Giả lập vốn 100 triệu
            self.current_capital = self.initial_capital
            self.peak_nav = self.initial_capital
            self.prev_drawdown = 0.0
        def reset(self, seed=None, options=None):
            self.current_step = 0
            self.weights = np.zeros(self.weights_dim)
            self.t_plus_lock = np.zeros(self.weights_dim)
            self.avg_entry_prices = np.zeros(self.weights_dim)
            self.current_capital = self.initial_capital
            self.peak_nav = self.initial_capital
            self.prev_drawdown = 0.0
            return self._get_obs(), {}
            
        def _get_obs(self):
            idx = min(self.current_step, self.n_steps - 1)
            obs_1d = self.features_arr[idx]
            obs_2d = obs_1d.reshape(42, self.weights_dim).T
            return obs_2d.astype(np.float32)
            
        def step(self, action):
            current_obs = self._get_obs()
            idx = min(self.current_step, self.n_steps - 1)
            
            current_scripts = self.script_arr[idx].reshape(self.num_script_features, self.weights_dim).T
            prev_idx = max(0, idx - 1)
            prev_scripts = self.script_arr[prev_idx].reshape(self.num_script_features, self.weights_dim).T
            
            # V6 Fix: Xóa Kịch bản Hard-code
            # V6 Fix: Tuyến tính hóa thay vì Softmax
            action_sum = np.sum(action)
            if action_sum > 1.0:
                action = action / action_sum
            elif action_sum == 0.0:
                action = np.zeros_like(action)
            else:
                action = np.zeros_like(action)
                
            # [FIX 1] Áp dụng luật khoá T+2.5 (T_PLUS_SETTLEMENT)
            # Khóa không cho bán (tỷ trọng không được giảm) nếu hàng chưa về
            locked_mask = self.t_plus_lock > 0
            action[locked_mask] = np.maximum(action[locked_mask], self.weights[locked_mask])
            
            # Cập nhật lại bộ đếm ngày khóa
            self.t_plus_lock = np.maximum(0, self.t_plus_lock - 1)
            
            # Mua mới hoặc mua thêm -> bị khóa lại
            bought_mask = action > self.weights
            self.t_plus_lock[bought_mask] = getattr(CONFIG, 'T_PLUS_SETTLEMENT', 3)
            
            # Chuẩn hóa lại nếu tổng > 1
            action_sum = np.sum(action)
            if action_sum > 1.0:
                action = action / action_sum
            elif action_sum == 0.0:
                action = np.zeros_like(action)
            
            turnover = np.sum(np.abs(action - self.weights))
            cost = self.cost_rate * turnover
            
            self.prev_weights = self.weights.copy()
            self.weights = action
            
            market_ret = np.mean(self.returns_arr[self.current_step])
            daily_ret = np.sum(self.weights * self.returns_arr[self.current_step]) - cost
            
            self.current_portfolio_value = self.current_portfolio_value * (1 + daily_ret)
            
            # V7.2 Fix: Hàm Reward mượt mà, tránh sợ hãi cực độ
            
            base_reward = daily_ret * 100 
            if daily_ret < 0:
                base_reward *= 2.0  # Phạt gấp 2 lần nếu lỗ
            
            reward = base_reward
            
            if getattr(self, 'is_test', False):

            
                date_str = self.dates[self.current_step] if getattr(self, 'dates', None) else f'Step {self.current_step}'

            
                

            
                # Tracker for detailed logs

            
                trade_logs = []

            
                current_prices = current_scripts[:, 2] # close price is index 2

            
                

            
                for i in range(self.weights_dim):

            
                    old_w = self.prev_weights[i]

            
                    new_w = self.weights[i]

            
                    

            
                    if new_w > old_w + 0.001: # Mua thêm

            
                        added_w = new_w - old_w

            
                        if old_w < 0.001:

            
                            self.avg_entry_prices[i] = current_prices[i]

            
                        else:

            
                            self.avg_entry_prices[i] = (old_w * self.avg_entry_prices[i] + added_w * current_prices[i]) / new_w

            
                        trade_logs.append(f"🟢 MUA {self.tickers[i]}: Tỷ trọng {old_w*100:.1f}% -> {new_w*100:.1f}% | Giá khớp: {current_prices[i]:.2f}")

            
                        

            
                    elif new_w < old_w - 0.001: # Bán

            
                        sold_w = old_w - new_w

            
                        if self.avg_entry_prices[i] > 0:

            
                            profit_pct = (current_prices[i] - self.avg_entry_prices[i]) / self.avg_entry_prices[i]

            
                            profit_pct -= self.cost_rate # Tính luôn thuế phí

            
                            profit_money = (sold_w * self.current_capital) * profit_pct

            
                            

            
                            icon = "🔥 CHỐT LỜI" if profit_pct > 0 else "🩸 CẮT LỖ"

            
                            trade_logs.append(f"{icon} {self.tickers[i]}: Tỷ trọng {old_w*100:.1f}% -> {new_w*100:.1f}% | Giá bán: {current_prices[i]:.2f} | Giá vốn: {self.avg_entry_prices[i]:.2f} | Lãi/Lỗ: {profit_pct*100:+.2f}% ({profit_money:+,.0f} đ)")

            
                        if new_w < 0.001:

            
                            self.avg_entry_prices[i] = 0

            
                

            
                # Cập nhật vốn hiện tại (NAV)

            
                prev_capital = self.current_capital

            
                self.current_capital = self.current_capital * (1 + daily_ret)

            
                daily_capital_change = self.current_capital - prev_capital

            
                

            
                weight_sum = np.sum(self.weights)

            
                if len(trade_logs) > 0 or weight_sum > 0.01:

            
                    cash_weight = max(0.0, 1.0 - weight_sum)

            
                    allocations = [f"{self.tickers[k]}: {self.weights[k]*100:.1f}%" for k in range(self.weights_dim) if self.weights[k] > 0.01]

            
                    alloc_str = ", ".join(allocations) if allocations else "Trống"

            
                    

            
                    print(f"\n[{date_str}] 📅 BÁO CÁO GIAO DỊCH:")

            
                    for log in trade_logs:

            
                        print(f"  > {log}")

            
                    print(f"  💵 Tỷ trọng: Tiền mặt {cash_weight*100:.1f}% | Cổ phiếu: [{alloc_str}]")

            
                    print(f"  📈 Tài sản: {daily_capital_change:+,.0f} đ | Hiệu suất ngày: {daily_ret*100:+.2f}% | Tổng NAV: {self.current_capital:,.0f} đ")

            
                    

            
            # ------------ HỆ THỐNG PHẠT DRAWDOWN & GAME OVER ------------
            self.peak_nav = max(self.peak_nav, getattr(self, 'current_capital', 100_000_000))
            drawdown = (self.peak_nav - getattr(self, 'current_capital', 100_000_000)) / self.peak_nav
            
            prev_dd = getattr(self, 'prev_drawdown', 0.0)
            if drawdown > prev_dd:
                dd_increase = drawdown - prev_dd
                reward -= (dd_increase * 1000)
            
            self.prev_drawdown = drawdown
            
            force_terminate = False
            if drawdown > 0.30:
                reward -= 100
                force_terminate = True
                if getattr(self, 'is_test', False):
                    print(f"💀 GAME OVER: Cháy tài khoản! Drawdown {drawdown*100:.1f}% tại Step {self.current_step}")
            # -----------------------------------------------------------
            
            self.current_step += 1
            done = (self.current_step >= self.n_steps - 1) or force_terminate
            
            return self._get_obs(), float(reward), done, False, {'net_return': daily_ret}

# %% [markdown]
# ## MẠNG NƠ-RON TRÍ TUỆ NHÂN TẠO (NEURAL NETWORK STRUCTURE)

# %% [markdown]
# ## Đây là "Bộ Não" thực sự của AI. Mạng Nơ-ron này chịu trách nhiệm Đọc dữ liệu (Extractor).

# %%
class AdvancedTickerExtractor(BaseFeaturesExtractor):
        def __init__(self, observation_space: spaces.Box, features_dim: int = 256):
            super().__init__(observation_space, features_dim)
            num_tickers = observation_space.shape[0] # 46 mã
            num_features_per_ticker = observation_space.shape[1] # 11 tính năng
            
            # Tầng 1 (Local): Học phân tích RIÊNG LẺ
            self.ticker_net = nn.Sequential(
                nn.Linear(num_features_per_ticker, 32),
                nn.ReLU(),
                # nn.Dropout(0.2),
                nn.Linear(32, 16),
                nn.ReLU()
            )
            
            # --- CẢI TIẾN: Tầng 1.5 (Attention) ---
            # Cho phép các cổ phiếu giao tiếp và so sánh sức mạnh với nhau
            self.attention = nn.MultiheadAttention(embed_dim=16, num_heads=4, batch_first=True)
            self.layer_norm = nn.LayerNorm(16)
            # --------------------------------------
    
            # Tầng 2 (Global): Tổng hợp ra quyết định
            self.global_net = nn.Sequential(
                nn.Linear(num_tickers * 16, features_dim),
                nn.ReLU()
            )
    
        def forward(self, observations: th.Tensor) -> th.Tensor:
            batch_size, num_tickers, num_features = observations.shape
            
            # 1. Trích xuất Local
            obs_reshaped = observations.view(batch_size * num_tickers, num_features)
            ticker_features = self.ticker_net(obs_reshaped)
            
            # Đưa về dạng 3D: (Batch, Số_Mã, Đặc_trưng) để chạy Attention
            ticker_features = ticker_features.view(batch_size, num_tickers, 16) 
            
            # 2. --- CẢI TIẾN: Cross-Ticker Attention ---
            # Các mã cổ phiếu "nhìn" nhau để tìm ra con mạnh nhất (Leader)
            attn_out, _ = self.attention(ticker_features, ticker_features, ticker_features)
            
            # Residual connection + LayerNorm (Bắt buộc phải có để đạo hàm không bị nổ))
            ticker_features = self.layer_norm(ticker_features + attn_out)
            # --------------------------------------------
            
            # 3. Đưa Tầng 1.5 vào Tầng 22
            flattened_features = ticker_features.view(batch_size, num_tickers * 16)
            global_features = self.global_net(flattened_features)
            
            return global_features

# %%
returns_df, ai_features_df, strategies_features_df, weights_dim, tickers, num_strategies_features, dates = load_data()

# %%
from stable_baselines3.common.vec_env import VecNormalize
print("\n[LUẬT 4] KHỞI ĐỘNG HỆ THỐNG HUẤN LUYỆN...")

TRAINING_MODE = getattr(CONFIG, 'TRAINING_MODE', 'fast_split') # 'fast_split' or 'rolling_window'

total_days = len(returns_df)

model = None

policy_kwargs = dict(
    features_extractor_class=AdvancedTickerExtractor,
    features_extractor_kwargs=dict(features_dim=256),
)

all_test_returns = []

if TRAINING_MODE == 'fast_split':
    print(f"\n=======================================================")
    print(f"--- CHẾ ĐỘ HỌC NHANH (FAST SPLIT: 70% Train, 15% Val, 15% Test) ---")
    
    train_ratio = 0.7
    val_ratio = 0.15
    
    train_end = int(total_days * train_ratio)
    val_end = int(total_days * (train_ratio + val_ratio))
    
    returns_train = returns_df.iloc[:train_end]
    ai_train = ai_features_df.iloc[:train_end]
    strategies_train = strategies_features_df.iloc[:train_end]
    dates_train = dates[:train_end]
    
    returns_val = returns_df.iloc[train_end:val_end]
    ai_val = ai_features_df.iloc[train_end:val_end]
    strategies_val = strategies_features_df.iloc[train_end:val_end]
    dates_val = dates[train_end:val_end]
    
    returns_test = returns_df.iloc[val_end:]
    ai_test = ai_features_df.iloc[val_end:]
    strategies_test = strategies_features_df.iloc[val_end:]
    dates_test = dates[val_end:]
    
    train_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
        returns_train, ai_train, strategies_train, weights_dim, num_strategies_features, tickers=tickers, dates=dates_train
    )])
    train_env = VecNormalize(train_env, norm_obs=False, norm_reward=True, clip_reward=10.0)
    
    print(f"Khởi tạo Mạng Nơ-ron AI (Train: {len(dates_train)} days, Val: {len(dates_val)} days, Test: {len(dates_test)} days)...")
    model = PPO("MlpPolicy", train_env, 
                policy_kwargs=policy_kwargs, 
                verbose=1, 
                n_steps=1024,
                learning_rate=0.00005,
                ent_coef=CONFIG.ENT_COEF,
                batch_size=90)
                
    print("\n[CURRICULUM LEARNING] Bắt đầu huấn luyện theo từng cấp độ độ trễ (T+0 -> T+1 -> T+3)...")

                
    CONFIG.T_PLUS_SETTLEMENT = 0

                
    print("Giai đoạn 1: Huấn luyện với T+0 (100,000 steps)...")

                
    model.learn(total_timesteps=10000, reset_num_timesteps=False)

                
    CONFIG.T_PLUS_SETTLEMENT = 1

                
    print("Giai đoạn 2: Huấn luyện với T+1 (100,000 steps)...")

                
    model.learn(total_timesteps=10000, reset_num_timesteps=False)

                
    CONFIG.T_PLUS_SETTLEMENT = 3

                
    print("Giai đoạn 3: Huấn luyện với T+3 (300,000 steps)...")

                
    model.learn(total_timesteps=30000, reset_num_timesteps=False)
    
    model.save(getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_2/AI_Brain_v7_2.zip'))
    train_env.save("v7_2/vec_normalize.pkl")
    
    print(f"\nĐang chạy Backtest trên Test Set (CÓ TÍNH PHÍ GIAO DỊCH {CONFIG.COST_RATE * 100}%)...")
    print("-------------------------------------------------------")
    
    test_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
        returns_test, ai_test, strategies_test, weights_dim, num_strategies_features, tickers=tickers, dates=dates_test, is_test=True
    )])
    test_env = VecNormalize.load("v7_2/vec_normalize.pkl", test_env)
    test_env.training = False
    test_env.norm_reward = False
    obs = test_env.reset()
    
    done = [False]
    while not done[0]:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = test_env.step(action)
        if 'net_return' in info[0]:
            all_test_returns.append(info[0]['net_return'])
            
    total_profit = (np.prod(1 + np.array(all_test_returns)) - 1) * 100
    print(f"\n🏆 TỔNG LỢI NHUẬN TEST SET: {total_profit:+.2f}%")
    
elif TRAINING_MODE == 'rolling_window':
    train_window = getattr(CONFIG, 'TRAIN_WINDOW', 252)
    test_window = getattr(CONFIG, 'TEST_WINDOW', 21)
    
    current_start = 0
    fold_idx = 1
    
    while current_start + train_window < total_days:
        train_start = current_start
        train_end = current_start + train_window
        test_start = train_end
        test_end = min(test_start + test_window, total_days)
        
        if test_end - test_start < 2:
            break
            
        print(f"\n=======================================================")
        print(f"--- CHU KỲ {fold_idx}: HỌC {dates[train_start]} -> {dates[train_end-1]} | THỰC CHIẾN: {dates[test_start]} -> {dates[test_end-1]} ---")
        
        returns_train = returns_df.iloc[train_start:train_end]
        ai_train = ai_features_df.iloc[train_start:train_end]
        strategies_train = strategies_features_df.iloc[train_start:train_end]
        dates_train = dates[train_start:train_end]
        
        returns_test = returns_df.iloc[test_start:test_end]
        ai_test = ai_features_df.iloc[test_start:test_end]
        strategies_test = strategies_features_df.iloc[test_start:test_end]
        dates_test = dates[test_start:test_end]
        
        train_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
            returns_train, ai_train, strategies_train, weights_dim, num_strategies_features, tickers=tickers, dates=dates_train
        )])
        
        if model is None:
            print("Khởi tạo Mạng Nơ-ron AI hoàn toàn mới...")
            train_env = VecNormalize(train_env, norm_obs=False, norm_reward=True, clip_reward=10.0)
            model = PPO("MlpPolicy", train_env, 
                policy_kwargs=policy_kwargs, 
                verbose=1, 
                n_steps=1024,
                learning_rate=0.00005,
                ent_coef=CONFIG.ENT_COEF,
                batch_size=90,
                use_sde=True,          # Bật SDE
                sde_sample_freq=5     # Đổi hướng khám phá 4 ngày 1 lần (khoảng 1 tuần giao dịch)
               )
        else:
            print("Nạp kiến thức cũ, chuyển Sàn môi trường để học tiếp (Continual Learning)...")
            train_env = VecNormalize.load("v7_2/vec_normalize.pkl", train_env)
            train_env.training = True
            train_env.norm_reward = True
            model.set_env(train_env)
            
        print("\n[CURRICULUM LEARNING] Bắt đầu huấn luyện theo từng cấp độ độ trễ (T+0 -> T+1 -> T+3)...")

            
        CONFIG.T_PLUS_SETTLEMENT = 0

            
        print("Giai đoạn 1: Huấn luyện với T+0 (1,000,000 steps)...")

            
        model.learn(total_timesteps=1000000, reset_num_timesteps=False)

            
        CONFIG.T_PLUS_SETTLEMENT = 1

            
        print("Giai đoạn 2: Huấn luyện với T+1 (1,000,000 steps)...")

            
        model.learn(total_timesteps=1000000, reset_num_timesteps=False)

            
        CONFIG.T_PLUS_SETTLEMENT = 3

            
        print("Giai đoạn 3: Huấn luyện với T+3 (3,000,000 steps)...")

            
        model.learn(total_timesteps=3000000, reset_num_timesteps=False)
        
        model.save(getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_2/AI_Brain_v7_2.zip'))
        train_env.save("v7_2/vec_normalize.pkl")
        
        print(f"Đang chạy Backtest thực chiến (CÓ TÍNH PHÍ GIAO DỊCH {CONFIG.COST_RATE * 100}%)...")
        print("-------------------------------------------------------")
        
        test_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
            returns_test, ai_test, strategies_test, weights_dim, num_strategies_features, tickers=tickers, dates=dates_test, is_test=True
        )])
        obs = test_env.reset()
        
        done = [False]
        fold_returns = []
        while not done[0]:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, info = test_env.step(action)
            if 'net_return' in info[0]:
                all_test_returns.append(info[0]['net_return'])
                fold_returns.append(info[0]['net_return'])
                

        # Tính lợi nhuận lũy kế cho chu kỳ hiện tại
        fold_profit = (np.prod(1 + np.array(fold_returns)) - 1) * 100
        print(f"💰 KẾT QUẢ CHU KỲ {fold_idx}: Lợi nhuận thực chiến = {fold_profit:+.2f}%")
        print("="*55 + "\n")
        current_start += test_window
        fold_idx += 1
        

    total_profit = (np.prod(1 + np.array(all_test_returns)) - 1) * 100
    print(f"\n🏆 TỔNG LỢI NHUẬN BACKTEST TOÀN BỘ THỜI GIAN: {total_profit:+.2f}%")
    print(f"\nĐã lưu bộ não AI mới nhất vào {getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_2/AI_Brain_v7_2.zip')}. Có thể dùng trực tiếp cho Live Trading ngày mai!")

# --- Centralized Leaderboard Logger ---
import os
import shutil
import pandas as pd
from datetime import datetime

os.makedirs('v7_2', exist_ok=True)

log_file = r'training_leaderboard.csv'
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

old_model_name = f"v7_2/AI_Brain_v7_2.zip"
new_model_name = f"v7_2/AI_Brain_v7_2_Seed{seed_val}_Profit_{total_profit:.2f}.zip"

if os.path.exists(old_model_name):
    shutil.copy(old_model_name, new_model_name)

# Tạo dict chứa các thông số cơ bản
new_row = {
    'Timestamp': timestamp,
    'Version': 'v7_2',
    'Seed': seed_val,
    'Profit (%)': round(total_profit, 2),
    'Model Path': new_model_name,
    'Total Features': ai_features_df.shape[1] // weights_dim,
}

# Tự động quét và lấy toàn bộ các tham số trong class CONFIG
try:
    for k in dir(CONFIG):
        blacklist_cols = ['TEST_WINDOW', 'TRAINING_MODE', 'TRAINING_TIMESTEPS', 'TRAIN_WINDOW']
        if not k.startswith('__') and k not in blacklist_cols:
            new_row[k] = getattr(CONFIG, k)
except NameError:
    pass

# Đọc file cũ nếu có và nối thêm dòng mới
if os.path.exists(log_file):
    try:
        df = pd.read_csv(log_file)
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    except:
        df = pd.DataFrame([new_row])
else:
    df = pd.DataFrame([new_row])

df = df.drop(columns=[c for c in blacklist_cols if c in df.columns], errors='ignore')

df.to_csv(log_file, index=False)

print(f"🎯 Đã lưu log tự động cấu hình vào Leaderboard! Lợi nhuận: {total_profit:.2f}% | Model: {new_model_name}")
# Out:
# [LUẬT 4] KHỞI ĐỘNG HỆ THỐNG HUẤN LUYỆN...
#
# =======================================================
# --- CHẾ ĐỘ HỌC NHANH (FAST SPLIT: 70% Train, 15% Val, 15% Test) ---
# Khởi tạo Mạng Nơ-ron AI (Train: 1667 days, Val: 357 days, Test: 358 days)...
# Using cpu device
#
# [CURRICULUM LEARNING] Bắt đầu huấn luyện theo từng cấp độ độ trễ (T+0 -> T+1 -> T+3)...
# Giai đoạn 1: Huấn luyện với T+0 (100,000 steps)...
# -----------------------------
# | time/              |      |
# |    fps             | 236  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 1024 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.009696064 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | -0.0939     |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.26       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 1           |
# |    value_loss           | 0.642       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.009909042 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.349      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 1           |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008088517 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.369      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0342     |
# |    std                  | 1           |
# |    value_loss           | 0.0618      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.009417914 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.362      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0414     |
# |    std                  | 1           |
# |    value_loss           | 0.045       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 6           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009877288 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.391      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0455     |
# |    std                  | 1           |
# |    value_loss           | 0.0417      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 7           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009155131 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.386      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0455     |
# |    std                  | 1           |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 8           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009509767 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.42       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0491     |
# |    std                  | 1           |
# |    value_loss           | 0.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 9           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009994816 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.3       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.418      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0521     |
# |    std                  | 1           |
# |    value_loss           | 0.0217      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 10           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0103346845 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -65.3        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.389       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0538      |
# |    std                  | 1            |
# |    value_loss           | 0.0149       |
# ------------------------------------------
# Giai đoạn 2: Huấn luyện với T+1 (100,000 steps)...
# ------------------------------
# | time/              |       |
# |    fps             | 348   |
# |    iterations      | 1     |
# |    time_elapsed    | 2     |
# |    total_timesteps | 11264 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011201966 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.418      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0591     |
# |    std                  | 1           |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.013028228 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.437      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0663     |
# |    std                  | 1           |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011917048 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.443      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0638     |
# |    std                  | 1           |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012035114 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.41       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0654     |
# |    std                  | 1           |
# |    value_loss           | 0.00932     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013651366 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.428      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0675     |
# |    std                  | 1           |
# |    value_loss           | 0.00968     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 7           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.014065254 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.439      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.07       |
# |    std                  | 1           |
# |    value_loss           | 0.00912     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 8           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014109244 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.436      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0714     |
# |    std                  | 1           |
# |    value_loss           | 0.00724     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 9           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.014292036 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.438      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0733     |
# |    std                  | 1           |
# |    value_loss           | 0.00765     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 10          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014694025 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.44       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.072      |
# |    std                  | 1           |
# |    value_loss           | 0.00675     |
# -----------------------------------------
# Giai đoạn 3: Huấn luyện với T+3 (300,000 steps)...
# ------------------------------
# | time/              |       |
# |    fps             | 375   |
# |    iterations      | 1     |
# |    time_elapsed    | 2     |
# |    total_timesteps | 21504 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015384932 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.446      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0743     |
# |    std                  | 1           |
# |    value_loss           | 0.00644     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.015799642 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.45       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0753     |
# |    std                  | 1           |
# |    value_loss           | 0.00543     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016381357 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.454      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0754     |
# |    std                  | 1           |
# |    value_loss           | 0.00611     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 198        |
# |    iterations           | 5          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.01651458 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.4      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.444     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0777    |
# |    std                  | 1          |
# |    value_loss           | 0.0053     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 6          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01771066 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -65.4      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.467     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0797    |
# |    std                  | 1          |
# |    value_loss           | 0.00502    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 7           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.018165201 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.442      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0828     |
# |    std                  | 1           |
# |    value_loss           | 0.00531     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 8           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016601896 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.45       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0804     |
# |    std                  | 1           |
# |    value_loss           | 0.00471     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 9           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.018816015 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.465      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.083      |
# |    std                  | 1           |
# |    value_loss           | 0.00463     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 10          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018485056 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.466      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0837     |
# |    std                  | 1           |
# |    value_loss           | 0.00472     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 11          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.019168066 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.458      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0846     |
# |    std                  | 1           |
# |    value_loss           | 0.00457     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 12          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020066759 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.461      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0838     |
# |    std                  | 1           |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 13          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.019740123 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.441      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0849     |
# |    std                  | 1           |
# |    value_loss           | 0.00392     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 201       |
# |    iterations           | 14        |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0187237 |
# |    clip_fraction        | 0.2       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -65.4     |
# |    explained_variance   | 0.994     |
# |    learning_rate        | 5e-05     |
# |    loss                 | -0.464    |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -0.0826   |
# |    std                  | 1         |
# |    value_loss           | 0.00417   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 15          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.020059846 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.455      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0862     |
# |    std                  | 1           |
# |    value_loss           | 0.00415     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 16          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020567322 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.468      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0852     |
# |    std                  | 1           |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 17          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.020069068 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.469      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0846     |
# |    std                  | 1           |
# |    value_loss           | 0.00361     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 18          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022261992 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.47       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0881     |
# |    std                  | 1           |
# |    value_loss           | 0.00335     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 19          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.021623636 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.457      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0889     |
# |    std                  | 1           |
# |    value_loss           | 0.00405     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 20          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020972269 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.436      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0869     |
# |    std                  | 1           |
# |    value_loss           | 0.00324     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 21          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.020174844 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.47       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0865     |
# |    std                  | 1           |
# |    value_loss           | 0.00298     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 22          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.022367544 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.456      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0889     |
# |    std                  | 1           |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 23          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.022800379 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.481      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.092      |
# |    std                  | 1.01        |
# |    value_loss           | 0.00326     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 24          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.022793112 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.48       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0906     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00273     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 25          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.022922374 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.467      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.091      |
# |    std                  | 1.01        |
# |    value_loss           | 0.00273     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 26          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023244062 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.477      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0901     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00308     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 27          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.021993794 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.471      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0892     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 28          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022832438 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.5       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.473      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0906     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00283     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 29          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.022843331 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.6       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.463      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0927     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 30          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023015467 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.6       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.445      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0889     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0029      |
# -----------------------------------------
#
# Đang chạy Backtest trên Test Set (CÓ TÍNH PHÍ GIAO DỊCH 0.01%)...
# -------------------------------------------------------
#
# [06/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BMP: Tỷ trọng 0.0% -> 4.2% | Giá khớp: 114.13
#   > 🟢 MUA BVH: Tỷ trọng 0.0% -> 5.2% | Giá khớp: 47.55
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 3.3% | Giá khớp: 62.01
#   > 🟢 MUA DCM: Tỷ trọng 0.0% -> 4.8% | Giá khớp: 32.59
#   > 🟢 MUA DGW: Tỷ trọng 0.0% -> 2.2% | Giá khớp: 37.31
#   > 🟢 MUA DIG: Tỷ trọng 0.0% -> 6.6% | Giá khớp: 16.22
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 7.5% | Giá khớp: 18.25
#   > 🟢 MUA HCM: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 21.40
#   > 🟢 MUA HDC: Tỷ trọng 0.0% -> 2.6% | Giá khớp: 19.18
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 4.3% | Giá khớp: 13.28
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 8.2% | Giá khớp: 31.61
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 4.7% | Giá khớp: 15.90
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 56.19
#   > 🟢 MUA NLG: Tỷ trọng 0.0% -> 7.0% | Giá khớp: 31.11
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 2.3% | Giá khớp: 19.21
#   > 🟢 MUA PHR: Tỷ trọng 0.0% -> 5.6% | Giá khớp: 50.71
#   > 🟢 MUA PNJ: Tỷ trọng 0.0% -> 9.0% | Giá khớp: 62.46
#   > 🟢 MUA PVD: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 22.44
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 2.4% | Giá khớp: 46.93
#   > 🟢 MUA SSI: Tỷ trọng 0.0% -> 2.1% | Giá khớp: 22.14
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 2.3% | Giá khớp: 11.76
#   > 🟢 MUA VCB: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 61.69
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 57.71
#   > 🟢 MUA VSC: Tỷ trọng 0.0% -> 7.6% | Giá khớp: 12.09
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 4.2%, BVH: 5.2%, CTD: 3.3%, DCM: 4.8%, DGW: 2.2%, DIG: 6.6%, EIB: 7.5%, HCM: 1.4%, HDC: 2.6%, HSG: 4.3%, KDH: 8.2%, MBB: 4.7%, NLG: 7.0%, NT2: 2.3%, PHR: 5.6%, PNJ: 9.0%, PVD: 1.6%, REE: 2.4%, SSI: 2.1%, TCH: 2.3%, VCB: 3.2%, VNM: 1.4%, VSC: 7.6%]
#   📈 Tài sản: -1,259,317 đ | Hiệu suất ngày: -1.26% | Tổng NAV: 98,740,683 đ
#
# [07/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BMP: Tỷ trọng
đ)
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 6.6% -> 5.3% | Giá bán: 15.92 | Giá vốn: 16.22 | Lãi/Lỗ: -1.86% (-23,630 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 6.6% -> 5.4% | Giá bán: 18.35 | Giá vốn: 18.25 | Lãi/Lỗ: +0.54% (+6,215 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 3.6% -> 2.9% | Giá bán: 21.59 | Giá vốn: 21.38 | Lãi/Lỗ: +0.99% (+6,893 đ)
#   > 🟢 MUA HDC: Tỷ trọng 2.9% -> 4.8% | Giá khớp: 19.14
#   > 🟢 MUA HSG: Tỷ trọng 5.8% -> 8.9% | Giá khớp: 13.47
#   > 🩸 CẮT LỖ KDH: Tỷ trọng 6.7% -> 5.4% | Giá bán: 30.70 | Giá vốn: 31.61 | Lãi/Lỗ: -2.89% (-37,683 đ)
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 3.8% -> 3.1% | Giá bán: 16.20 | Giá vốn: 15.90 | Lãi/Lỗ: +1.88% (+13,813 đ)
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 5.7% -> 4.8% | Giá bán: 29.38 | Giá vốn: 31.11 | Lãi/Lỗ: -5.57% (-50,660 đ)
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.9% -> 1.5% | Giá bán: 19.45 | Giá vốn: 19.21 | Lãi/Lỗ: +1.24% (+4,606 đ)
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 4.6% -> 3.7% | Giá bán: 50.61 | Giá vốn: 50.71 | Lãi/Lỗ: -0.21% (-1,833 đ)
#   > 🩸 CẮT LỖ PNJ: Tỷ trọng 7.4% -> 5.9% | Giá bán: 61.95 | Giá vốn: 62.46 | Lãi/Lỗ: -0.83% (-11,759 đ)
#   > 🩸 CẮT LỖ PVD: Tỷ trọng 1.3% -> 1.1% | Giá bán: 21.66 | Giá vốn: 22.44 | Lãi/Lỗ: -3.49% (-8,955 đ)
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 2.1% -> 1.7% | Giá bán: 47.00 | Giá vốn: 46.93 | Lãi/Lỗ: +0.14% (+573 đ)
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 1.0% | Giá khớp: 30.52
#   > 🟢 MUA SSI: Tỷ trọng 4.3% -> 4.5% | Giá khớp: 21.96
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 2.2% -> 1.8% | Giá bán: 11.80 | Giá vốn: 11.76 | Lãi/Lỗ: +0.33% (+1,407 đ)
#   > 🟢 MUA VCB: Tỷ trọng 4.3% -> 5.7% | Giá khớp: 61.36
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 1.2% -> 0.9% | Giá bán: 56.97 | Giá vốn: 57.71 | Lãi/Lỗ: -1.29% (-2,910 đ)
#   > 🟢 MUA VSC: Tỷ trọng 7.6% -> 10.2% | Giá khớp: 12.33
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 5.4%, BVH: 3.4%, CTD: 2.1%, DCM: 6.6%, DGW: 3.5%, DIG: 5.3%, EIB: 5.4%, HCM: 2.9%, HDC: 4.8%, HSG: 8.9%, KDH: 5.4%, MBB: 3.1%, NLG: 4.8%, NT2: 1.5%, PHR: 3.7%, PNJ: 5.9%, PVD: 1.1%, REE: 1.7%, SSI: 4.5%, TCH: 1.8%, VCB: 5.7%, VSC: 10.2%]
#   📈 Tài sản: +906,867 đ | Hiệu suất ngày: +0.93% | Tổng NAV: 98,574,023 đ
#
# [09/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BMP: Tỷ trọng 5.4% -> 7.3% | Giá khớp: 117.62
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 3.4% -> 3.1% | Giá bán: 48.04 | Giá vốn: 47.55 | Lãi/Lỗ: +1.02% (+3,480 đ)
#   > 🟢 MUA CII: Tỷ trọng 0.2% -> 1.9% | Giá khớp: 11.49
#   > 🟢 MUA CTD: Tỷ trọng 2.1% -> 2.4% | Giá khớp: 61.83
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 6.6% -> 6.2% | Giá bán: 32.26 | Giá vốn: 32.61 | Lãi/Lỗ: -1.09% (-4,380 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.5% -> 2.8% | Giá bán: 36.35 | Giá vốn: 36.83 | Lãi/Lỗ: -1.32% (-7,975 đ)
#   > 🟢 MUA DIG: Tỷ trọng 5.3% -> 6.2% | Giá khớp: 15.70
#   > 🟢 MUA EIB: Tỷ trọng 5.4% -> 5.9% | Giá khớp: 18.40
#   > 🟢 MUA HCM: Tỷ trọng 2.9% -> 6.9% | Giá khớp: 21.28
#   > 🩸 CẮT LỖ HDC: Tỷ trọng
đ)
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 0.5% -> 0.1% | Giá bán: 196.00 | Giá vốn: 205.77 | Lãi/Lỗ: -4.76% (-24,316 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 59.20
#   > 🟢 MUA VSC: Tỷ trọng 2.7% -> 4.0% | Giá khớp: 18.45
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 3.7%, BVH: 5.4%, CII: 4.2%, CTD: 2.9%, DCM: 2.3%, DGW: 1.7%, DIG: 2.8%, EIB: 2.6%, HCM: 5.9%, HDC: 4.3%, HPG: 3.7%, HSG: 2.2%, HT1: 2.2%, KBC: 2.1%, KDC: 4.0%, KDH: 5.0%, MWG: 2.0%, NLG: 4.9%, PDR: 2.3%, PHR: 6.2%, PNJ: 9.6%, SSI: 3.2%, TCH: 4.3%, VCB: 3.2%, VHC: 2.2%, VSC: 4.0%]
#   📈 Tài sản: -716,616 đ | Hiệu suất ngày: -0.54% | Tổng NAV: 131,020,268 đ
#
# [12/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 0.2% -> 0.7% | Giá khớp: 41.05
#   > 🟢 MUA BMP: Tỷ trọng 3.7% -> 5.2% | Giá khớp: 135.00
#   > 🟢 MUA BVH: Tỷ trọng 5.4% -> 5.6% | Giá khớp: 65.60
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 4.2% -> 3.6% | Giá bán: 17.35 | Giá vốn: 16.84 | Lãi/Lỗ: +3.01% (+20,723 đ)
#   > 🩸 CẮT LỖ CTD: Tỷ trọng 2.9% -> 2.5% | Giá bán: 70.80 | Giá vốn: 71.83 | Lãi/Lỗ: -1.45% (-6,906 đ)
#   > 🟢 MUA CTG: Tỷ trọng 0.3% -> 0.6% | Giá khớp: 33.40
#   > 🟢 MUA DCM: Tỷ trọng 2.3% -> 3.0% | Giá khớp: 38.20
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 1.7% -> 1.5% | Giá bán: 38.90 | Giá vốn: 39.11 | Lãi/Lỗ: -0.55% (-1,547 đ)
#   > 🟢 MUA DIG: Tỷ trọng 2.8% -> 3.7% | Giá khớp: 12.60
#   > 🟢 MUA EIB: Tỷ trọng 2.6% -> 4.5% | Giá khớp: 20.70
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 5.9% -> 5.2% | Giá bán: 27.00 | Giá vốn: 27.52 | Lãi/Lỗ: -1.89% (-18,611 đ)
#   > 🩸 CẮT LỖ HDC: Tỷ trọng 4.3% -> 4.0% | Giá bán: 15.40 | Giá vốn: 15.54 | Lãi/Lỗ: -0.92% (-3,751 đ)
#   > 🩸 CẮT LỖ HPG: Tỷ trọng 3.7% -> 3.3% | Giá bán: 23.20 | Giá vốn: 23.64 | Lãi/Lỗ: -1.86% (-11,529 đ)
#   > 🟢 MUA HSG: Tỷ trọng 2.2% -> 2.5% | Giá khớp: 11.70
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 2.2% -> 1.9% | Giá bán: 13.60 | Giá vốn: 13.85 | Lãi/Lỗ: -1.85% (-6,676 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 2.1% -> 0.0% | Giá bán: 30.70 | Giá vốn: 30.03 | Lãi/Lỗ: +2.23% (+61,130 đ)
#   > 🩸 CẮT LỖ KDC: Tỷ trọng 4.0% -> 3.5% | Giá bán: 49.90 | Giá vốn: 50.75 | Lãi/Lỗ: -1.69% (-11,271 đ)
#   > 🟢 MUA MSN: Tỷ trọng 0.8% -> 1.1% | Giá khớp: 71.10
#   > 🩸 CẮT LỖ MWG: Tỷ trọng 2.0% -> 1.7% | Giá bán: 76.40 | Giá vốn: 78.73 | Lãi/Lỗ: -2.98% (-9,868 đ)
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 4.9% -> 4.3% | Giá bán: 25.40 | Giá vốn: 25.62 | Lãi/Lỗ: -0.88% (-7,154 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 2.3% -> 2.0% | Giá bán: 14.90 | Giá vốn: 15.14 | Lãi/Lỗ: -1.60% (-6,013 đ)
#   > 🩸 CẮT LỖ PNJ: Tỷ trọng 9.6% -> 8.4% | Giá bán: 62.00 | Giá vốn: 65.52 | Lãi/Lỗ: -5.38% (-85,293 đ)
#   > 🟢 MUA SSI: Tỷ trọng 3.2% -> 3.4% | Giá khớp: 26.15
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 4
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 5.3% -> 4.2% | Giá bán: 36.30 | Giá vốn: 37.77 | Lãi/Lỗ: -3.89% (-56,444 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 2.4% -> 1.9% | Giá bán: 13.15 | Giá vốn: 12.71 | Lãi/Lỗ: +3.46% (+22,183 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 2.8% -> 2.2% | Giá bán: 21.45 | Giá vốn: 21.01 | Lãi/Lỗ: +2.06% (+15,788 đ)
#   > 🟢 MUA HCM: Tỷ trọng 3.7% -> 3.9% | Giá khớp: 27.50
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 3.9% -> 3.1% | Giá bán: 16.27 | Giá vốn: 15.66 | Lãi/Lỗ: +3.90% (+38,097 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 2.0% -> 1.6% | Giá bán: 24.00 | Giá vốn: 23.64 | Lãi/Lỗ: +1.52% (+8,422 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 4.2% -> 3.4% | Giá bán: 12.05 | Giá vốn: 12.02 | Lãi/Lỗ: +0.24% (+2,799 đ)
#   > 🟢 MUA KBC: Tỷ trọng 4.2% -> 5.0% | Giá khớp: 31.05
#   > 🩸 CẮT LỖ KDC: Tỷ trọng 2.0% -> 0.0% | Giá bán: 50.40 | Giá vốn: 50.75 | Lãi/Lỗ: -0.71% (-19,077 đ)
#   > 🟢 MUA KDH: Tỷ trọng 5.0% -> 5.6% | Giá khớp: 23.30
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 2.8% -> 2.2% | Giá bán: 25.20 | Giá vốn: 25.20 | Lãi/Lỗ: -0.01% (-76 đ)
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 0.6% -> 0.5% | Giá bán: 72.50 | Giá vốn: 72.04 | Lãi/Lỗ: +0.63% (+1,080 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 3.5% -> 2.8% | Giá bán: 79.10 | Giá vốn: 79.07 | Lãi/Lỗ: +0.03% (+243 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 6.7% -> 5.9% | Giá bán: 27.65 | Giá vốn: 26.55 | Lãi/Lỗ: +4.12% (+46,814 đ)
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 1.1% -> 0.0% | Giá bán: 15.15 | Giá vốn: 15.14 | Lãi/Lỗ: +0.05% (+713 đ)
#   > 🟢 MUA PHR: Tỷ trọng 3.7% -> 5.0% | Giá khớp: 64.90
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 7.8% -> 7.7% | Giá bán: 68.00 | Giá vốn: 66.01 | Lãi/Lỗ: +3.00% (+4,469 đ)
#   > 🟢 MUA PVD: Tỷ trọng 0.4% -> 1.9% | Giá khớp: 30.25
#   > 🔥 CHỐT LỜI PVT: Tỷ trọng 1.4% -> 1.1% | Giá bán: 19.75 | Giá vốn: 19.30 | Lãi/Lỗ: +2.32% (+9,038 đ)
#   > 🩸 CẮT LỖ REE: Tỷ trọng 2.1% -> 1.7% | Giá bán: 50.90 | Giá vốn: 50.91 | Lãi/Lỗ: -0.04% (-211 đ)
#   > 🟢 MUA SSI: Tỷ trọng 2.3% -> 4.2% | Giá khớp: 27.70
#   > 🟢 MUA STB: Tỷ trọng 2.9% -> 4.4% | Giá khớp: 72.10
#   > 🟢 MUA TCH: Tỷ trọng 1.7% -> 2.3% | Giá khớp: 15.30
#   > 🟢 MUA VCB: Tỷ trọng 2.1% -> 2.2% | Giá khớp: 62.20
#   > 🟢 MUA VHC: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 58.50
#   > 🟢 MUA VNM: Tỷ trọng 1.7% -> 3.3% | Giá khớp: 59.00
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 7.1% -> 5.6% | Giá bán: 20.25 | Giá vốn: 19.12 | Lãi/Lỗ: +5.88% (+113,177 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 1.8%, BMP: 4.0%, BVH: 3.9%, CII: 2.7%, CTD: 5.1%, DCM: 4.2%, DIG: 1.9%, EIB: 2.2%, HCM: 3.9%, HDC: 3.1%, HPG: 1.6%, HSG: 3.4%, KBC: 5.0%, KDH: 5.6%, MBB: 2.2%, MWG: 2.8%, NLG: 5.9%, PHR: 5.0%, PNJ: 7.7%, PVD: 1.9%, PVT: 1.1%, REE: 1.7%, SSI: 4.2%, STB: 4.4%, TCH: 2.3%, VCB: 2.2%, VNM: 3.3%, VSC: 5.6%]
#   📈 Tài sản: +729,580 đ | Hiệu suất ngày: +0.54% | Tổng NAV: 134,991,444 đ
#
# 🏆 TỔNG LỢI NHUẬN TEST SET: +34.99%
# 🎯 Đã lưu log tự động cấu hình vào Leaderboard! Lợi nhuận: 34.99% | Model: v7_2/AI_Brain_v7_2_Seed321_Profit_34.99.zip

# %% [markdown]
# ## Kết quả

# %%
# Đoạn code đánh giá chuyên sâu (Evaluation & Metrics)
# Bạn hãy chạy (Run) cell này sau khi model đã train xong.

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# ---------------------------------------------
# Cài đặt Seaborn style để biểu đồ đẹp hơn
# ---------------------------------------------
sns.set_theme(style="whitegrid")

# Giả sử các biến từ hàm load_data() đã có trong bộ nhớ: 
# returns_df, ai_features_df, strategies_features_df, tickers, dates, weights_dim

try:
    total_days = len(returns_df)

    # Lấy 15% dữ liệu cuối cùng để backtest (giống fast_split)
    test_ratio = 0.15
    test_size = int(total_days * test_ratio)
    test_start = total_days - test_size

    returns_test = returns_df.iloc[test_start:]
    ai_test = ai_features_df.iloc[test_start:]
    strategies_test = strategies_features_df.iloc[test_start:]
    dates_test = dates[test_start:]

    from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
    from stable_baselines3 import PPO

    model_path = getattr(CONFIG, 'SAVE_MODEL_PATH', 'v7_2/AI_Brain_v7_2.zip')
    env_path = 'v7_2/vec_normalize.pkl'

    print(f"🔄 Đang nạp bộ não từ {model_path} để tiến hành phân tích...")
    model = PPO.load(model_path)
    
    test_env = DummyVecEnv([lambda: AdvancedPortfolioEnv(
            returns_test, ai_test, strategies_test, weights_dim, num_strategies_features, tickers=tickers, dates=dates_test, is_test=True
        )])
    test_env = VecNormalize.load(env_path, test_env)
    test_env.training = False
    test_env.norm_reward = False
    
    obs = test_env.reset()
    done = [False]
    
    portfolio_returns = []
    portfolio_dates = []
    benchmark_returns = [] # Benchmark: Lợi nhuận Equal Weight của danh mục
    action_history = []
    
    step_idx = 0
    while not done[0]:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = test_env.step(action)
        
        if 'net_return' in info[0]:
            portfolio_returns.append(info[0]['net_return'])
            portfolio_dates.append(pd.to_datetime(dates_test[step_idx], format='%d/%m/%Y'))
            
            # Tính benchmark (Equal Weight)
            bm_ret = np.mean(returns_test.iloc[step_idx].values)
            benchmark_returns.append(bm_ret)
            
            action_history.append(action[0])
            
        step_idx += 1
        
    perf_df = pd.DataFrame({
        'AI_Strategy': portfolio_returns,
        'Benchmark_EQ': benchmark_returns
    }, index=portfolio_dates)
    
    # ---------------------------------------------------------
    # 1. TÍNH TOÁN CÁC CHỈ SỐ RỦI RO VÀ HIỆU SUẤT (METRICS)
    # ---------------------------------------------------------
    def calc_metrics(returns):
        cum_ret = (1 + returns).cumprod()
        total_return = cum_ret.iloc[-1] - 1
        annualized_return = (1 + total_return)**(252 / len(returns)) - 1
        sharpe_ratio = np.sqrt(252) * (returns.mean() / returns.std()) if returns.std() != 0 else 0
        
        rolling_max = cum_ret.cummax()
        drawdowns = (cum_ret - rolling_max) / rolling_max
        max_drawdown = drawdowns.min()
        
        win_rate = (returns > 0).mean()
        return total_return, annualized_return, sharpe_ratio, max_drawdown, win_rate
        
    ai_tot, ai_ann, ai_sharpe, ai_mdd, ai_win = calc_metrics(perf_df['AI_Strategy'])
    bm_tot, bm_ann, bm_sharpe, bm_mdd, bm_win = calc_metrics(perf_df['Benchmark_EQ'])
    
    cov = np.cov(perf_df['AI_Strategy'], perf_df['Benchmark_EQ'])[0][1]
    var = np.var(perf_df['Benchmark_EQ'])
    beta = cov / var if var > 0 else 1
    alpha = ai_ann - (beta * bm_ann)
    
    print("\n=========================================================")
    print("📊 BÁO CÁO HIỆU SUẤT ĐẦU TƯ (BACKTEST)")
    print("=========================================================")
    print(f"{str('Chỉ số').ljust(20)} | {str('AI Strategy').ljust(15)} | {str('Benchmark (EQ)').ljust(15)}")
    print("-" * 55)
    print(f"{str('Tổng lợi nhuận').ljust(20)} | {ai_tot*100:>14.2f}% | {bm_tot*100:>14.2f}%")
    print(f"{str('Lợi nhuận năm').ljust(20)} | {ai_ann*100:>14.2f}% | {bm_ann*100:>14.2f}%")
    print(f"{str('Sharpe Ratio').ljust(20)} | {ai_sharpe:>14.2f}  | {bm_sharpe:>14.2f} ")
    print(f"{str('Max Drawdown').ljust(20)} | {ai_mdd*100:>14.2f}% | {bm_mdd*100:>14.2f}%")
    print(f"{str('Win Rate (Ngày)').ljust(20)} | {ai_win*100:>14.2f}% | {bm_win*100:>14.2f}%")
    print("-" * 55)
    print(f"Alpha (So với BM): {alpha*100:.2f}% (Lợi nhuận vượt trội sau khi trừ rủi ro thị trường)")
    print(f"Beta  (So với BM): {beta:.2f} (Độ nhạy cảm với biến động chung)")
    
    # ---------------------------------------------------------
    # 2. VẼ BIỂU ĐỒ EQUITY CURVE (LỢI NHUẬN TÍCH LŨY)
    # ---------------------------------------------------------
    fig, ax = plt.subplots(figsize=(12, 6))
    ((1 + perf_df).cumprod() - 1).plot(ax=ax, linewidth=2)
    plt.title("So sánh Lợi nhuận Tích lũy (Equity Curve): AI vs Benchmark", fontsize=14, fontweight='bold')
    plt.ylabel("Lợi nhuận (%)")
    plt.xlabel("Thời gian")
    
    import matplotlib.ticker as mtick
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.show()

    # ---------------------------------------------------------
    # 3. PHÂN TÍCH HÀNH VI (ALLOCATION HISTORY)
    # ---------------------------------------------------------
    action_df = pd.DataFrame(action_history, columns=tickers, index=portfolio_dates)
    action_df = action_df.loc[:, action_df.max() > 0.01]
    
    mean_alloc = action_df.mean().sort_values(ascending=False)
    print("\n=========================================================")
    print("🔍 PHÂN TÍCH HÀNH VI: AI YÊU THÍCH CỔ PHIẾU NÀO NHẤT?")
    print("=========================================================")
    print(mean_alloc.head(10).apply(lambda x: f"{x*100:.2f}%").to_string())
    
    action_df['CASH'] = 1.0 - action_df.sum(axis=1)
    action_df['CASH'] = action_df['CASH'].clip(lower=0)
    
    fig2, ax2 = plt.subplots(figsize=(14, 7))
    top_cols = list(mean_alloc.head(10).index) + ['CASH']
    action_df[top_cols].plot.area(ax=ax2, colormap='tab20', alpha=0.8, linewidth=0)
    plt.title("Biến động Phân bổ Tỷ trọng (Portfolio Allocation) theo thời gian", fontsize=14, fontweight='bold')
    plt.ylabel("Tỷ trọng (%)")
    plt.xlabel("Thời gian")
    plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    ax2.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.tight_layout()
    plt.show()
    
    # ---------------------------------------------------------
    # 4. KẾT LUẬN HÀNH VI: BÁN NON HAY GỒNG LÃI?
    # ---------------------------------------------------------
    cash_holdings = action_df['CASH'].mean()
    turnover_rate = action_df.drop(columns=['CASH']).diff().abs().sum(axis=1).mean()
    
    print("\n=========================================================")
    print("💡 ĐÁNH GIÁ PHONG CÁCH GIAO DỊCH CỦA AI")
    print("=========================================================")
    print(f"- Tỷ trọng Tiền mặt trung bình: {cash_holdings*100:.2f}% ")
    if cash_holdings > 0.5:
        print("  -> Phong cách: Rất an toàn (Phòng thủ). AI thường xuyên ôm tiền đứng ngoài.")
    elif cash_holdings < 0.1:
        print("  -> Phong cách: Tấn công (Aggressive). AI gần như lúc nào cũng full cổ phiếu.")
    else:
        print("  -> Phong cách: Cân bằng. Biết tiến biết lùi.")
        
    print(f"- Tốc độ xoay vòng vốn (Turnover/ngày): {turnover_rate*100:.2f}%")
    if turnover_rate > 0.3:
        print("  -> AI lướt sóng (T+) rất nhiều. Có xu hướng chốt non nhanh để bảo toàn rủi ro.")
    elif turnover_rate < 0.05:
        print("  -> AI có xu hướng Buy & Hold (Gồng lãi/lỗ) dài hạn, ít nhảy nhót.")
    else:
        print("  -> AI giao dịch ở mức độ vừa phải, luân chuyển dòng tiền hợp lý.")

except Exception as e:
    import traceback
    print(f"Không thể chạy đánh giá. Lỗi: {e}")
    traceback.print_exc()
# Out:
# 🔄 Đang nạp bộ não từ v7_2/AI_Brain_v7_2.zip để tiến hành phân tích...
#
# [07/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BMP: Tỷ trọng 0.0% -> 5.6% | Giá khớp: 117.53
#   > 🟢 MUA BVH: Tỷ trọng 0.0% -> 3.2% | Giá khớp: 47.84
#   > 🟢 MUA CII: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 11.32
#   > 🟢 MUA CTD: Tỷ trọng 0.0% -> 2.7% | Giá khớp: 61.66
#   > 🟢 MUA DCM: Tỷ trọng 0.0% -> 6.0% | Giá khớp: 32.49
#   > 🟢 MUA DGW: Tỷ trọng 0.0% -> 5.3% | Giá khớp: 36.35
#   > 🟢 MUA DIG: Tỷ trọng 0.0% -> 8.0% | Giá khớp: 15.66
#   > 🟢 MUA EIB: Tỷ trọng 0.0% -> 8.1% | Giá khớp: 18.20
#   > 🟢 MUA HCM: Tỷ trọng 0.0% -> 4.4% | Giá khớp: 21.36
#   > 🟢 MUA HDC: Tỷ trọng 0.0% -> 3.6% | Giá khớp: 18.91
#   > 🟢 MUA HSG: Tỷ trọng 0.0% -> 7.1% | Giá khớp: 13.28
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 2.8% | Giá khớp: 30.75
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 3.6% | Giá khớp: 16.24
#   > 🟢 MUA NLG: Tỷ trọng 0.0% -> 3.0% | Giá khớp: 29.69
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 2.0% | Giá khớp: 18.80
#   > 🟢 MUA PHR: Tỷ trọng 0.0% -> 3.5% | Giá khớp: 49.83
#   > 🟢 MUA PNJ: Tỷ trọng 0.0% -> 5.4% | Giá khớp: 61.04
#   > 🟢 MUA PVD: Tỷ trọng 0.0% -> 0.5% | Giá khớp: 21.66
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 2.6% | Giá khớp: 47.52
#   > 🟢 MUA SSI: Tỷ trọng 0.0% -> 5.2% | Giá khớp: 21.82
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 2.7% | Giá khớp: 11.59
#   > 🟢 MUA VCB: Tỷ trọng 0.0% -> 5.3% | Giá khớp: 61.29
#   > 🟢 MUA VSC: Tỷ trọng 0.0% -> 9.3% | Giá khớp: 12.09
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 5.6%, BVH: 3.2%, CTD: 2.7%, DCM: 6.0%, DGW: 5.3%, DIG: 8.0%, EIB: 8.1%, HCM: 4.4%, HDC: 3.6%, HSG: 7.1%, KDH: 2.8%, MBB: 3.6%, NLG: 3.0%, NT2: 2.0%, PHR: 3.5%, PNJ: 5.4%, REE: 2.6%, SSI: 5.2%, TCH: 2.7%, VCB: 5.3%, VSC: 9.3%]
#   📈 Tài sản: -856,588 đ | Hiệu suất ngày: -0.86% | Tổng NAV: 99,143,412 đ
#
# [08/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 3.2% -> 2.6% | Giá bán: 48.43 | Giá vốn: 47.84 | Lãi/Lỗ: +1.22% (+6,264 đ)
#   > 🩸 CẮT LỖ CTD: Tỷ trọng 2.7% -> 2.2% | Giá bán: 61.03 | Giá vốn: 61.66 | Lãi/Lỗ: -1.03% (-4,508 đ)
#   > 🟢 MUA DCM: Tỷ trọng 6.0% -> 6.8% | Giá khớp: 32.68
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 5.3% -> 4.4% | Giá bán: 36.44 | Giá vốn: 36.35 | Lãi/Lỗ: +0.24% (+2,035 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 8.0% -> 6.7% | Giá bán: 15.92 | Giá vốn: 15.66 | Lãi/Lỗ: +1.65% (+21,536 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 8.1% -> 6.7% | Giá bán: 18.35 | Giá vốn: 18.20 | Lãi/Lỗ: +0.81% (+10,663 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 4.4% -> 3.7% | Giá bán: 21.59 | Giá vốn: 21.36 | Lãi/Lỗ: +1.07% (+7,609 đ)
#   > 🟢 MUA HDC: Tỷ trọng 3.6% -> 5.0% | Giá khớp: 19.14
#   > 🟢 MUA HSG: Tỷ trọng 7.1% -> 9.3% | Giá khớp: 13.47
#   > 🩸 CẮT LỖ KDH: Tỷ trọng 2.8% -> 2.3% | Giá bán: 30.70 | Giá vốn: 30.75 | Lãi/Lỗ: -0.17% (-781 đ)
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 3.6% -> 3.0% | Giá bán: 16.20 | Giá vốn: 16.24 | Lãi/Lỗ: -0.26% (-1,488 đ)
#   > 🟢 MUA NLG: Tỷ trọng 3.0% -> 5.0% | Giá khớp: 29.38
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 2.0% -> 1.7% | Giá bán: 19.45 | Giá vốn: 18.80 | Lãi/Lỗ: +3.45% (+11,274 đ)
#   > 🔥 CHỐT LỜI PHR: Tỷ trọng 3.5% -> 2.9% | Giá bán: 50.61 | Giá vốn: 49.83 | Lãi/Lỗ: +1.56% (+8,810 đ)
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 5.4% -> 4.5% | Giá bán: 61.95 | Giá vốn: 61.04 | Lãi/Lỗ: +1.48% (+12,985 đ)
#   > 🩸 CẮT LỖ REE: Tỷ trọng 2.6% -> 2.2% | Giá bán: 47.00 | Giá vốn: 47.52 | Lãi/Lỗ: -1.10% (-4,672 đ)
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 1.0% | Giá khớp: 30.52
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 5.2% -> 4.7% | Giá bán: 21.96 | Giá vốn: 21.82 | Lãi/Lỗ: +0.63% (+3,014 đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 2.7% -> 2.3% | Giá bán: 11.80 | Giá vốn: 11.59 | Lãi/Lỗ: +1.80% (+7,889 đ)
#   > 🟢 MUA VCB: Tỷ trọng 5.3% -> 5.9% | Giá khớp: 61.36
#   > 🟢 MUA VSC: Tỷ trọng 9.3% -> 10.6% | Giá khớp: 12.33
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 5.6%, BVH: 2.6%, CTD: 2.2%, DCM: 6.8%, DGW: 4.4%, DIG: 6.7%, EIB: 6.7%, HCM: 3.7%, HDC: 5.0%, HSG: 9.3%, KDH: 2.3%, MBB: 3.0%, NLG: 5.0%, NT2: 1.7%, PHR: 2.9%, PNJ: 4.5%, REE: 2.2%, SSI: 4.7%, TCH: 2.3%, VCB: 5.9%, VSC: 10.6%]
#   📈 Tài sản: +954,627 đ | Hiệu suất ngày: +0.96% | Tổng NAV: 100,098,039 đ
#
# [09/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA
đ)
#   > 🟢 MUA BVH: Tỷ trọng 3.2% -> 4.7% | Giá khớp: 48.53
#   > 🩸 CẮT LỖ CII: Tỷ trọng 2.0% -> 1.7% | Giá bán: 11.32 | Giá vốn: 11.47 | Lãi/Lỗ: -1.29% (-3,985 đ)
#   > 🟢 MUA CTD: Tỷ trọng 2.5% -> 3.7% | Giá khớp: 62.10
#   > 🟢 MUA DCM: Tỷ trọng 6.4% -> 9.1% | Giá khớp: 31.07
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.8% -> 3.2% | Giá bán: 35.96 | Giá vốn: 36.35 | Lãi/Lỗ: -1.08% (-6,356 đ)
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 6.1% -> 5.4% | Giá bán: 18.10 | Giá vốn: 18.20 | Lãi/Lỗ: -0.56% (-4,132 đ)
#   > 🟢 MUA HAG: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 11.65
#   > 🟢 MUA HCM: Tỷ trọng 7.1% -> 7.4% | Giá khớp: 20.68
#   > 🩸 CẮT LỖ HDC: Tỷ trọng 4.3% -> 3.6% | Giá bán: 18.25 | Giá vốn: 18.98 | Lãi/Lỗ: -3.83% (-25,593 đ)
#   > 🟢 MUA HPG: Tỷ trọng 0.8% -> 2.5% | Giá khớp: 18.99
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 2.0% -> 1.7% | Giá bán: 30.88 | Giá vốn: 30.75 | Lãi/Lỗ: +0.41% (+1,280 đ)
#   > 🟢 MUA MBB: Tỷ trọng 2.5% -> 3.0% | Giá khớp: 15.86
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 4.3% -> 3.6% | Giá bán: 28.54 | Giá vốn: 29.57 | Lãi/Lỗ: -3.48% (-23,166 đ)
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.4% -> 1.2% | Giá bán: 19.40 | Giá vốn: 18.80 | Lãi/Lỗ: +3.18% (+7,129 đ)
#   > 🟢 MUA PHR: Tỷ trọng 2.5% -> 2.8% | Giá khớp: 48.85
#   > 🩸 CẮT LỖ PNJ: Tỷ trọng 3.8% -> 3.2% | Giá bán: 60.53 | Giá vốn: 61.04 | Lãi/Lỗ: -0.85% (-5,080 đ)
#   > 🟢 MUA PVD: Tỷ trọng 0.3% -> 1.2% | Giá khớp: 21.66
#   > 🩸 CẮT LỖ REE: Tỷ trọng 1.9% -> 1.6% | Giá bán: 47.15 | Giá vốn: 47.52 | Lãi/Lỗ: -0.79% (-2,263 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 0.8% -> 0.7% | Giá bán: 32.80 | Giá vốn: 30.52 | Lãi/Lỗ: +7.46% (+9,857 đ)
#   > 🩸 CẮT LỖ SSI: Tỷ trọng 6.5% -> 5.5% | Giá bán: 21.07 | Giá vốn: 21.78 | Lãi/Lỗ: -3.29% (-33,484 đ)
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 1.9% -> 1.6% | Giá bán: 11.10 | Giá vốn: 11.59 | Lãi/Lỗ: -4.24% (-12,713 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 5.0% -> 4.2% | Giá bán: 60.70 | Giá vốn: 61.30 | Lãi/Lỗ: -0.98% (-7,741 đ)
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 9.1% -> 7.6% | Giá bán: 12.13 | Giá vốn: 12.12 | Lãi/Lỗ: +0.06% (+913 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 6.4%, BVH: 4.7%, CII: 1.7%, CTD: 3.7%, DCM: 9.1%, DGW: 3.2%, DIG: 6.3%, EIB: 5.4%, HCM: 7.4%, HDC: 3.6%, HPG: 2.5%, HSG: 7.9%, KDH: 1.7%, MBB: 3.0%, NLG: 3.6%, NT2: 1.2%, PHR: 2.8%, PNJ: 3.2%, PVD: 1.2%, REE: 1.6%, SSI: 5.5%, TCH: 1.6%, VCB: 4.2%, VSC: 7.6%]
#   📈 Tài sản: -1,956,535 đ | Hiệu suất ngày: -1.97% | Tổng NAV: 97,396,098 đ
#
# [13/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 6.4% -> 5.4% | Giá bán: 111.52 | Giá vốn: 117.55 | Lãi/Lỗ: -5.14% (-47,042 đ)
#   > 🟢 MUA BVH: Tỷ trọng 4.7% -> 5.0% | Giá khớp: 48.53
#   > 🩸 CẮT LỖ CII: Tỷ trọng 1.7% -> 1.4% | Giá bán: 11.41 | Giá vốn: 11.47 | Lãi/Lỗ: -0.50% (-1,204 đ)
#   > 🟢 MUA CTD: Tỷ trọng 3.7% -> 5.7% | Giá khớp: 63.81
#   > 🟢 MUA DCM: Tỷ trọng 9.1% -> 12.5% | Giá khớp: 31.64
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.2% -> 1.1% | Giá bán: 36.06 | Giá vốn: 36.35 | Lãi/Lỗ: -0.81% (-16,479 đ)
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 6.3% -> 5.7% | Giá bán: 15.57 | Giá vốn: 15.66 | Lãi/Lỗ: -0.58% (-3,340 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 5.4% -> 4.9% | Giá bán: 18.30 | Giá vốn: 18.20 | Lãi/Lỗ: +0.54% (+2,318 đ)
#   > 🟢 MUA HAG: Tỷ trọng 0.1% -> 1.3% | Giá khớp: 11.80
#   > 🟢 MUA HCM: Tỷ trọng 7.4% -> 8.4% | Giá khớp: 21.13
#   > 🩸 CẮT LỖ HDC: Tỷ trọng 3.6% -> 3.1% | Giá bán: 18.36 | Giá vốn: 18.98 | Lãi/Lỗ: -3.25% (-16,855 đ)
#   > 🟢 MUA HPG: Tỷ trọng 2.5% -> 4.6% | Giá khớp: 19.25
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 7.9% -> 6.8% | Giá bán: 12.98 | Giá vốn: 13.32 | Lãi/Lỗ: -2.59% (-29,648 đ)
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 1.7% -> 0.0% | Giá bán: 31.29 | Giá vốn: 30.75 | Lãi/Lỗ: +1.75% (+28,427 đ)
#   > 🟢 MUA MBB: Tỷ trọng 3.0% -> 3.7% | Giá khớp: 16.12
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 56.49
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 3.6% -> 3.1% | Giá bán: 28.76 | Giá vốn: 29.57 | Lãi/Lỗ: -2.74% (-11,955 đ)
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.2% -> 0.0% | Giá bán: 19.40 | Giá vốn: 18.80 | Lãi/Lỗ: +3.18% (+37,414 đ)
#   > 🟢 MUA PHR: Tỷ trọng 2.8% -> 3.3% | Giá khớp: 48.56
#   > 🩸 CẮT LỖ PNJ: Tỷ trọng 3.2% -> 2.1% | Giá bán: 60.91 | Giá vốn: 61.04 | Lãi/Lỗ: -0.22% (-2,432 đ)
#   > 🟢 MUA PVD: Tỷ trọng 1.2% -> 3.6% | Giá khớp: 22.25
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 1.6% -> 1.3% | Giá bán: 47.66 | Giá vốn: 47.52 | Lãi/Lỗ: +0.28% (+641 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 0.7% -> 0.6% | Giá bán: 33.96 | Giá vốn: 30.52 | Lãi/Lỗ: +11.26% (+11,546 đ)
#   > 🩸 CẮT LỖ SSI: Tỷ trọng 5.5% -> 4.7% | Giá bán: 21.47 | Giá vốn: 21.78 | Lãi/Lỗ: -1.45% (-11,474 đ)
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 1.6% -> 0.0% | Giá bán: 11.43 | Giá vốn: 11.59 | Lãi/Lỗ: -1.39% (-21,894 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 4.2% -> 3.6% | Giá bán: 61.03 | Giá vốn: 61.30 | Lãi/Lỗ: -0.45% (-2,722 đ)
#   > 🟢 MUA VSC: Tỷ trọng 7.6% -> 7.9% | Giá khớp: 12.13
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 5.4%, BVH: 5.0%, CII: 1.4%, CTD: 5.7%, DCM: 12.5%, DGW: 1.1%, DIG: 5.7%, EIB: 4.9%, HAG: 1.3%, HCM: 8.4%, HDC: 3.1%, HPG: 4.6%, HSG: 6.8%, MBB: 3.7%, NLG: 3.1%, PHR: 3.3%, PNJ: 2.1%, PVD: 3.6%, REE: 1.3%, SSI: 4.7%, VCB: 3.6%, VSC: 7.9%]
#   📈 Tài sản: +1,066,067 đ | Hiệu suất ngày: +1.09% | Tổng NAV: 98,462,165 đ
#
# [14/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 5.4% -> 4.4% | Giá bán: 108.04 | Giá vốn: 117.55 | Lãi/Lỗ: -8.10% (-77,032 đ)
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 5.0% -> 4.1% | Giá bán: 49.80 | Giá vốn: 48.11 | Lãi/Lỗ: +3.50% (+30,862 đ)
#   > 🟢 MUA CII: Tỷ trọng 1.4% -> 2.4% | Giá khớp: 11.36
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 5.7% -> 4.7% | Giá bán: 63.45 | Giá vốn: 62.52 | Lãi/Lỗ: +1.47% (+14,710 đ)
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 12.5% -> 10.2% | Giá bán: 31.74 | Giá vốn: 31.96 | Lãi/Lỗ: -0.70% (-15,322 đ)
#   > 🟢 MUA DGW: Tỷ trọng 1.1% -> 2.5% | Giá khớp: 36.01
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 5.7% -> 4.7% | Giá bán: 15.49 | Giá vốn: 15.66 | Lãi/Lỗ: -1.10% (-11,022 đ)
#   > 🟢 MUA EIB: Tỷ trọng 4.9% -> 5.7% | Giá khớp: 18.25
#   > 🩸 CẮT LỖ HAG: Tỷ trọng 1.3% -> 1.0% | Giá bán: 11.55 | Giá vốn: 11.79 | Lãi/Lỗ: -2.01% (-4,466 đ)
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 8.4% -> 6.9% | Giá bán: 20.94 | Giá vốn: 21.27 | Lãi/Lỗ: -1.58% (-23,223 đ)
#   > 🩸 CẮT LỖ HDC: Tỷ trọng 3.1% -> 0.6% | Giá bán: 18.13 | Giá vốn: 18.98 | Lãi/Lỗ: -4.46% (-108,490 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 4.6% -> 3.8% | Giá bán: 19.21 | Giá vốn: 19.17 | Lãi/Lỗ: +0.21% (+1,702 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 6.8% -> 5.6% | Giá bán: 12.76 | Giá vốn: 13.32 | Lãi/Lỗ: -4.24% (-50,431 đ)
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.5% | Giá khớp: 31.02
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 3.7% -> 3.1% | Giá bán: 15.98 | Giá vốn: 16.17 | Lãi/Lỗ: -1.16% (-7,630 đ)
#   > 🟢 MUA MWG: Tỷ trọng 0.1% -> 0.5% | Giá khớp: 56.39
#   > 🟢 MUA NLG: Tỷ trọng 3.1% -> 5.5% | Giá khớp: 28.67
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 2.5% | Giá khớp: 19.40
#   > 🟢 MUA PHR: Tỷ trọng 3.3% -> 5.2% | Giá khớp: 49.24
#   > 🟢 MUA PNJ: Tỷ trọng 2.1% -> 4.5% | Giá khớp: 61.56
#   > 🟢 MUA PVD: Tỷ trọng 3.6% -> 4.8% | Giá khớp: 21.91
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 1.3% -> 1.1% | Giá bán: 47.96 | Giá vốn: 47.52 | Lãi/Lỗ: +0.92% (+1,821 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 0.6% -> 0.0% | Giá bán: 35.74 | Giá vốn: 30.52 | Lãi/Lỗ: +17.09% (+102,109 đ)
#   > 🩸 CẮT LỖ SSI: Tỷ trọng 4.7% -> 4.4% | Giá bán: 21.29 | Giá vốn: 21.78 | Lãi/Lỗ: -2.28% (-5,803 đ)
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 1.0% | Giá khớp: 11.22
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 3.6% -> 2.0% | Giá bán: 60.90 | Giá vốn: 61.30 | Lãi/Lỗ: -0.66% (-10,271 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 0.6% | Giá khớp: 56.87
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 7.9% -> 6.6% | Giá bán: 12.44 | Giá vốn: 12.12 | Lãi/Lỗ: +2.62% (+34,184 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 4
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 1.9% -> 0.0% | Giá bán: 16.12 | Giá vốn: 16.17 | Lãi/Lỗ: -0.30% (-5,502 đ)
#   > 🟢 MUA MWG: Tỷ trọng 1.4% -> 2.0% | Giá khớp: 56.88
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 3.9% -> 3.8% | Giá bán: 29.38 | Giá vốn: 29.18 | Lãi/Lỗ: +0.68% (+750 đ)
#   > 🩸 CẮT LỖ NT2: Tỷ trọng 1.5% -> 1.2% | Giá bán: 19.16 | Giá vốn: 19.40 | Lãi/Lỗ: -1.25% (-3,589 đ)
#   > 🟢 MUA PHR: Tỷ trọng 3.9% -> 5.3% | Giá khớp: 50.12
#   > 🟢 MUA PNJ: Tỷ trọng 4.6% -> 9.5% | Giá khớp: 61.43
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 3.2% -> 2.5% | Giá bán: 22.79 | Giá vốn: 22.02 | Lãi/Lỗ: +3.51% (+21,217 đ)
#   > 🟢 MUA REE: Tỷ trọng 2.8% -> 4.1% | Giá khớp: 48.91
#   > 🩸 CẮT LỖ SJS: Tỷ trọng 1.5% -> 1.2% | Giá bán: 33.11 | Giá vốn: 35.27 | Lãi/Lỗ: -6.14% (-17,479 đ)
#   > 🟢 MUA SSI: Tỷ trọng 2.9% -> 4.2% | Giá khớp: 21.82
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 1.9% -> 1.6% | Giá bán: 11.67 | Giá vốn: 11.34 | Lãi/Lỗ: +2.87% (+10,569 đ)
#   > 🟢 MUA VCB: Tỷ trọng 3.2% -> 5.2% | Giá khớp: 61.43
#   > 🔥 CHỐT LỜI VNM: Tỷ trọng 0.7% -> 0.6% | Giá bán: 57.24 | Giá vốn: 56.97 | Lãi/Lỗ: +0.46% (+634 đ)
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 5.3% -> 5.0% | Giá bán: 12.98 | Giá vốn: 12.16 | Lãi/Lỗ: +6.77% (+17,136 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 1.4%, BMP: 3.7%, BVH: 4.1%, CII: 1.2%, CTD: 4.2%, DCM: 8.8%, DGW: 1.2%, EIB: 2.8%, HAG: 2.3%, HCM: 4.4%, HDC: 2.0%, HPG: 4.2%, HSG: 6.4%, KBC: 3.0%, KDH: 4.1%, MWG: 2.0%, NLG: 3.8%, NT2: 1.2%, PHR: 5.3%, PNJ: 9.5%, PVD: 2.5%, REE: 4.1%, SJS: 1.2%, SSI: 4.2%, TCH: 1.6%, VCB: 5.2%, VSC: 5.0%]
#   📈 Tài sản: +713,998 đ | Hiệu suất ngày: +0.72% | Tổng NAV: 100,136,204 đ
#
# [20/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BID: Tỷ trọng 1.4% -> 1.1% | Giá bán: 39.46 | Giá vốn: 38.95 | Lãi/Lỗ: +1.29% (+4,023 đ)
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 3.7% -> 2.9% | Giá bán: 108.91 | Giá vốn: 117.55 | Lãi/Lỗ: -7.36% (-60,387 đ)
#   > 🟢 MUA BVH: Tỷ trọng 4.1% -> 4.9% | Giá khớp: 51.17
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 1.2% -> 1.0% | Giá bán: 11.66 | Giá vốn: 11.42 | Lãi/Lỗ: +2.05% (+5,642 đ)
#   > 🟢 MUA CTD: Tỷ trọng 4.2% -> 6.5% | Giá khớp: 65.60
#   > 🟢 MUA DCM: Tỷ trọng 8.8% -> 12.1% | Giá khớp: 31.69
#   > 🟢 MUA DGW: Tỷ trọng 1.2% -> 1.9% | Giá khớp: 36.83
#   > 🟢 MUA DIG: Tỷ trọng 0.0% -> 0.9% | Giá khớp: 15.92
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 2.8% -> 1.3% | Giá bán: 18.40 | Giá vốn: 18.21 | Lãi/Lỗ: +1.05% (+15,237 đ)
#   > 🟢 MUA HAG: Tỷ trọng 2.3% -> 4.3% | Giá khớp: 11.80
#   > 🟢 MUA HCM: Tỷ trọng 4.4% -> 8.3% | Giá khớp: 21.59
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 2
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 1.0% -> 0.8% | Giá bán: 11.62 | Giá vốn: 11.42 | Lãi/Lỗ: +1.70% (+2,298 đ)
#   > 🟢 MUA CTD: Tỷ trọng 6.5% -> 8.1% | Giá khớp: 65.60
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 12.1% -> 10.4% | Giá bán: 31.59 | Giá vốn: 31.82 | Lãi/Lỗ: -0.74% (-12,503 đ)
#   > 🟢 MUA DGW: Tỷ trọng 1.9% -> 3.1% | Giá khớp: 36.16
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 0.9% -> 0.7% | Giá bán: 16.05 | Giá vốn: 15.92 | Lãi/Lỗ: +0.81% (+978 đ)
#   > 🩸 CẮT LỖ EIB: Tỷ trọng 1.3% -> 0.4% | Giá bán: 18.15 | Giá vốn: 18.21 | Lãi/Lỗ: -0.32% (-3,036 đ)
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 4.3% -> 4.1% | Giá bán: 11.95 | Giá vốn: 11.78 | Lãi/Lỗ: +1.45% (+2,582 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 8.3% -> 7.1% | Giá bán: 21.82 | Giá vốn: 21.42 | Lãi/Lỗ: +1.84% (+21,262 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 1.6% -> 0.0% | Giá bán: 18.79 | Giá vốn: 18.57 | Lãi/Lỗ: +1.16% (+18,306 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 4.0% -> 3.4% | Giá bán: 19.55 | Giá vốn: 19.33 | Lãi/Lỗ: +1.11% (+6,212 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 6.9% -> 6.2% | Giá bán: 12.95 | Giá vốn: 13.26 | Lãi/Lỗ: -2.36% (-16,157 đ)
#   > 🟢 MUA KBC: Tỷ trọng 2.3% -> 3.7% | Giá khớp: 29.35
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 3.2% -> 2.7% | Giá bán: 31.25 | Giá vốn: 31.11 | Lãi/Lỗ: +0.43% (+1,923 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 1.6% -> 1.3% | Giá bán: 56.88 | Giá vốn: 56.58 | Lãi/Lỗ: +0.52% (+1,127 đ)
#   > 🟢 MUA NLG: Tỷ trọng 3.0% -> 6.8% | Giá khớp: 29.16
#   > 🔥 CHỐT LỜI PHR: Tỷ trọng 4.1% -> 3.5% | Giá bán: 50.12 | Giá vốn: 49.61 | Lãi/Lỗ: +1.03% (+5,863 đ)
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 7.4% -> 6.7% | Giá bán: 61.69 | Giá vốn: 61.32 | Lãi/Lỗ: +0.59% (+3,763 đ)
#   > 🟢 MUA PVD: Tỷ trọng 2.0% -> 3.7% | Giá khớp: 22.98
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 3.2% -> 2.7% | Giá bán: 48.40 | Giá vốn: 48.00 | Lãi/Lỗ: +0.83% (+3,674 đ)
#   > 🩸 CẮT LỖ SSI: Tỷ trọng 3.3% -> 2.8% | Giá bán: 21.74 | Giá vốn: 21.80 | Lãi/Lỗ: -0.27% (-1,219 đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 1.2% -> 0.0% | Giá bán: 11.59 | Giá vốn: 11.34 | Lãi/Lỗ: +2.16% (+26,154 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 4.1% -> 3.5% | Giá bán: 60.70 | Giá vốn: 61.16 | Lãi/Lỗ: -0.77% (-4,347 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.5% -> 1.7% | Giá khớp: 57.06
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 5.9% -> 5.4% | Giá bán: 12.95 | Giá vốn: 12.28 | Lãi/Lỗ: +5.46% (+24,824 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 2.5%, BVH: 6.6%, CTD: 8.1%, DCM: 10.4%, DGW: 3.1%, HAG: 4.1%, HCM: 7.1%, HPG: 3.4%, HSG: 6.2%, KBC: 3.7%, KDH: 2.7%, MWG: 1.3%, NLG: 6.8%, PHR: 3.5%, PNJ: 6.7%, PVD: 3.7%, REE: 2.7%, SSI: 2.8%, VCB: 3.5%, VNM: 1.7%, VSC: 5.4%]
#   📈 Tài sản: -227,375 đ | Hiệu suất ngày: -0.23% | Tổng NAV: 99,742,728 đ
#
# [22/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BID: Tỷ trọng 0.9% -> 0.8% | Giá bán: 39.07 | Giá vốn: 38.95 | Lãi/Lỗ: +0.29% (+545 đ)
#   > 🟢 MUA BMP: Tỷ trọng 2.5% -> 5.4% | Giá khớp: 109.08
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 6.6% -> 6.0% | Giá bán: 49.70 | Giá vốn: 49.69 | Lãi/Lỗ: +0.02% (+90 đ)
#   > 🩸 CẮT LỖ CII: Tỷ trọng 0.8% -> 0.7% | Giá bán: 11.36 | Giá vốn: 11.42 | Lãi/Lỗ: -0.57% (-628 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 8.1% -> 6.5% | Giá bán: 65.33 | Giá vốn: 64.35 | Lãi/Lỗ: +1.52% (+24,547 đ)
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 10.4% -> 8.3% | Giá bán: 30.98 | Giá vốn: 31.82 | Lãi/Lỗ: -2.66% (-55,056 đ)
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 3.1% -> 2.5% | Giá bán: 35.82 | Giá vốn: 36.31 | Lãi/Lỗ: -1.35% (-8,335 đ)
#   > 🟢 MUA DIG: Tỷ trọng 0.7% -> 1.8% | Giá khớp: 15.88
#   > 🟢 MUA EIB: Tỷ trọng 0.4% -> 4.3% | Giá khớp: 17.90
#   > 🟢 MUA FPT: Tỷ trọng 0.0% -> 0.4% | Giá khớp: 126.04
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 4.1% -> 3.3% | Giá bán: 12.10 | Giá vốn: 11.78 | Lãi/Lỗ: +2.72% (+22,102 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 7.1% -> 5.7% | Giá bán: 21.86 | Giá vốn: 21.42 | Lãi/Lỗ: +2.03% (+28,741 đ)
#   > 🟢 MUA HDC: Tỷ trọng 0.0% -> 1.6% | Giá khớp: 18.67
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 3.4% -> 2.8% | Giá bán: 19.44 | Giá vốn: 19.33 | Lãi/Lỗ: +0.55% (+3,731 đ)
#   > 🩸 CẮT LỖ HSG: Tỷ trọng 6.2% -> 5.4% | Giá bán: 12.76 | Giá vốn: 13.26 | Lãi/Lỗ: -3.79% (-30,747 đ)
#   > 🩸 CẮT LỖ KBC: Tỷ trọng 3.7% -> 3.0% | Giá bán: 28.95 | Giá vốn: 29.68 | Lãi/Lỗ: -2.48% (-18,173 đ)
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 2.7% -> 2.2% | Giá bán: 31.16 | Giá vốn: 31.11 | Lãi/Lỗ: +0.14% (+786 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 1.3% -> 1.1% | Giá bán: 56.59 | Giá vốn: 56.58 | Lãi/Lỗ: +0.01% (+16 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 6.8% -> 6.5% | Giá bán: 29.74 | Giá vốn: 29.17 | Lãi/Lỗ: +1.95% (+5,626 đ)
#   > 🟢 MUA NT2: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 18.82
#   > 🟢 MUA PHR: Tỷ trọng 3.5% -> 3.9% | Giá khớp: 49.64
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 6.7% -> 5.4% | Giá bán: 61.82 | Giá vốn: 61.32 | Lãi/Lỗ: +0.80% (+10,740 đ)
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 3.7% -> 3.6% | Giá bán: 22.64 | Giá vốn: 22.46 | Lãi/Lỗ: +0.80% (+881 đ)
#   > 🩸 CẮT LỖ REE: Tỷ trọng 2.7% -> 2.2% | Giá bán: 47.96 | Giá vốn: 48.00 | Lãi/Lỗ: -0.08% (-454 đ)
#   > 🟢 MUA SJS: Tỷ trọng 0.9% -> 1.2% | Giá khớp: 33.11
#   > 🟢 MUA SSI: Tỷ trọng 2.8% -> 3.8% | Giá khớp: 21.69
#   > 🟢 MUA VCB: Tỷ trọng 3.5% -> 5.0% | Giá khớp: 60.56
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 1
đ)
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 1.1% -> 0.9% | Giá bán: 19.02 | Giá vốn: 18.82 | Lãi/Lỗ: +1.05% (+2,297 đ)
#   > 🔥 CHỐT LỜI PHR: Tỷ trọng 3.9% -> 3.1% | Giá bán: 51.20 | Giá vốn: 49.61 | Lãi/Lỗ: +3.20% (+25,074 đ)
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 5.4% -> 4.3% | Giá bán: 62.66 | Giá vốn: 61.32 | Lãi/Lỗ: +2.17% (+23,794 đ)
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 3.6% -> 2.8% | Giá bán: 23.03 | Giá vốn: 22.46 | Lãi/Lỗ: +2.53% (+18,334 đ)
#   > 🟢 MUA REE: Tỷ trọng 2.2% -> 3.2% | Giá khớp: 48.32
#   > 🟢 MUA SJS: Tỷ trọng 1.2% -> 3.2% | Giá khớp: 34.15
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 3.8% -> 3.1% | Giá bán: 22.36 | Giá vốn: 21.77 | Lãi/Lỗ: +2.71% (+21,106 đ)
#   > 🟢 MUA VCB: Tỷ trọng 5.0% -> 5.2% | Giá khớp: 61.43
#   > 🔥 CHỐT LỜI VNM: Tỷ trọng 1.3% -> 1.1% | Giá bán: 57.24 | Giá vốn: 57.04 | Lãi/Lỗ: +0.35% (+944 đ)
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 4.3% -> 3.5% | Giá bán: 13.18 | Giá vốn: 12.28 | Lãi/Lỗ: +7.33% (+64,741 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 4.3%, BVH: 4.8%, CTD: 5.2%, DCM: 12.8%, DGW: 3.2%, DIG: 3.5%, EIB: 3.4%, HAG: 2.6%, HCM: 7.2%, HDC: 1.2%, HPG: 2.2%, HSG: 10.9%, KBC: 2.4%, NLG: 5.2%, PHR: 3.1%, PNJ: 4.3%, PVD: 2.8%, REE: 3.2%, SJS: 3.2%, SSI: 3.1%, VCB: 5.2%, VNM: 1.1%, VSC: 3.5%]
#   📈 Tài sản: +1,446,933 đ | Hiệu suất ngày: +1.46% | Tổng NAV: 100,657,857 đ
#
# [24/01/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 4.3% -> 3.5% | Giá bán: 110.47 | Giá vốn: 112.98 | Lãi/Lỗ: -2.23% (-17,256 đ)
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 4.8% -> 3.9% | Giá bán: 49.80 | Giá vốn: 49.69 | Lãi/Lỗ: +0.22% (+1,886 đ)
#   > 🩸 CẮT LỖ CII: Tỷ trọng 0.6% -> 0.5% | Giá bán: 11.36 | Giá vốn: 11.42 | Lãi/Lỗ: -0.57% (-593 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 5.2% -> 4.3% | Giá bán: 65.69 | Giá vốn: 64.35 | Lãi/Lỗ: +2.08% (+19,378 đ)
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 12.8% -> 10.5% | Giá bán: 31.64 | Giá vốn: 31.71 | Lãi/Lỗ: -0.23% (-5,362 đ)
#   > 🟢 MUA DGW: Tỷ trọng 3.2% -> 3.5% | Giá khớp: 36.54
#   > 🟢 MUA DIG: Tỷ trọng 3.5% -> 5.1% | Giá khớp: 15.32
#   > 🟢 MUA EIB: Tỷ trọng 3.4% -> 4.7% | Giá khớp: 18.55
#   > 🟢 MUA HCM: Tỷ trọng 7.2% -> 8.4% | Giá khớp: 22.24
#   > 🟢 MUA HDC: Tỷ trọng 1.2% -> 1.6% | Giá khớp: 18.75
#   > 🩸 CẮT LỖ KBC: Tỷ trọng 2.4% -> 1.9% | Giá bán: 29.00 | Giá vốn: 29.68 | Lãi/Lỗ: -2.31% (-9,767 đ)
#   > 🟢 MUA KDH: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 31.57
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 0.2% -> 0.0% | Giá bán: 59.25 | Giá vốn: 56.58 | Lãi/Lỗ: +4.71% (+7,459 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 5.2% -> 4.3% | Giá bán: 32.35 | Giá vốn: 29.17 | Lãi/Lỗ: +10.90% (+101,649 đ)
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 0.9% -> 0.7% | Giá bán: 18.97 | Giá vốn: 18.82 | Lãi/Lỗ: +0.79% (+1,211 đ)
#   > 🔥 CHỐT LỜI PHR: Tỷ trọng 3.1% -> 2.5% | Giá bán: 50.81 | Giá vốn: 49.61 | Lãi/Lỗ: +2.41% (+13,331 đ)
#   > 🟢 MUA PNJ: Tỷ trọng 4.3% -> 4.4% | Giá khớp: 62.98
#   > 🔥 CHỐT LỜI PVD: Tỷ trọng 2.8% -> 2.3% | Giá bán: 23.08 | Giá vốn: 22.46 | Lãi/Lỗ: +2.76% (+14,061 đ)
#   > 🩸 CẮT LỖ SJS: Tỷ trọng 3.2% -> 2.6% | Giá bán: 33.61 | Giá vốn: 34.35 | Lãi/Lỗ: -2.15% (-12,490 đ)
#   > 🟢 MUA SSI: Tỷ trọng 3.1% -> 5.1% | Giá khớp: 22.45
#   > 🔥 CHỐT LỜI VNM: Tỷ trọng 1.1% -> 0.9% | Giá bán: 57.43 | Giá vốn: 57.04 | Lãi/Lỗ: +0.68% (+1,303 đ)
#   > 🟢 MUA VSC: Tỷ trọng 3.5% -> 3.8% | Giá khớp: 13.57
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 3.5%, BVH: 3.9%, CTD: 4.3%, DCM: 10.5%, DGW: 3.5%, DIG: 5.1%, EIB: 4.7%, HAG: 2.5%, HCM: 8.4%, HDC: 1.6%, HPG: 2.2%, HSG: 10.8%, KBC: 1.9%, KDH: 1.4%, NLG: 4.3%, PHR: 2.5%, PNJ: 4.4%, PVD: 2.3%, REE: 3.2%, SJS: 2.6%, SSI: 5.1%, VCB: 5.1%, VSC: 3.8%]
#   📈 Tài sản: +376,619 đ | Hiệu suất ngày: +0.37% | Tổng NAV: 101,034,476 đ
#
# [03/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 3.5% -> 2.8% | Giá bán: 107.16 | Giá vốn: 112.98 | Lãi/Lỗ: -5.16% (-36,199 đ)
#   > 🟢 MUA BVH: Tỷ trọng 3.9% -> 5.5% | Giá khớp: 49.70
#   > 🟢 MUA CII: Tỷ trọng 0.5% -> 1.2% | Giá khớp: 11.45
#   > 🩸 CẮT LỖ CTD: Tỷ trọng 4.3% -> 3.8% | Giá bán: 64.34 | Giá vốn: 64.35 | Lãi/Lỗ: -0.02% (-103 đ)
#   > 🔥 CHỐT LỜI DCM: Tỷ trọng 10.5% -> 8.4% | Giá bán: 32.07 | Giá vốn: 31.71 | Lãi/Lỗ: +1.12% (+23,390 đ)
#   > 🟢 MUA DGW: Tỷ trọng 3.5% -> 4.8% | Giá khớp: 36.68
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 5.1% -> 4.1% | Giá bán: 15.10 | Giá vốn: 15.66 | Lãi/Lỗ: -3.61% (-36,642 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 4.7% -> 4.1% | Giá bán: 18.20 | Giá vốn: 18.10 | Lãi/Lỗ: +0.56% (+3,360 đ)
#   > 🟢 MUA FPT: Tỷ trọng 0.2% -> 1.2% | Giá khớp: 122.51
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 8.4% -> 6.8% | Giá bán: 22.08 | Giá vốn: 21.69 | Lãi/Lỗ: +1.77% (+28,456 đ)
#   > 🟢 MUA HDC: Tỷ trọng 1.6% -> 2.0% | Giá khớp: 18.71
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 2.2% -> 1.7% | Giá bán: 19.62 | Giá vốn: 19.33 | Lãi/Lỗ: +1.48% (+6,342 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 10.8% -> 8.7% | Giá bán: 13.13 | Giá vốn: 13.12 | Lãi/Lỗ: +0.07% (+1,603 đ)
#   > 🩸 CẮT LỖ KBC: Tỷ trọng 1.9% -> 0.5% | Giá bán: 29.40 | Giá vốn: 29.68 | Lãi/Lỗ: -0.96% (-13,838 đ)
#   > 🟢 MUA KDH: Tỷ trọng 1.4% -> 3.6% | Giá khớp: 31.38
#   > 🟢 MUA MWG: Tỷ trọng 0.0% -> 1.8% | Giá khớp: 58.75
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 4.3% -> 3.4% | Giá bán: 30.98 | Giá vốn: 29.17 | Lãi/Lỗ: +6.20% (+52,438 đ)
#   > 🟢 MUA NT2: Tỷ trọng 0.7% -> 3.0% | Giá khớp: 18.97
#   > 🟢 MUA PHR: Tỷ trọng 2.5% -> 4.3% | Giá khớp: 51.30
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 4.4% -> 3.6% | Giá bán: 63.30 | Giá vốn: 61.37 | Lãi/Lỗ: +3.13% (+27,528 đ)
#   > 🟢 MUA PVD: Tỷ trọng 2.3% -> 4.3% | Giá khớp: 22.88
#   > 🩸 CẮT LỖ REE: Tỷ trọng 3.2% -> 2.6% | Giá bán: 47.88 | Giá vốn: 48.10 | Lãi/Lỗ: -0.47% (-2,991 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 2.6% -> 2.1% | Giá bán: 34.38 | Giá vốn: 34.35 | Lãi/Lỗ: +0.09% (+479 đ)
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 5.1% -> 4.1% | Giá bán: 22.05 | Giá vốn: 22.04 | Lãi/Lỗ: +0.01% (+131 đ)
#   > 🟢 MUA TCH: Tỷ trọng 0.0% -> 1.1% | Giá khớp: 12.50
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 5.1% -> 4.1% | Giá bán: 60.83 | Giá vốn: 60.99 | Lãi/Lỗ: -0.27% (-2,747 đ)
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 0.9% -> 0.0% | Giá bán: 55.86 | Giá vốn: 57.04 | Lãi/Lỗ: -2.07% (-18,273 đ)
#   > 🟢 MUA VSC: Tỷ trọng 3.8% -> 3.9% | Giá khớp: 13.60
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 2.8%, BVH: 5.5%, CII: 1.2%, CTD: 3.8%, DCM: 8.4%, DGW: 4.8%, DIG: 4.1%, EIB: 4.1%, FPT: 1.2%, HAG: 2.5%, HCM: 6.8%, HDC: 2.0%, HPG: 1.7%, HSG: 8.7%, KDH: 3.6%, MWG: 1.8%, NLG: 3.4%, NT2: 3.0%, PHR: 4.3%, PNJ: 3.6%, PVD: 4.3%, REE: 2.6%, SJS: 2.1%, SSI: 4.1%, TCH: 1.1%, VCB: 4.1%, VSC: 3.9%]
#   📈 Tài sản: -499,164 đ | Hiệu suất ngày: -0.49% | Tổng NAV: 100,535,312 đ
#
# [04/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🩸 CẮT LỖ BMP: Tỷ trọng 2.8% -> 0.0% | Giá bán: 108.04 | Giá vốn: 112.98 | Lãi/Lỗ: -4.38% (-124,916 đ)
#   > 🔥 CHỐT LỜI BVH: Tỷ trọng 5.5% -> 4.3% | Giá bán: 50.39 | Giá vốn: 49.69 | Lãi/Lỗ: +1.40% (+16,269 đ)
#   > 🟢 MUA CII: Tỷ trọng 1.2% -> 2.1% | Giá khớp: 11.75
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 3.8% -> 3.0% | Giá bán: 68.82 | Giá vốn: 64.35 | Lãi/Lỗ: +6.94% (+55,831 đ)
#   > 🔥 CHỐT LỜI DCM: Tỷ trọng 8.4% -> 6.7% | Giá bán: 32.68 | Giá vốn: 31.71 | Lãi/Lỗ: +3.05% (+54,258 đ)
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 4.8% -> 3.8% | Giá bán: 37.12 | Giá vốn: 36.40 | Lãi/Lỗ: +1.98% (+20,218 đ)
#   > 🩸 CẮT LỖ DIG: Tỷ trọng 4.1% -> 3.2% | Giá bán: 15.32 | Giá vốn: 15.66 | Lãi/Lỗ: -2.21% (-19,138 đ)
#   > 🟢 MUA EIB: Tỷ trọng 4.1% -> 5.8% | Giá khớp: 18.60
#   > 🟢 MUA FPT: Tỷ trọng 1.2% -> 4.3% | Giá khớp: 123.10
#   > 🔥 CHỐT LỜI HAG: Tỷ trọng 2.5% -> 2.0% | Giá bán: 11.90 | Giá vốn: 11.78 | Lãi/Lỗ: +1.02% (+5,376 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 6.8% -> 5.4% | Giá bán: 22.55 | Giá vốn: 21.69 | Lãi/Lỗ: +3.94% (+57,064 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 2.0% -> 1.8% | Giá bán: 18.98 | Giá vốn: 18.69 | Lãi/Lỗ: +1.53% (+3,015 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 1.7% -> 1.4% | Giá bán: 19.96 | Giá vốn: 19.33 | Lãi/Lỗ: +3.23% (+11,881 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 8.7% -> 6.8% | Giá bán: 13.36 | Giá vốn: 13.12 | Lãi/Lỗ: +1.83% (+33,454 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 0.5% -> 0.0% | Giá bán: 29.70 | Giá vốn: 29.68 | Lãi/Lỗ: +0.05% (+257 đ)
#   > 🟢 MUA KDH: Tỷ trọng 3.6% -> 4.2% | Giá khớp: 31.57
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 16.84
#   > 🟢 MUA MWG: Tỷ trọng 1.8% -> 2.4% | Giá khớp: 58.75
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 3.4% -> 3.0% | Giá bán: 30.62 | Giá vốn: 29.17 | Lãi/Lỗ: +4.97% (+22,548 đ)
#   > 🟢 MUA NT2: Tỷ trọng 3.0% -> 5.0% | Giá khớp: 19.07
#   > 🟢 MUA PHR: Tỷ trọng 4.3% -> 5.5% | Giá khớp: 51.20
#   > 🟢 MUA PNJ: Tỷ trọng 3.6% -> 7.0% | Giá khớp: 63.37
#   > 🟢 MUA PVD: Tỷ trọng 4.3% -> 4.6% | Giá khớp: 23.08
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 2.6% -> 2.0% | Giá bán: 48.40 | Giá vốn: 48.10 | Lãi/Lỗ: +0.61% (+3,309 đ)
#   > 🩸 CẮT LỖ SJS: Tỷ trọng 2.1% -> 1.7% | Giá bán: 33.96 | Giá vốn: 34.35 | Lãi/Lỗ: -1.13% (-5,094 đ)
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 4.1% -> 3.3% | Giá bán: 22.49 | Giá vốn: 22.04 | Lãi/Lỗ: +2.01% (+17,528 đ)
#   > 🟢 MUA TCH: Tỷ trọng 1.1% -> 1.5% | Giá khớp: 12.74
#   > 🔥 CHỐT LỜI VCB: Tỷ trọng 4.1% -> 4.0% | Giá bán: 61.10 | Giá vốn: 60.99 | Lãi/Lỗ: +0.17% (+213 đ)
#   > 🟢 MUA VSC: Tỷ trọng 3.9% -> 4.5% | Giá khớp: 13.92
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BVH: 4.3%, CII: 2.1%, CTD: 3.0%, DCM: 6.7%, DGW: 3.8%, DIG: 3.2%, EIB: 5.8%, FPT: 4.3%, HAG: 2.0%, HCM: 5.4%, HDC: 1.8%, HPG: 1.4%, HSG: 6.8%, KDH: 4.2%, MWG: 2.4%, NLG: 3.0%, NT2: 5.0%, PHR: 5.5%, PNJ: 7.0%, PVD: 4.6%, REE: 2.0%, SJS: 1.7%, SSI: 3.3%, TCH: 1.5%, VCB: 4.0%, VSC: 4.5%]
#   📈 Tài sản: +1,276,348 đ | Hiệu suất ngày: +1.27% | Tổng NAV: 101,811,660 đ
#
# [05/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI
đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 1.5% -> 1.2% | Giá bán: 12.87 | Giá vốn: 12.56 | Lãi/Lỗ: +2.42% (+7,095 đ)
#   > 🟢 MUA VCB: Tỷ trọng 4.0% -> 4.5% | Giá khớp: 61.49
#   > 🟢 MUA VSC: Tỷ trọng 4.5% -> 7.2% | Giá khớp: 14.07
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BVH: 3.5%, CII: 1.7%, CTD: 2.4%, DCM: 5.7%, DGW: 7.7%, DIG: 3.4%, EIB: 4.9%, FPT: 3.5%, HAG: 1.6%, HCM: 5.1%, HDC: 1.5%, HPG: 1.1%, HSG: 6.4%, KDH: 3.4%, MBB: 3.7%, MWG: 1.9%, NLG: 2.4%, NT2: 4.9%, PHR: 5.2%, PNJ: 5.6%, PVD: 3.8%, REE: 2.1%, SJS: 2.6%, SSI: 2.6%, TCH: 1.2%, VCB: 4.5%, VSC: 7.2%]
#   📈 Tài sản: +656,406 đ | Hiệu suất ngày: +0.64% | Tổng NAV: 102,468,066 đ
#
# [06/02/2025] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BVH: Tỷ trọng 3.5% -> 7.3% | Giá khớp: 50.19
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 1.7% -> 1.4% | Giá bán: 11.62 | Giá vốn: 11.57 | Lãi/Lỗ: +0.41% (+1,351 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 2.4% -> 2.0% | Giá bán: 73.39 | Giá vốn: 64.35 | Lãi/Lỗ: +14.04% (+66,271 đ)
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 7.7% -> 6.2% | Giá bán: 37.55 | Giá vốn: 36.74 | Lãi/Lỗ: +2.21% (+32,912 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 3.4% -> 2.8% | Giá bán: 16.27 | Giá vốn: 15.70 | Lãi/Lỗ: +3.63% (+24,054 đ)
#   > 🟢 MUA DPM: Tỷ trọng 0.0% -> 0.1% | Giá khớp: 19.60
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 4.9% -> 3.9% | Giá bán: 18.60 | Giá vốn: 18.25 | Lãi/Lỗ: +1.93% (+18,186 đ)
#   > 🟢 MUA FPT: Tỷ trọng 3.5% -> 7.4% | Giá khớp: 123.35
#   > 🟢 MUA HAG: Tỷ trọng 1.6% -> 3.8% | Giá khớp: 12.00
#   > 🟢 MUA HCM: Tỷ trọng 5.1% -> 5.3% | Giá khớp: 22.28
#   > 🟢 MUA HDC: Tỷ trọng 1.5% -> 1.6% | Giá khớp: 18.95
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 1.1% -> 0.0% | Giá bán: 19.92 | Giá vốn: 19.33 | Lãi/Lỗ: +3.03% (+34,435 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 6.4% -> 5.2% | Giá bán: 13.24 | Giá vốn: 13.12 | Lãi/Lỗ: +0.91% (+11,434 đ)
#   > 🩸 CẮT LỖ KDH: Tỷ trọng 3.4% -> 2.8% | Giá bán: 31.43 | Giá vốn: 31.47 | Lãi/Lỗ: -0.15% (-992 đ)
#   > 🔥 CHỐT LỜI MBB: Tỷ trọng 3.7% -> 3.0% | Giá bán: 16.95 | Giá vốn: 16.87 | Lãi/Lỗ: +0.45% (+3,247 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 2.4% -> 1.9% | Giá bán: 30.58 | Giá vốn: 29.17 | Lãi/Lỗ: +4.83% (+22,515 đ)
#   > 🔥 CHỐT LỜI NT2: Tỷ trọng 4.9% -> 3.9% | Giá bán: 19.26 | Giá vốn: 18.99 | Lãi/Lỗ: +1.41% (+13,302 đ)
#   > 🟢 MUA PDR: Tỷ trọng 0.4% -> 2.9% | Giá khớp: 18.33
#   > 🔥 CHỐT LỜI PHR: Tỷ trọng 5.2% -> 5.1% | Giá bán: 51.30 | Giá vốn: 50.50 | Lãi/Lỗ: +1.57% (+2,597 đ)
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 5.6% -> 4.6% | Giá bán: 64.27 | Giá vốn: 62.35 | Lãi/Lỗ: +3.07% (+33,595 đ)
#   > 🟢 MUA PVD: Tỷ trọng 3.8% -> 7.1% | Giá khớp: 23.23
#   > 🔥 CHỐT LỜI REE: Tỷ trọng 2.1% -> 1.7% | Giá bán: 48.40 | Giá vốn: 48.10 | Lãi/Lỗ: +0.61% (+2,503 đ)
#   > 🔥 CHỐT LỜI SJS: Tỷ trọng 2.6% -> 2.1% | Giá bán: 34.85 | Giá vốn: 34.49 | Lãi/Lỗ: +1.03% (+5,117 đ)
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 2.6% -> 0.0% | Giá bán: 22.27 | Giá vốn: 22.04 | Lãi/Lỗ: +1.01% (+27,310 đ)
#   > 🔥 CHỐT LỜI TCH: Tỷ trọng 1.2% -> 1.0% | Giá bán: 12.70 | Giá vốn: 12.56 | Lãi/Lỗ: +1.07% (+2,530 đ)
# ...
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 2.5% -> 2.2% | Giá bán: 13.75 | Giá vốn: 13.85 | Lãi/Lỗ: -0.77% (-3,277 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 2.4% -> 2.1% | Giá bán: 31.00 | Giá vốn: 30.03 | Lãi/Lỗ: +3.22% (+13,283 đ)
#   > 🟢 MUA KDC: Tỷ trọng 1.8% -> 4.0% | Giá khớp: 51.00
#   > 🔥 CHỐT LỜI KDH: Tỷ trọng 5.7% -> 5.0% | Giá bán: 23.35 | Giá vốn: 23.32 | Lãi/Lỗ: +0.11% (+1,111 đ)
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 0.6% -> 0.0% | Giá bán: 24.75 | Giá vốn: 25.00 | Lãi/Lỗ: -1.01% (-8,088 đ)
#   > 🩸 CẮT LỖ MWG: Tỷ trọng 2.3% -> 2.0% | Giá bán: 76.90 | Giá vốn: 78.73 | Lãi/Lỗ: -2.34% (-9,197 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 5.6% -> 4.9% | Giá bán: 25.95 | Giá vốn: 25.62 | Lãi/Lỗ: +1.27% (+12,208 đ)
#   > 🟢 MUA PDR: Tỷ trọng 1.6% -> 2.3% | Giá khớp: 15.00
#   > 🟢 MUA PHR: Tỷ trọng 4.9% -> 6.2% | Giá khớp: 64.50
#   > 🟢 MUA PNJ: Tỷ trọng 7.7% -> 9.6% | Giá khớp: 62.00
#   > 🩸 CẮT LỖ REE: Tỷ trọng 1.1% -> 0.0% | Giá bán: 50.60 | Giá vốn: 51.52 | Lãi/Lỗ: -1.80% (-25,312 đ)
#   > 🟢 MUA SSI: Tỷ trọng 3.0% -> 3.2% | Giá khớp: 26.30
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 4.9% -> 4.3% | Giá bán: 15.00 | Giá vốn: 15.38 | Lãi/Lỗ: -2.48% (-20,749 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 3.7% -> 3.2% | Giá bán: 61.60 | Giá vốn: 62.37 | Lãi/Lỗ: -1.25% (-7,836 đ)
#   > 🩸 CẮT LỖ VHC: Tỷ trọng 2.5% -> 2.2% | Giá bán: 57.00 | Giá vốn: 57.08 | Lãi/Lỗ: -0.15% (-632 đ)
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 0.5% -> 0.1% | Giá bán: 196.00 | Giá vốn: 205.77 | Lãi/Lỗ: -4.76% (-24,697 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.0% -> 0.7% | Giá khớp: 59.20
#   > 🟢 MUA VSC: Tỷ trọng 2.7% -> 4.0% | Giá khớp: 18.45
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 3.7%, BVH: 5.4%, CII: 4.2%, CTD: 2.9%, DCM: 2.3%, DGW: 1.7%, DIG: 2.8%, EIB: 2.6%, HCM: 5.9%, HDC: 4.3%, HPG: 3.7%, HSG: 2.2%, HT1: 2.2%, KBC: 2.1%, KDC: 4.0%, KDH: 5.0%, MWG: 2.0%, NLG: 4.9%, PDR: 2.3%, PHR: 6.2%, PNJ: 9.6%, SSI: 3.2%, TCH: 4.3%, VCB: 3.2%, VHC: 2.2%, VSC: 4.0%]
#   📈 Tài sản: -727,865 đ | Hiệu suất ngày: -0.54% | Tổng NAV: 133,076,877 đ
#
# [12/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 0.2% -> 0.7% | Giá khớp: 41.05
#   > 🟢 MUA BMP: Tỷ trọng 3.7% -> 5.2% | Giá khớp: 135.00
#   > 🟢 MUA BVH: Tỷ trọng 5.4% -> 5.6% | Giá khớp: 65.60
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 4.2% -> 3.6% | Giá bán: 17.35 | Giá vốn: 16.84 | Lãi/Lỗ: +3.01% (+21,048 đ)
#   > 🩸 CẮT LỖ CTD: Tỷ trọng 2.9% -> 2.5% | Giá bán: 70.80 | Giá vốn: 71.83 | Lãi/Lỗ: -1.45% (-7,015 đ)
#   > 🟢 MUA CTG: Tỷ trọng 0.3% -> 0.6% | Giá khớp: 33.40
#   > 🟢 MUA DCM: Tỷ trọng 2.3% -> 3.0% | Giá khớp: 38.20
#   > 🩸 CẮT LỖ DGW: Tỷ trọng 1.7% -> 1.5% | Giá bán: 38.90 | Giá vốn: 39.11 | Lãi/Lỗ: -0.55% (-1,571 đ)
#   > 🟢 MUA DIG: Tỷ trọng 2.8% -> 3.7% | Giá khớp: 12.60
#   > 🟢 MUA EIB: Tỷ trọng 2.6% -> 4.5% | Giá khớp: 20.70
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 5.9% -> 5.2% | Giá bán: 27.00 | Giá vốn: 27.52 | Lãi/Lỗ: -1.89% (-18,903 đ)
#   > 🩸 CẮT LỖ HDC: Tỷ trọng 4.3% -> 4.0% | Giá bán: 15.40 | Giá vốn: 15.54 | Lãi/Lỗ: -0.92% (-3,810 đ)
#   > 🩸 CẮT LỖ HPG: Tỷ trọng 3.7% -> 3.3% | Giá bán: 23.20 | Giá vốn: 23.64 | Lãi/Lỗ: -1.86% (-11,710 đ)
#   > 🟢 MUA HSG: Tỷ trọng 2.2% -> 2.5% | Giá khớp: 11.70
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 2.2% -> 1.9% | Giá bán: 13.60 | Giá vốn: 13.85 | Lãi/Lỗ: -1.85% (-6,781 đ)
#   > 🔥 CHỐT LỜI KBC: Tỷ trọng 2.1% -> 0.0% | Giá bán: 30.70 | Giá vốn: 30.03 | Lãi/Lỗ: +2.23% (+62,089 đ)
#   > 🩸 CẮT LỖ KDC: Tỷ trọng 4.0% -> 3.5% | Giá bán: 49.90 | Giá vốn: 50.75 | Lãi/Lỗ: -1.69% (-11,448 đ)
#   > 🟢 MUA MSN: Tỷ trọng 0.8% -> 1.1% | Giá khớp: 71.10
#   > 🩸 CẮT LỖ MWG: Tỷ trọng 2.0% -> 1.7% | Giá bán: 76.40 | Giá vốn: 78.73 | Lãi/Lỗ: -2.98% (-10,023 đ)
#   > 🩸 CẮT LỖ NLG: Tỷ trọng 4.9% -> 4.3% | Giá bán: 25.40 | Giá vốn: 25.62 | Lãi/Lỗ: -0.88% (-7,266 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 2.3% -> 2.0% | Giá bán: 14.90 | Giá vốn: 15.14 | Lãi/Lỗ: -1.60% (-6,108 đ)
#   > 🩸 CẮT LỖ PNJ: Tỷ trọng 9.6% -> 8.4% | Giá bán: 62.00 | Giá vốn: 65.52 | Lãi/Lỗ: -5.38% (-86,632 đ)
#   > 🟢 MUA SSI: Tỷ trọng 3.2% -> 3.4% | Giá khớp: 26.15
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 4.3% -> 3.7% | Giá bán: 14.95 | Giá vốn: 15.38 | Lãi/Lỗ: -2.80% (-20,119 đ)
#   > 🟢 MUA VCB: Tỷ trọng 3.2% -> 3.6% | Giá khớp: 61.60
#   > 🔥 CHỐT LỜI VHC: Tỷ trọng 2.2% -> 1.9% | Giá bán: 57.10 | Giá vốn: 57.08 | Lãi/Lỗ: +0.03% (+108 đ)
#   > 🩸 CẮT LỖ VIC: Tỷ trọng 0.1% -> 0.0% | Giá bán: 195.50 | Giá vốn: 205.77 | Lãi/Lỗ: -5.00% (-8,330 đ)
#   > 🟢 MUA VSC: Tỷ trọng 4.0% -> 5.7% | Giá khớp: 18.50
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 5.2%, BVH: 5.6%, CII: 3.6%, CTD: 2.5%, DCM: 3.0%, DGW: 1.5%, DIG: 3.7%, EIB: 4.5%, HCM: 5.2%, HDC: 4.0%, HPG: 3.3%, HSG: 2.5%, HT1: 1.9%, KDC: 3.5%, KDH: 4.9%, MSN: 1.1%, MWG: 1.7%, NLG: 4.3%, PDR: 2.0%, PHR: 6.3%, PNJ: 8.4%, SSI: 3.4%, TCH: 3.7%, VCB: 3.6%, VHC: 1.9%, VSC: 5.7%]
#   📈 Tài sản: -847,167 đ | Hiệu suất ngày: -0.64% | Tổng NAV: 132,229,710 đ
#
# [15/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BID: Tỷ trọng 0.7% -> 0.5% | Giá bán: 41.60 | Giá vốn: 41.16 | Lãi/Lỗ: +1.07% (+2,380 đ)
#   > 🟢 MUA BMP: Tỷ trọng 5.2% -> 6.5% | Giá khớp: 137.90
#   > 🟢 MUA BVH: Tỷ trọng 5.6% -> 6.4% | Giá khớp: 65.20
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 3.6% -> 2.8% | Giá bán: 17.50 | Giá vốn: 16.84 | Lãi/Lỗ: +3.90% (+44,342 đ)
#   > 🔥 CHỐT LỜI CTD: Tỷ trọng 2.5% -> 2.4% | Giá bán: 72.30 | Giá vốn: 71.83 | Lãi/Lỗ: +0.64% (+1,177 đ)
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 0.6% -> 0.5% | Giá bán: 33.70 | Giá vốn: 33.71 | Lãi/Lỗ: -0.04% (-72 đ)
#   > 🟢 MUA DCM: Tỷ trọng 3.0% -> 7.1% | Giá khớp: 37.20
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 1.5% -> 1.1% | Giá bán: 40.20 | Giá vốn: 39.11 | Lãi/Lỗ: +2.77% (+12,778 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 3.7% -> 3.1% | Giá bán: 13.00 | Giá vốn: 12.71 | Lãi/Lỗ: +2.28% (+16,077 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 4.5% -> 3.7% | Giá bán: 21.15 | Giá vốn: 21.01 | Lãi/Lỗ: +0.63% (+6,692 đ)
#   > 🩸 CẮT LỖ HCM: Tỷ trọng 5.2% -> 4.0% | Giá bán: 27.45 | Giá vốn: 27.52 | Lãi/Lỗ: -0.26% (-4,153 đ)
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 4.0% -> 3.2% | Giá bán: 15.62 | Giá vốn: 15.54 | Lãi/Lỗ: +0.49% (+5,188 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 3.3% -> 2.5% | Giá bán: 24.35 | Giá vốn: 23.64 | Lãi/Lỗ: +3.00% (+30,654 đ)
#   > 🟢 MUA HSG: Tỷ trọng 2.5% -> 2.9% | Giá khớp: 12.05
#   > 🩸 CẮT LỖ HT1: Tỷ trọng 1.9% -> 0.0% | Giá bán: 13.65 | Giá vốn: 13.85 | Lãi/Lỗ: -1.49% (-37,420 đ)
#   > 🟢 MUA KBC: Tỷ trọng 0.0% -> 0.8% | Giá khớp: 30.95
#   > 🔥 CHỐT LỜI KDC: Tỷ trọng 3.5% -> 2.7% | Giá bán: 50.80 | Giá vốn: 50.75 | Lãi/Lỗ: +0.08% (+879 đ)
#   > 🩸 CẮT LỖ KDH: Tỷ trọng 4.9% -> 3.8% | Giá bán: 23.25 | Giá vốn: 23.32 | Lãi/Lỗ: -0.31% (-4,879 đ)
#   > 🟢 MUA MBB: Tỷ trọng 0.0% -> 3.7% | Giá khớp: 25.20
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 1.1% -> 0.8% | Giá bán: 72.20 | Giá vốn: 72.04 | Lãi/Lỗ: +0.22% (+745 đ)
#   > 🟢 MUA MWG: Tỷ trọng 1.7% -> 2.5% | Giá khớp: 79.40
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 4.3% -> 4.1% | Giá bán: 26.25 | Giá vốn: 25.62 | Lãi/Lỗ: +2.44% (+5,882 đ)
#   > 🩸 CẮT LỖ PDR: Tỷ trọng 2.0% -> 1.5% | Giá bán: 15.10 | Giá vốn: 15.14 | Lãi/Lỗ: -0.28% (-1,753 đ)
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 6.3% -> 4.8% | Giá bán: 64.20 | Giá vốn: 66.20 | Lãi/Lỗ: -3.02% (-59,536 đ)
#   > 🩸 CẮT LỖ PNJ: Tỷ trọng 8.4% -> 6.4% | Giá bán: 65.00 | Giá vốn: 65.52 | Lãi/Lỗ: -0.80% (-20,887 đ)
#   > 🩸 CẮT LỖ PVD: Tỷ trọng 0.6% -> 0.5% | Giá bán: 29.25 | Giá vốn: 31.00 | Lãi/Lỗ: -5.65% (-10,958 đ)
#   > 🟢 MUA REE: Tỷ trọng 0.0% -> 0.3% | Giá khớp: 51.00
#   > 🟢 MUA SJS: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 48.90
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 3.4% -> 2.6% | Giá bán: 27.05 | Giá vốn: 26.97 | Lãi/Lỗ: +0.30% (+3,182 đ)
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 3.7% -> 2.8% | Giá bán: 15.05 | Giá vốn: 15.38 | Lãi/Lỗ: -2.15% (-25,126 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 3.6% -> 2.8% | Giá bán: 61.60 | Giá vốn: 62.28 | Lãi/Lỗ: -1.10% (-12,536 đ)
#   > 🔥 CHỐT LỜI VHC: Tỷ trọng 1.9% -> 1.5% | Giá bán: 58.40 | Giá vốn: 57.08 | Lãi/Lỗ: +2.31% (+13,898 đ)
#   > 🟢 MUA VNM: Tỷ trọng 0.6% -> 1.9% | Giá khớp: 59.70
#   > 🟢 MUA VSC: Tỷ trọng 5.7% -> 9.4% | Giá khớp: 18.95
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BMP: 6.5%, BVH: 6.4%, CII: 2.8%, CTD: 2.4%, DCM: 7.1%, DGW: 1.1%, DIG: 3.1%, EIB: 3.7%, HCM: 4.0%, HDC: 3.2%, HPG: 2.5%, HSG: 2.9%, KDC: 2.7%, KDH: 3.8%, MBB: 3.7%, MWG: 2.5%, NLG: 4.1%, PDR: 1.5%, PHR: 4.8%, PNJ: 6.4%, SSI: 2.6%, TCH: 2.8%, VCB: 2.8%, VHC: 1.5%, VNM: 1.9%, VSC: 9.4%]
#   📈 Tài sản: +2,222,180 đ | Hiệu suất ngày: +1.68% | Tổng NAV: 134,451,890 đ
#
# [16/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🟢 MUA BID: Tỷ trọng 0.5% -> 1.8% | Giá khớp: 41.90
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 6.5% -> 4.9% | Giá bán: 142.00 | Giá vốn: 134.81 | Lãi/Lỗ: +5.33% (+115,820 đ)
#   > 🩸 CẮT LỖ BVH: Tỷ trọng 6.4% -> 4.8% | Giá bán: 65.50 | Giá vốn: 67.61 | Lãi/Lỗ: -3.13% (-67,676 đ)
#   > 🔥 CHỐT LỜI CII: Tỷ trọng 2.8% -> 2.1% | Giá bán: 18.05 | Giá vốn: 16.84 | Lãi/Lỗ: +7.17% (+66,572 đ)
#   > 🩸 CẮT LỖ CTG: Tỷ trọng 0.5% -> 0.4% | Giá bán: 33.70 | Giá vốn: 33.71 | Lãi/Lỗ: -0.04% (-59 đ)
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 7.1% -> 5.3% | Giá bán: 36.50 | Giá vốn: 37.77 | Lãi/Lỗ: -3.36% (-80,098 đ)
#   > 🔥 CHỐT LỜI DGW: Tỷ trọng 1.1% -> 0.0% | Giá bán: 41.30 | Giá vốn: 39.11 | Lãi/Lỗ: +5.58% (+84,251 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 3.1% -> 2.4% | Giá bán: 13.20 | Giá vốn: 12.71 | Lãi/Lỗ: +3.85% (+40,587 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 3.7% -> 2.8% | Giá bán: 21.20 | Giá vốn: 21.01 | Lãi/Lỗ: +0.87% (+10,966 đ)
#   > 🔥 CHỐT LỜI HCM: Tỷ trọng 4.0% -> 3.7% | Giá bán: 27.85 | Giá vốn: 27.52 | Lãi/Lỗ: +1.20% (+3,900 đ)
#   > 🟢 MUA HDC: Tỷ trọng 3.2% -> 3.9% | Giá khớp: 16.22
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 2.5% -> 2.0% | Giá bán: 24.20 | Giá vốn: 23.64 | Lãi/Lỗ: +2.37% (+14,416 đ)
#   > 🟢 MUA HSG: Tỷ trọng 2.9% -> 4.2% | Giá khớp: 12.20
#   > 🟢 MUA KBC: Tỷ trọng 0.8% -> 4.2% | Giá khớp: 30.95
#   > 🩸 CẮT LỖ KDC: Tỷ trọng 2.7% -> 2.0% | Giá bán: 50.00 | Giá vốn: 50.75 | Lãi/Lỗ: -1.50% (-13,441 đ)
#   > 🟢 MUA KDH: Tỷ trọng 3.8% -> 5.0% | Giá khớp: 23.70
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 3.7% -> 2.8% | Giá bán: 25.10 | Giá vốn: 25.20 | Lãi/Lỗ: -0.41% (-5,072 đ)
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 0.8% -> 0.6% | Giá bán: 73.00 | Giá vốn: 72.04 | Lãi/Lỗ: +1.33% (+3,716 đ)
#   > 🟢 MUA MWG: Tỷ trọng 2.5% -> 3.5% | Giá khớp: 79.40
#   > 🟢 MUA NLG: Tỷ trọng 4.1% -> 6.7% | Giá khớp: 28.00
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 1.5% -> 1.1% | Giá bán: 15.35 | Giá vốn: 15.14 | Lãi/Lỗ: +1.37% (+6,920 đ)
#   > 🩸 CẮT LỖ PHR: Tỷ trọng 4.8% -> 3.7% | Giá bán: 64.60 | Giá vốn: 66.20 | Lãi/Lỗ: -2.42% (-33,965 đ)
#   > 🟢 MUA PNJ: Tỷ trọng 6.4% -> 7.8% | Giá khớp: 68.20
#   > 🩸 CẮT LỖ PVD: Tỷ trọng 0.5% -> 0.4% | Giá bán: 30.15 | Giá vốn: 31.00 | Lãi/Lỗ: -2.75% (-4,354 đ)
#   > 🟢 MUA PVT: Tỷ trọng 0.0% -> 1.4% | Giá khớp: 19.30
#   > 🟢 MUA REE: Tỷ trọng 0.3% -> 2.1% | Giá khớp: 50.90
#   > 🔥 CHỐT LỜI SSI: Tỷ trọng 2.6% -> 2.3% | Giá bán: 27.60 | Giá vốn: 26.97 | Lãi/Lỗ: +2.34% (+11,001 đ)
#   > 🟢 MUA STB: Tỷ trọng 0.2% -> 2.9% | Giá khớp: 71.30
#   > 🩸 CẮT LỖ TCH: Tỷ trọng 2.8% -> 1.7% | Giá bán: 15.35 | Giá vốn: 15.38 | Lãi/Lỗ: -0.20% (-3,025 đ)
#   > 🩸 CẮT LỖ VCB: Tỷ trọng 2.8% -> 2.1% | Giá bán: 61.80 | Giá vốn: 62.28 | Lãi/Lỗ: -0.78% (-7,261 đ)
#   > 🔥 CHỐT LỜI VHC: Tỷ trọng 1.5% -> 0.0% | Giá bán: 58.50 | Giá vốn: 57.08 | Lãi/Lỗ: +2.48% (+48,923 đ)
#   > 🩸 CẮT LỖ VNM: Tỷ trọng 1.9% -> 1.7% | Giá bán: 59.10 | Giá vốn: 59.53 | Lãi/Lỗ: -0.74% (-1,652 đ)
#   > 🩸 CẮT LỖ VSC: Tỷ trọng 9.4% -> 7.1% | Giá bán: 18.95 | Giá vốn: 19.12 | Lãi/Lỗ: -0.92% (-29,063 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 1.8%, BMP: 4.9%, BVH: 4.8%, CII: 2.1%, CTD: 2.4%, DCM: 5.3%, DIG: 2.4%, EIB: 2.8%, HCM: 3.7%, HDC: 3.9%, HPG: 2.0%, HSG: 4.2%, KBC: 4.2%, KDC: 2.0%, KDH: 5.0%, MBB: 2.8%, MWG: 3.5%, NLG: 6.7%, PDR: 1.1%, PHR: 3.7%, PNJ: 7.8%, PVT: 1.4%, REE: 2.1%, SSI: 2.3%, STB: 2.9%, TCH: 1.7%, VCB: 2.1%, VNM: 1.7%, VSC: 7.1%]
#   📈 Tài sản: +1,917,466 đ | Hiệu suất ngày: +1.43% | Tổng NAV: 136,369,356 đ
#
# [17/06/2026] 📅 BÁO CÁO GIAO DỊCH:
#   > 🔥 CHỐT LỜI BMP: Tỷ trọng 4.9% -> 4.0% | Giá bán: 147.40 | Giá vốn: 134.81 | Lãi/Lỗ: +9.33% (+112,323 đ)
#   > 🩸 CẮT LỖ BVH: Tỷ trọng 4.8% -> 3.9% | Giá bán: 66.90 | Giá vốn: 67.61 | Lãi/Lỗ: -1.06% (-14,124 đ)
#   > 🟢 MUA CII: Tỷ trọng 2.1% -> 2.7% | Giá khớp: 17.85
#   > 🟢 MUA CTD: Tỷ trọng 2.4% -> 5.1% | Giá khớp: 73.60
#   > 🩸 CẮT LỖ DCM: Tỷ trọng 5.3% -> 4.2% | Giá bán: 36.30 | Giá vốn: 37.77 | Lãi/Lỗ: -3.89% (-57,330 đ)
#   > 🔥 CHỐT LỜI DIG: Tỷ trọng 2.4% -> 1.9% | Giá bán: 13.15 | Giá vốn: 12.71 | Lãi/Lỗ: +3.46% (+22,532 đ)
#   > 🔥 CHỐT LỜI EIB: Tỷ trọng 2.8% -> 2.2% | Giá bán: 21.45 | Giá vốn: 21.01 | Lãi/Lỗ: +2.06% (+16,035 đ)
#   > 🟢 MUA HCM: Tỷ trọng 3.7% -> 3.9% | Giá khớp: 27.50
#   > 🔥 CHỐT LỜI HDC: Tỷ trọng 3.9% -> 3.1% | Giá bán: 16.27 | Giá vốn: 15.66 | Lãi/Lỗ: +3.90% (+38,695 đ)
#   > 🔥 CHỐT LỜI HPG: Tỷ trọng 2.0% -> 1.6% | Giá bán: 24.00 | Giá vốn: 23.64 | Lãi/Lỗ: +1.52% (+8,554 đ)
#   > 🔥 CHỐT LỜI HSG: Tỷ trọng 4.2% -> 3.4% | Giá bán: 12.05 | Giá vốn: 12.02 | Lãi/Lỗ: +0.24% (+2,843 đ)
#   > 🟢 MUA KBC: Tỷ trọng 4.2% -> 5.0% | Giá khớp: 31.05
#   > 🩸 CẮT LỖ KDC: Tỷ trọng 2.0% -> 0.0% | Giá bán: 50.40 | Giá vốn: 50.75 | Lãi/Lỗ: -0.71% (-19,377 đ)
#   > 🟢 MUA KDH: Tỷ trọng 5.0% -> 5.6% | Giá khớp: 23.30
#   > 🩸 CẮT LỖ MBB: Tỷ trọng 2.8% -> 2.2% | Giá bán: 25.20 | Giá vốn: 25.20 | Lãi/Lỗ: -0.01% (-77 đ)
#   > 🔥 CHỐT LỜI MSN: Tỷ trọng 0.6% -> 0.5% | Giá bán: 72.50 | Giá vốn: 72.04 | Lãi/Lỗ: +0.63% (+1,097 đ)
#   > 🔥 CHỐT LỜI MWG: Tỷ trọng 3.5% -> 2.8% | Giá bán: 79.10 | Giá vốn: 79.07 | Lãi/Lỗ: +0.03% (+247 đ)
#   > 🔥 CHỐT LỜI NLG: Tỷ trọng 6.7% -> 5.9% | Giá bán: 27.65 | Giá vốn: 26.55 | Lãi/Lỗ: +4.12% (+47,549 đ)
#   > 🔥 CHỐT LỜI PDR: Tỷ trọng 1.1% -> 0.0% | Giá bán: 15.15 | Giá vốn: 15.14 | Lãi/Lỗ: +0.05% (+724 đ)
#   > 🟢 MUA PHR: Tỷ trọng 3.7% -> 5.0% | Giá khớp: 64.90
#   > 🔥 CHỐT LỜI PNJ: Tỷ trọng 7.8% -> 7.7% | Giá bán: 68.00 | Giá vốn: 66.01 | Lãi/Lỗ: +3.00% (+4,539 đ)
#   > 🟢 MUA PVD: Tỷ trọng 0.4% -> 1.9% | Giá khớp: 30.25
#   > 🔥 CHỐT LỜI PVT: Tỷ trọng 1.4% -> 1.1% | Giá bán: 19.75 | Giá vốn: 19.30 | Lãi/Lỗ: +2.32% (+9,180 đ)
#   > 🩸 CẮT LỖ REE: Tỷ trọng 2.1% -> 1.7% | Giá bán: 50.90 | Giá vốn: 50.91 | Lãi/Lỗ: -0.04% (-214 đ)
#   > 🟢 MUA SSI: Tỷ trọng 2.3% -> 4.2% | Giá khớp: 27.70
#   > 🟢 MUA STB: Tỷ trọng 2.9% -> 4.4% | Giá khớp: 72.10
#   > 🟢 MUA TCH: Tỷ trọng 1.7% -> 2.3% | Giá khớp: 15.30
#   > 🟢 MUA VCB: Tỷ trọng 2.1% -> 2.2% | Giá khớp: 62.20
#   > 🟢 MUA VHC: Tỷ trọng 0.0% -> 0.2% | Giá khớp: 58.50
#   > 🟢 MUA VNM: Tỷ trọng 1.7% -> 3.3% | Giá khớp: 59.00
#   > 🔥 CHỐT LỜI VSC: Tỷ trọng 7.1% -> 5.6% | Giá bán: 20.25 | Giá vốn: 19.12 | Lãi/Lỗ: +5.88% (+114,954 đ)
#   💵 Tỷ trọng: Tiền mặt 0.0% | Cổ phiếu: [BID: 1.8%, BMP: 4.0%, BVH: 3.9%, CII: 2.7%, CTD: 5.1%, DCM: 4.2%, DIG: 1.9%, EIB: 2.2%, HCM: 3.9%, HDC: 3.1%, HPG: 1.6%, HSG: 3.4%, KBC: 5.0%, KDH: 5.6%, MBB: 2.2%, MWG: 2.8%, NLG: 5.9%, PHR: 5.0%, PNJ: 7.7%, PVD: 1.9%, PVT: 1.1%, REE: 1.7%, SSI: 4.2%, STB: 4.4%, TCH: 2.3%, VCB: 2.2%, VNM: 3.3%, VSC: 5.6%]
#   📈 Tài sản: +741,032 đ | Hiệu suất ngày: +0.54% | Tổng NAV: 137,110,388 đ
#
# =========================================================
# 📊 BÁO CÁO HIỆU SUẤT ĐẦU TƯ (BACKTEST)
# =========================================================
# Chỉ số               | AI Strategy     | Benchmark (EQ)
# -------------------------------------------------------
# Tổng lợi nhuận       |          37.11% |          17.62%
# Lợi nhuận năm        |          25.03% |          12.17%
# Sharpe Ratio         |           1.04  |           0.62
# Max Drawdown         |         -23.09% |         -23.65%
# Win Rate (Ngày)      |          55.62% |          54.49%
# -------------------------------------------------------
# Alpha (So với BM): 12.11% (Lợi nhuận vượt trội sau khi trừ rủi ro thị trường)
# Beta  (So với BM): 1.06 (Độ nhạy cảm với biến động chung)
# =========================================================
# 🔍 PHÂN TÍCH HÀNH VI: AI YÊU THÍCH CỔ PHIẾU NÀO NHẤT?
# =========================================================
# PNJ    10.91%
# VSC    10.22%
# KDH     9.93%
# TCH     9.35%
# DCM     8.57%
# HCM     8.09%
# PHR     7.85%
# NLG     7.53%
# NT2     7.41%
# EIB     7.29%
# =========================================================
# 💡 ĐÁNH GIÁ PHONG CÁCH GIAO DỊCH CỦA AI
# =========================================================
# - Tỷ trọng Tiền mặt trung bình: 0.00%
#   -> Phong cách: Tấn công (Aggressive). AI gần như lúc nào cũng full cổ phiếu.
# - Tốc độ xoay vòng vốn (Turnover/ngày): 97.74%
#   -> AI lướt sóng (T+) rất nhiều. Có xu hướng chốt non nhanh để bảo toàn rủi ro.
